# %% [markdown]
# # Reading in a text file
#
# **Text files contain plain text data, JPEGs contain images and MP3s contain audio files. These are examples of files that can be read into Python.**
#
# **To start, you open the text file with Python `open()` function, and you must understand file paths and how to find files in your computer. To get the data itself, you need to iterate over the text line-by-line.**

# %%
jabber = open('data/jabberwocky.txt', 'r')

for line in jabber:
    print(line)
    
    
jabber.close()
# Out:
# 'Twas brillig, and the slithy toves
#
# Did gyre and gimble in the wabe;
#
# All mimsy were the borogoves,
#
# And the mome raths outgrabe.
#
#
#
# "Beware the Jabberwock, my son!
#
# The jaws that bite, the claws that catch!
#
# Beware the Jubjub bird, and shun
#
# The frumious Bandersnatch!"
#
#
#
# He took his vorpal sword in hand:
#
# Long time the manxome foe he soughtâ€”
#
# So rested he by the Tumtum tree,
#
# And stood awhile in thought.
#
#
#
# And as in uffish thought he stood,
#
# The Jabberwock, with eyes of flame,
#
# Came whiffling through the tulgey wood,
#
# And burbled as it came!
#
#
#
# One two! One two! And through and through
#
# The vorpal blade went snicker-snack!
#
# He left it dead, and with its head
#
# He went galumphing back.
#
#
#
# "And hast thou slain the Jabberwock?
#
# Come to my arms, my beamish boy!"
#
# "O frabjous day! Callooh! Callay!"
#
# He chortled in his joy.
#
#
#
# 'Twas brillig, and the slithy toves
#
# Did gyre and gimble in the wabe;
#
# All mimsy were the borogoves,
#
# And the mome raths outgrabe.
#
#
#
#     â€“ Lewis Carroll

# %%
jabber = open('data/jabberwocky.txt', encoding='utf-8')

for line in jabber:
    print(line, end='')
    
    
jabber.close()
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"
#
# He took his vorpal sword in hand:
# Long time the manxome foe he sought—
# So rested he by the Tumtum tree,
# And stood awhile in thought.
#
# And as in uffish thought he stood,
# The Jabberwock, with eyes of flame,
# Came whiffling through the tulgey wood,
# And burbled as it came!
#
# One two! One two! And through and through
# The vorpal blade went snicker-snack!
# He left it dead, and with its head
# He went galumphing back.
#
# "And hast thou slain the Jabberwock?
# Come to my arms, my beamish boy!"
# "O frabjous day! Callooh! Callay!"
# He chortled in his joy.
#
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
#     – Lewis Carroll

# %% [markdown]
# **The text output is automatically double-spaced lines, because it reads an end-of-line caret in the text file as a new line (`\n`). You can change this by updating the end of the print statement in the loop to suppress the automated new line. You can also use Python string methods on the text variable to clean up the data:**
#
#     print(line.strip())
#     print(line.lstrip())
#     print(line.rstrip())
#
# **Also, note that hyphens were not being encoded properly, until adding `encoding` specification.**
#
# **NOTE: You must remember to close the file once done, otherwise there will be problems, especially with Windows. In some cases, the data is lost completely.**
#
# ## `with` statement
#
# **The above code is not the cleanest way to read files. Python introduced the `with` statement in version 2.5 to avoid problems when dealing with external files.**

# %%
with open('data/jabberwocky.txt', encoding='utf-8') as jabber:
    for line in jabber:
        print(line.rstrip())
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"
#
# He took his vorpal sword in hand:
# Long time the manxome foe he sought—
# So rested he by the Tumtum tree,
# And stood awhile in thought.
#
# And as in uffish thought he stood,
# The Jabberwock, with eyes of flame,
# Came whiffling through the tulgey wood,
# And burbled as it came!
#
# One two! One two! And through and through
# The vorpal blade went snicker-snack!
# He left it dead, and with its head
# He went galumphing back.
#
# "And hast thou slain the Jabberwock?
# Come to my arms, my beamish boy!"
# "O frabjous day! Callooh! Callay!"
# He chortled in his joy.
#
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
#     – Lewis Carroll

# %%
# Read top 5 lines to list object

with open('data/jabberwocky.txt', encoding='utf-8') as jabber:
    head = [next(jabber) for _ in range(4)]

    
print(*head)
# Out:
# 'Twas brillig, and the slithy toves
#  Did gyre and gimble in the wabe;
#  All mimsy were the borogoves,
#  And the mome raths outgrabe.

# %% [markdown]
# **The `next()` function retrieves the next line in a text object for adding to the list. The loop ends once the 5th line is reached.**
#
# **Even though iterating over open text file is the most common way to read in text, there are other methods like `read()`, `readline()` and `readlines()`.**
#
# **The `readlines()` method outputs each line of the entire text as string objects in a list.**

# %%
with open('data/jabberwocky.txt', encoding='utf-8') as jabber:
    lines = jabber.readlines()

    
print(*lines)
print(lines)
print()
print(lines[-3])
# Out:
# 'Twas brillig, and the slithy toves
#  Did gyre and gimble in the wabe;
#  All mimsy were the borogoves,
#  And the mome raths outgrabe.
#
#  "Beware the Jabberwock, my son!
#  The jaws that bite, the claws that catch!
#  Beware the Jubjub bird, and shun
#  The frumious Bandersnatch!"
#
#  He took his vorpal sword in hand:
#  Long time the manxome foe he sought—
#  So rested he by the Tumtum tree,
#  And stood awhile in thought.
#
#  And as in uffish thought he stood,
#  The Jabberwock, with eyes of flame,
#  Came whiffling through the tulgey wood,
#  And burbled as it came!
#
#  One two! One two! And through and through
#  The vorpal blade went snicker-snack!
#  He left it dead, and with its head
#  He went galumphing back.
#
#  "And hast thou slain the Jabberwock?
#  Come to my arms, my beamish boy!"
#  "O frabjous day! Callooh! Callay!"
#  He chortled in his joy.
#
#  'Twas brillig, and the slithy toves
#  Did gyre and gimble in the wabe;
#  All mimsy were the borogoves,
#  And the mome raths outgrabe.
#
#      – Lewis Carroll
#
# ["'Twas brillig, and the slithy toves\n", 'Did gyre and gimble in the wabe;\n', 'All mimsy were the borogoves,\n', 'And the mome raths outgrabe.\n', '\n', '"Beware the Jabberwock, my son!\n', 'The jaws that bite, the claws that catch!\n', 'Beware the Jubjub bird, and shun\n', 'The frumious Bandersnatch!"\n', '\n', 'He took his vorpal sword in hand:\n', 'Long time the manxome foe he sought—\n', 'So rested he by the Tumtum tree,\n', 'And stood awhile in thought.\n', '\n', 'And as in uffish thought he stood,\n', 'The Jabberwock, with eyes of flame,\n', 'Came whiffling through the tulgey wood,\n', 'And burbled as it came!\n', '\n', 'One two! One two! And through and through\n', 'The vorpal blade went snicker-snack!\n', 'He left it dead, and with its head\n', 'He went galumphing back.\n', '\n', '"And hast thou slain the Jabberwock?\n', 'Come to my arms, my beamish boy!"\n', '"O frabjous day! Callooh! Callay!"\n', 'He chortled in his joy.\n', '\n', "'Twas brillig, and the slithy toves\n", 'Did gyre and gimble in the wabe;\n', 'All mimsy were the borogoves,\n', 'And the mome raths outgrabe.\n', '\n', '    – Lewis Carroll\n']
#
# And the mome raths outgrabe.

# %% [markdown]
# **The `read()` method returns the entire text as one single string rather than split up into lines, even though the output looks similar.**

# %%
with open('data/jabberwocky.txt', encoding='utf-8') as jabber:
    text = jabber.read()
    
print(text)
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"
#
# He took his vorpal sword in hand:
# Long time the manxome foe he sought—
# So rested he by the Tumtum tree,
# And stood awhile in thought.
#
# And as in uffish thought he stood,
# The Jabberwock, with eyes of flame,
# Came whiffling through the tulgey wood,
# And burbled as it came!
#
# One two! One two! And through and through
# The vorpal blade went snicker-snack!
# He left it dead, and with its head
# He went galumphing back.
#
# "And hast thou slain the Jabberwock?
# Come to my arms, my beamish boy!"
# "O frabjous day! Callooh! Callay!"
# He chortled in his joy.
#
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
#     – Lewis Carroll

# %%
# Print the string backwards

for character in reversed(text):
    print(character, end='')
# Out:
# llorraC siweL –
#
# .ebargtuo shtar emom eht dnA
# ,sevogorob eht erew ysmim llA
# ;ebaw eht ni elbmig dna eryg diD
# sevot yhtils eht dna ,gillirb sawT'
#
# .yoj sih ni deltrohc eH
# "!yallaC !hoollaC !yad suojbarf O"
# "!yob hsimaeb ym ,smra ym ot emoC
# ?kcowrebbaJ eht nials uoht tsah dnA"
#
# .kcab gnihpmulag tnew eH
# daeh sti htiw dna ,daed ti tfel eH
# !kcans-rekcins tnew edalb laprov ehT
# hguorht dna hguorht dnA !owt enO !owt enO
#
# !emac ti sa delbrub dnA
# ,doow yeglut eht hguorht gnilffihw emaC
# ,emalf fo seye htiw ,kcowrebbaJ ehT
# ,doots eh thguoht hsiffu ni sa dnA
#
# .thguoht ni elihwa doots dnA
# ,eert mutmuT eht yb eh detser oS
# —thguos eh eof emoxnam eht emit gnoL
# :dnah ni drows laprov sih koot eH
#
# "!hctansrednaB suoimurf ehT
# nuhs dna ,drib bujbuJ eht eraweB
# !hctac taht swalc eht ,etib taht swaj ehT
# !nos ym ,kcowrebbaJ eht eraweB"
#
# .ebargtuo shtar emom eht dnA
# ,sevogorob eht erew ysmim llA
# ;ebaw eht ni elbmig dna eryg diD
# sevot yhtils eht dna ,gillirb sawT'

# %% [markdown]
# **The `readline()` method is not as useful as the others, but you can handle each line separately which is useful in large text files. It is similar to iterating over the text in `for` loop seen at the start.**

# %%
with open('data/jabberwocky.txt', encoding='utf-8') as jabber:
    while True:
        line = jabber.readline().rstrip()
        print(line)
        
        if 'bandersnatch' in line.casefold():
            break
# Out:
# 'Twas brillig, and the slithy toves
# Did gyre and gimble in the wabe;
# All mimsy were the borogoves,
# And the mome raths outgrabe.
#
# "Beware the Jabberwock, my son!
# The jaws that bite, the claws that catch!
# Beware the Jubjub bird, and shun
# The frumious Bandersnatch!"

# %%
print(line)
# Out:
# The frumious Bandersnatch!"

# %% [markdown]
# ## String methods
#
# **You have seen `strip()` and `rstrip()` methods used to process text, but their behaviour is not obvious without some explanation, especially when you involve other string methods, like `lstrip()`.**
#
# **In Python, whitespace characters refer to space, tab, newline, carriage returns and character feeds. When using `strip()` method on a string object, Python removes any leading or trailing whitespace characters.**
#
# **The `lstrip()` method removes any whitespace characters from the left side of the string, e.g. tab spaces.**
#
# **The `rstrip()` method removes any whitespace characters from the right side of the string, e.g. newline characters.**
#
# **Use the appropriate method based on your preferred language and whether it reads from left-to-right or vice versa.**

# %%
filepath = 'data/jabberwocky.txt'

with open(filepath) as poem:
    first = poem.readline().rstrip()
    

print(first)
# Out:
# 'Twas brillig, and the slithy toves

# %%
filepath = 'data/jabberwocky.txt'

with open(filepath) as poem:
    first = poem.readline().lstrip()
    

print(first)
# Out:
# 'Twas brillig, and the slithy toves

# %%
filepath = 'data/jabberwocky.txt'

with open(filepath) as poem:
    first = poem.readline().strip()
    

print(first)
# Out:
# 'Twas brillig, and the slithy toves

# %% [markdown]
# **The stripping methods check for the default whitespace or defined sequence of characters that you want removed at start or end of a string, and only if they exist at the start or end of the string are the characters removed. Once the defined characters have been checked, the function ends.**
#
# **As you can see, all three methods output the same when reading the first line, so there appears no difference in behaviour. The initial apostrophe is not considered whitespace, so you would need to explicity define it to be removed when stripping. You should use `lstrip()` method because stripping will remove the apostrophe from both ends.**

# %%
chars = "' "

no_apos_first = first.lstrip(chars)

print(no_apos_first)
# Out:
# Twas brillig, and the slithy toves

# %% [markdown]
# ## Parsing Data in text file
#
# **In many cases, the data will be formatted in the text file in such a way that you need to 'parse' the data, e.g. when a line is actually a row and each field is separated by comma or `|` separator, i.e. a table with rows and columns. You can read the data into nested dictionaries, lists or sets.**
#
# **In the text sample provided, there are seven fields for each country, containing the capital name, country and phone codes, currency and timezone. Not all countries have data for each field so there are missing values, e.g. Antarctica has no capital city and polar regions cover all timezones. Parsing the data means making sense of the data, by separating it into logical components for the Python compiler.**
#
#     Country|Capital|CC|CC3|IAC|TimeZone|Currency
#     Afghanistan|Kabul|AF|AFG|+93|UTC+04:30|Afghan afghani
#     ...

# %%
input_file = 'data/country_info.txt'

# %%
# Note that list for Antarctica has seven strings, even if most are empty

with open(input_file) as countries:
    for row in countries:
        data = row.strip().split('|')
        print(data)
# Out:
# ['Country', 'Capital', 'CC', 'CC3', 'IAC', 'TimeZone', 'Currency']
# ['Afghanistan', 'Kabul', 'AF', 'AFG', '+93', 'UTC+04:30', 'Afghan afghani']
# ['Aland Islands', 'Mariehamn', 'AX', 'ALA', '+358', 'UTC+02:00', 'Euro']
# ['Albania', 'Tirana', 'AL', 'ALB', '+355', 'UTC+01:00', 'Albanian lek']
# ['Algeria', 'Algiers', 'DZ', 'DZA', '+213', 'UTC', 'Algerian dinar']
# ['American Samoa', 'Pago Pago', 'AS', 'ASM', '+1 684', 'UTC-11:00', '']
# ['Andorra', 'Andorra la Vella', 'AD', 'AND', '+376', 'UTC+01:00', 'Euro']
# ['Angola', 'Luanda', 'AO', 'AGO', '+244', 'UTC+01:00', 'Angolan kwanza']
# ['Anguilla', 'The Valley', 'AI', 'AIA', '+1 264', 'UTC-04:00', 'East Caribbean dollar']
# ['Antarctica', '', 'AQ', 'ATA', '', '', '']
# ['Antigua and Barbuda', "St. John's", 'AG', 'ATG', '+1 268', 'UTC-04:00', 'East Caribbean dollar']
# ['Argentina', 'Buenos Aires', 'AR', 'ARG', '+54', 'UTC-03:00', 'Argentine peso']
# ['Armenia', 'Yerevan', 'AM', 'ARM', '+374', 'UTC+04:00', 'Armenian dram']
# ['Aruba', 'Oranjestad', 'AW', 'ABW', '+297', 'UTC-04:00', 'Aruban florin']
# ['Australia', 'Canberra', 'AU', 'AUS', '+61', 'UTC+07:00 - UTC+10:00', 'Australian dollar']
# ['Austria', 'Vienna', 'AT', 'AUT', '+43', 'UTC+01:00', 'Euro']
# ['Azerbaijan', 'Baku', 'AZ', 'AZE', '+994', 'UTC+04:00', 'Azerbaijani manat']
# ['Bahamas', 'Nassau', 'BS', 'BHS', '+1 242', 'UTC-05:00', 'Bahamian dollar']
# ['Bahrain', 'Manama', 'BH', 'BHR', '+973', 'UTC+03:00', 'Bahraini dinar']
# ['Bangladesh', 'Dhaka', 'BD', 'BGD', '+880', 'UTC+06:00', 'Bangladeshi taka']
# ['Barbados', 'Bridgetown', 'BB', 'BRB', '+1 246', 'UTC-04:00', 'Barbadian dollar']
# ['Belarus', 'Minsk', 'BY', 'BLR', '+375', 'UTC+03:00', 'Belarusian ruble']
# ['Belgium', 'Brussels', 'BE', 'BEL', '+32', 'UTC+01:00', 'Euro']
# ['Belize', 'Belmopan', 'BZ', 'BLZ', '+501', 'UTC-06:00', 'Belize dollar']
# ['Benin', 'Porto-Novo', 'BJ', 'BEN', '+229', 'UTC+01:00', 'West African CFA franc']
# ['Bermuda', 'Hamilton', 'BM', 'BMU', '+1 441', 'UTC-04:00', 'Bermudian dollar']
# ['Bhutan', 'Thimphu', 'BT', 'BTN', '+975', 'UTC+05:30', 'Bhutanese ngultrum']
# ['Bolivia', 'Sucre', 'BO', 'BOL', '+591', 'UTC-04:00', 'Bolivian boliviano']
# ['Bonaire', 'Kralendijk', 'BQ', 'BES', '+599', 'UTC-04:00', 'United States dollar']
# ['Bosnia and Herzegovina', 'Sarajevo', 'BA', 'BIH', '+387', 'UTC+01:00', 'Bosnia and Herzegovina convertible mark']
# ['Botswana', 'Gaborone', 'BW', 'BWA', '+267', 'UTC+02:00', 'Botswana pula']
# ['Bouvet Island', '', 'BV', 'BVT', '', 'UTC+01:00', '']
# ['Brazil', 'BrasÃ\xadlia', 'BR', 'BRA', '+55', 'UTC-05:00 - UTC-03:00', 'Brazilian real']
# ['British Indian Ocean Territory', 'Diego Garcia', 'IO', 'IOT', '+246', 'UTC+06', 'United States dollar']
# ['Brunei', 'Bandar Seri Begawan', 'BN', 'BRN', '+673', 'UTC+08:00', 'Brunei dollar']
# ['Bulgaria', 'Sofia', 'BG', 'BGR', '+359', 'UTC+02:00', 'Bulgarian lev']
# ['Burkina Faso', 'Ouagadougou', 'BF', 'BFA', '+226', 'UTC', 'West African CFA franc']
# ['Burundi', 'Bujumbura', 'BI', 'BDI', '+257', 'UTC+02:00', 'Burundian franc']
# ['Cambodia', 'Phnom Penh', 'KH', 'KHM', '+855', 'UTC+07:00', 'Cambodian riel']
# ['Cameroon', 'YaoundÃ©', 'CM', 'CMR', '+237', 'UTC+01:00', 'Central African CFA franc']
# ['Canada', 'Ottawa', 'CA', 'CAN', '+1', 'UTC-08:00 - UTC-04:00', 'Canadian dollar']
# ['Cape Verde', 'Praia', 'CV', 'CPV', '+238', 'UTC-01:00', 'Cape Verdean escudo']
# ['Cayman Islands', 'George Town', 'KY', 'CYM', '+1 345', 'UTC-05:00', 'Cayman Islands dollar']
# ['Central African Republic', 'Bangui', 'CF', 'CAF', '+236', 'UTC+01:00', 'Central African CFA franc']
# ['Chad', "N'Djamena", 'TD', 'TCD', '+235', 'UTC+01:00', 'Central African CFA franc']
# ['Chile', 'Santiago', 'CL', 'CHL', '+56', 'UTC-04:00', 'Chilean peso']
# ['China', 'Beijing', 'CN', 'CHN', '+86', 'UTC+08:00', 'Chinese yuan']
# ['Christmas Island', 'Flying Fish Cove', 'CX', 'CXR', '+61 8 9164', 'UTC+07', 'Australian dollar']
# ['Cocos (Keeling) Islands', 'West Island', 'CC', 'CCK', '+61 8 9162', 'UTC+06:30', 'Australian dollar']
# ['Colombia', 'BogotÃ¡', 'CO', 'COL', '+57', 'UTC-05:00', 'Colombian peso']
# ['Comoros', 'Moroni', 'KM', 'COM', '+269', 'UTC+03:00', 'Comorian franc']
# ['Congo, Republic of the', 'Brazzaville', 'CG', 'COG', '+242', 'UTC+01:00', 'Central African CFA franc']
# ['Congo, Democratic Republic of the', 'Kinshasa', 'CD', 'COD', '+243', 'UTC+01:00 - UTC+02:00', 'Congolese franc']
# ['Cook Islands', 'Avarua', 'CK', 'COK', '+682', 'UTC-10:00', 'New Zealand dollar']
# ['Costa Rica', 'San JosÃ©', 'CR', 'CRI', '+506', 'UTC-06:00', 'Costa Rican colÃ³n']
# ["CÃ´te d'Ivoire", 'Yamoussoukro', 'CI', 'CIV', '+225', 'UTC', 'West African CFA franc']
# ['Croatia', 'Zagreb', 'HR', 'HRV', '+385', 'UTC+01:00', 'Croatian kuna']
# ['Cuba', 'Havana', 'CU', 'CUB', '+53', 'UTC-03:00', 'Cuban convertible peso']
# ['Curacao', 'Willemstad', 'CW', 'CUW', '+599 9', 'UTC-04:00', 'Netherlands Antillean guilder']
# ['Cyprus', 'Nicosia', 'CY', 'CYP', '+357', 'UTC+02:00', 'Euro']
# ['Czech Republic', 'Prague', 'CZ', 'CZE', '+420', 'UTC+01:00', 'Czech koruna']
# ['Denmark', 'Copenhagen', 'DK', 'DNK', '+45', 'UTC+01:00', 'Danish krone']
# ['Djibouti', 'Djibouti', 'DJ', 'DJI', '+253', 'UTC+03:00', 'Djiboutian franc']
# ['Dominica', 'Roseau', 'DM', 'DMA', '+1 767', 'UTC-04:00', 'East Caribbean dollar']
# ['Dominican Republic', 'Santo Domingo', 'DO', 'DOM', '+1 809/829/849', 'UTC-04:00', 'Dominican peso']
# ['East Timor', 'Dili', 'TL', 'TLS', '+670', 'UTC+09', 'United States dollar']
# ['Ecuador', 'Quito', 'EC', 'ECU', '+593', 'UTC-05:00', 'United States dollar']
# ['Egypt', 'Cairo', 'EG', 'EGY', '+20', 'UTC+02:00', 'Egyptian pound']
# ['El Salvador', 'San Salvador', 'SV', 'SLV', '+503', 'UTC-06:00', 'Salvadoran colÃ³n']
# ['Equatorial Guinea', 'Malabo', 'GQ', 'GNQ', '+240', 'UTC+01:00', 'Central African CFA franc']
# ['Eritrea', 'Asmara', 'ER', 'ERI', '+291', 'UTC+03:00', 'Eritrean nakfa']
# ['Estonia', 'Tallinn', 'EE', 'EST', '+372', 'UTC+03:00', 'Euro']
# ['Ethiopia', 'Addis Ababa', 'ET', 'ETH', '+251', 'UTC+03:00', 'Ethiopian birr']
# ['Falkland Islands (Malvinas)', 'Stanley', 'FK', 'FLK', '+500', 'UTC-04:00', 'Falkland Islands pound']
# ['Faroe Islands', 'TÃ³rshavn', 'FO', 'FRO', '+298', 'UTC', 'Danish krone']
# ['Fiji', 'Suva', 'FJ', 'FJI', '+679', 'UTC+12:00', 'Fijian dollar']
# ['Finland', 'Helsinki', 'FI', 'FIN', '+358', 'UTC+02:00', 'Euro']
# ['France', 'Paris', 'FR', 'FRA', '+33', 'UTC+01:00', 'Euro']
# ['French Guiana', 'Cayenne', 'GF', 'GUF', '+594', 'UTC-01:00', 'Euro']
# ['French Polynesia', 'Papeete', 'PF', 'PYF', '+689', 'UTC-10:00', 'CFP franc']
# ['French Southern Territories', 'Port-aux-FranÃ§ais', 'TF', 'ATF', '', 'UTC+05:00', 'Euro']
# ['Gabon', 'Libreville', 'GA', 'GAB', '+241', 'UTC+01:00', 'Central African CFA franc']
# ['Gambia', 'Banjul', 'GM', 'GMB', '+220', 'UTC', 'Gambian dalasi']
# ['Georgia', 'Tbilisi', 'GE', 'GEO', '+995', 'UTC+04:00', 'Georgian lari']
# ['Germany', 'Berlin', 'DE', 'DEU', '+49', 'UTC+01:00', 'Euro']
# ['Ghana', 'Accra', 'GH', 'GHA', '+233', 'UTC', 'Ghanaian cedi']
# ['Gibraltar', 'Gibraltar', 'GI', 'GIB', '+350', 'UTC+01:00', 'Gibraltar pound']
# ['Greece', 'Athens', 'GR', 'GRC', '+30', 'UTC+02:00', 'Euro']
# ['Greenland', 'Nuuk', 'GL', 'GRL', '+299', 'UTC-03:00', 'Danish krone']
# ['Grenada', "St. George's", 'GD', 'GRD', '+1 473', 'UTC-04:00', 'East Caribbean dollar']
# ['Guadeloupe', 'Basse-Terre', 'GP', 'GLP', '+590', 'UTC-04:00', 'Euro']
# ['Guam', 'HagÃ¥tÃ±a', 'GU', 'GUM', '+1 671', 'UTC+10:00', 'United States dollar']
# ['Guatemala', 'Guatemala City', 'GT', 'GTM', '+502', 'UTC-06:00', 'Guatemalan quetzal']
# ['Guernsey', 'St. Peter Port', 'GG', 'GGY', '+44 1481', 'UTC', 'British pound']
# ['Guinea', 'Conakry', 'GN', 'GIN', '+224', 'UTC', 'Guinean franc']
# ['Guinea-Bissau', 'Bissau', 'GW', 'GNB', '+245', 'UTC', 'West African CFA franc']
# ['Guyana', 'Georgetown', 'GY', 'GUY', '+592', 'UTC-03:00', 'Guyanese dollar']
# ['Haiti', 'Port-au-Prince', 'HT', 'HTI', '+509', 'UTC-05:00', 'Haitian gourde']
# ['Heard Island and McDonald Islands', '', 'HM', 'HMD', '', 'UTC+05', '']
# ['Honduras', 'Tegucigalpa', 'HN', 'HND', '+504', 'UTC-06:00', 'Honduran lempira']
# ['Hong Kong', '', 'HK', 'HKG', '+852', 'UTC+08:00', 'Hong Kong dollar']
# ['Hungary', 'Budapest', 'HU', 'HUN', '+36', 'UTC+01:00', 'Hungarian forint']
# ['Iceland', 'ReykjavÃ\xadk', 'IS', 'ISL', '+354', 'UTC', 'Icelandic krÃ³na']
# ['India', 'New Delhi', 'IN', 'IND', '+91', 'UTC+05:30', 'Indian rupee']
# ['Indonesia', 'Jakarta', 'ID', 'IDN', '+62', 'UTC+07:00 - UTC+09:00', 'Indonesian rupiah']
# ['Iran', 'Tehran', 'IR', 'IRN', '+98', 'UTC+03:30', 'Iranian rial']
# ['Iraq', 'Baghdad', 'IQ', 'IRQ', '+964', 'UTC+03:00', 'Iraqi dinar']
# ['Ireland', 'Dublin', 'IE', 'IRL', '+353', 'UTC', 'Euro']
# ['Isle of Man', 'Douglas', 'IM', 'IMN', '+44 1624', 'UTC', 'British pound']
# ['Israel', 'Jerusalem', 'IL', 'ISR', '+972', 'UTC+02:00', 'Israeli new shekel']
# ['Italy', 'Rome', 'IT', 'ITA', '+39', 'UTC+01:00', 'Euro']
# ['Jamaica', 'Kingston', 'JM', 'JAM', '+1 876', 'UTC-05:00', 'Jamaican dollar']
# ['Japan', 'Tokyo', 'JP', 'JPN', '+81', 'UTC+09:00', 'Japanese yen']
# ['Jersey', 'St. Helier', 'JE', 'JEY', '+44 1534', 'UTC', 'British pound']
# ['Jordan', 'Amman', 'JO', 'JOR', '+962', 'UTC+02:00', 'Jordanian dinar']
# ['Kazakhstan', 'Astana', 'KZ', 'KAZ', '+7 6xx/7xx', 'UTC+06:00', 'Kazakhstani tenge']
# ['Kenya', 'Nairobi', 'KE', 'KEN', '+254', 'UTC+03:00', 'Kenyan shilling']
# ['Kiribati', 'Tarawa', 'KI', 'KIR', '+686', 'UTC+12:00', 'Australian dollar']
# ['Kuwait', 'Kuwait City', 'KW', 'KWT', '+965', 'UTC+03:00', 'Kuwaiti dinar']
# ['Kyrgyzstan', 'Bishkek', 'KG', 'KGZ', '+996', 'UTC+06:00', 'Kyrgyzstani som']
# ['Laos', 'Vientiane', 'LA', 'LAO', '+856', 'UTC+07:00', 'Lao kip']
# ['Latvia', 'Riga', 'LV', 'LVA', '+371', 'UTC+03:00', 'Latvian lats']
# ['Lebanon', 'Beirut', 'LB', 'LBN', '+961', 'UTC+02:00', 'Lebanese pound']
# ['Lesotho', 'Maseru', 'LS', 'LSO', '+266', 'UTC+02:00', 'Lesotho loti']
# ['Liberia', 'Monrovia', 'LR', 'LBR', '+231', 'UTC', 'Liberian dollar']
# ['Libya', 'Tripoli', 'LY', 'LBY', '+218', 'UTC+02:00', 'Libyan dinar']
# ['Liechtenstein', 'Vaduz', 'LI', 'LIE', '+423', 'UTC+01:00', 'Swiss franc']
# ['Lithuania', 'Vilnius', 'LT', 'LTU', '+370', 'UTC+02:00', 'Lithuanian litas']
# ['Luxembourg', 'Luxembourg', 'LU', 'LUX', '+352', 'UTC+01:00', 'Euro']
# ['Macau', '', 'MO', 'MAC', '+853', 'UTC+08:00', 'Macanese pataca']
# ['Macedonia', 'Skopje', 'MK', 'MKD', '+389', 'UTC+01:00', 'Macedonian denar']
# ['Madagascar', 'Antananarivo', 'MG', 'MDG', '+261', 'UTC+03:00', 'Malagasy ariary']
# ['Malawi', 'Lilongwe', 'MW', 'MWI', '+265', 'UTC+02:00', 'Malawian kwacha']
# ['Malaysia', 'Kuala Lumpur', 'MY', 'MYS', '+60', 'UTC+08:00', 'Malaysian ringgit']
# ['Maldives', 'MalÃ©', 'MV', 'MDV', '+960', 'UTC+05:00', 'Maldivian rufiyaa']
# ['Mali', 'Bamako', 'ML', 'MLI', '+223', 'UTC', 'West African CFA franc']
# ['Malta', 'Valletta', 'MT', 'MLT', '+356', 'UTC+01:00', 'Euro']
# ['Marshall Islands', 'Majuro', 'MH', 'MHL', '+692', 'UTC+10:00', 'United States dollar']
# ['Martinique', 'Fort-de-France', 'MQ', 'MTQ', '+596', 'UTC-04:00', 'Euro']
# ['Mauritania', 'Nouakchott', 'MR', 'MRT', '+222', 'UTC', 'Mauritanian ouguiya']
# ['Mauritius', 'Port Louis', 'MU', 'MUS', '+230', 'UTC+04:00', 'Mauritian rupee']
# ['Mayotte', 'Mamoudzou', 'YT', 'MYT', '+262 269/639', 'UTC+03:00', 'Euro']
# ['Mexico', 'Mexico City', 'MX', 'MEX', '+52', 'UTC-08:00 - UTC-06:00', 'Mexican peso']
# ['Micronesia', 'Palikir', 'FM', 'FSM', '+691', 'UTC+10:00', 'Micronesian dollar']
# ['Moldova', 'Chisinau', 'MD', 'MDA', '+373', 'UTC+03:00', 'Moldovan leu']
# ['Monaco', 'Monaco', 'MC', 'MCO', '+377', 'UTC+01:00', 'Euro']
# ['Mongolia', 'Ulaanbaatar', 'MN', 'MNG', '+976', 'UTC+08:00', 'Mongolian tÃ¶grÃ¶g']
# ['Montenegro', 'Podgorica', 'ME', 'MNE', '+382', 'UTC+01', 'Euro']
# ['Montserrat', 'Plymouth', 'MS', 'MSR', '+1 664', 'UTC-04:00', 'East Caribbean dollar']
# ['Morocco', 'Rabat', 'MA', 'MAR', '+212', 'UTC', 'Moroccan dirham']
# ['Mozambique', 'Maputo', 'MZ', 'MOZ', '+258', 'UTC+02:00', 'Mozambican metical']
# ['Myanmar (Burma)', 'Naypyidaw', 'MM', 'MMR', '+95', 'UTC+06:30', 'Myanma kyat']
# ['Namibia', 'Windhoek', 'NA', 'NAM', '+264', 'UTC+02:00', 'Namibian dollar']
# ['Nauru', 'Yaren', 'NR', 'NRU', '+674', 'UTC+12:00', 'Australian dollar']
# ['Nepal', 'Kathmandu', 'NP', 'NPL', '+977', 'UTC+05:30', 'Nepalese rupee']
# ['Netherlands', 'Amsterdam', 'NL', 'NLD', '+31', 'UTC+01:00', 'Euro']
# ['New Caledonia', 'NoumÃ©a', 'NC', 'NCL', '+687', 'UTC+11:00', 'CFP franc']
# ['New Zealand', 'Wellington', 'NZ', 'NZL', '+64', 'UTC+12:00', 'New Zealand dollar']
# ['Nicaragua', 'Managua', 'NI', 'NIC', '+505', 'UTC-06:00', 'Nicaraguan cÃ³rdoba']
# ['Niger', 'Niamey', 'NE', 'NER', '+227', 'UTC+01:00', 'West African CFA franc']
# ['Nigeria', 'Abuja', 'NG', 'NGA', '+234', 'UTC+01:00', 'Nigerian naira']
# ['Niue', 'Alofi', 'NU', 'NIU', '+683', 'UTC-11:00', 'New Zealand dollar']
# ['Norfolk Island', 'Kingston', 'NF', 'NFK', '+672 3', 'UTC+11:30', 'Australian dollar']
# ['North Korea', 'Pyongyang', 'KP', 'PRK', '+850', 'UTC+09:00', 'North Korean won']
# ['Northern Mariana Islands', 'Saipan', 'MP', 'MNP', '+1 670', 'UTC+10:00', 'United States dollar']
# ['Norway', 'Oslo', 'NO', 'NOR', '+47', 'UTC+01:00', 'Norwegian krone']
# ['Oman', 'Muscat', 'OM', 'OMN', '+968', 'UTC+04:00', 'Omani rial']
# ['Pakistan', 'Islamabad', 'PK', 'PAK', '+92', 'UTC+05:00', 'Pakistani rupee']
# ['Palau', 'Ngerulmud', 'PW', 'PLW', '+680', 'UTC+09:00', 'Palauan dollar']
# ['Panama', 'Panama City', 'PA', 'PAN', '+507', 'UTC-05:00', 'Panamanian balboa']
# ['Papua New Guinea', 'Port Moresby', 'PG', 'PNG', '+675', 'UTC+10:00', 'Papua New Guinean kina']
# ['Paraguay', 'AsunciÃ³n', 'PY', 'PRY', '+595', 'UTC-04:00', 'Paraguayan guaranÃ\xad']
# ['Peru', 'Lima', 'PE', 'PER', '+51', 'UTC-05:00', 'Peruvian nuevo sol']
# ['Philippines', 'Manila', 'PH', 'PHL', '+63', 'UTC+08:00', 'Philippine peso']
# ['Pitcairn', 'Adamstown', 'PN', 'PCN', '+872', 'UTC-08', 'New Zealand dollar']
# ['Poland', 'Warsaw', 'PL', 'POL', '+48', 'UTC+01:00', 'Polish zÅ‚oty']
# ['Portugal', 'Lisbon', 'PT', 'PRT', '+351', 'UTC+01:00', 'Euro']
# ['Puerto Rico', 'San Juan', 'PR', 'PRI', '+1 787/939', 'UTC-04:00', 'United States dollar']
# ['Qatar', 'Doha', 'QA', 'QAT', '+974', 'UTC+03:00', 'Qatari riyal']
# ['Reunion', '', 'RE', 'REU', '+262', 'UTC+04:00', 'Euro']
# ['Romania', 'Bucharest', 'RO', 'ROU', '+40', 'UTC+02:00', 'Romanian leu']
# ['Russia', 'Moscow', 'RU', 'RUS', '+7', 'UTC+03:00', 'Russian ruble']
# ['Rwanda', 'Kigali', 'RW', 'RWA', '+250', 'UTC+02:00', 'Rwandan franc']
# ['Saint Barthelemy', 'Gustavia', 'BL', 'BLM', '+590', 'UTC-04', 'Euro']
# ['Saint Helena', 'Jamestown', 'SH', 'SHN', '+290', 'UTC', 'Saint Helena pound']
# ['Saint Kitts and Nevis', 'Basseterre', 'KN', 'KNA', '+1 869', 'UTC-04:00', 'East Caribbean dollar']
# ['Saint Lucia', 'Castries', 'LC', 'LCA', '+1 758', 'UTC-04:00', 'East Caribbean dollar']
# ['Saint Martin', 'Marigot', 'MF', 'MAF', '+590', 'UTC-04', 'Euro']
# ['Saint Pierre and Miquelon', 'St. Pierre', 'PM', 'SPM', '+508', 'UTC-03', 'Euro']
# ['Saint Vincent and the Grenadines', 'Kingstown', 'VC', 'VCT', '+1 784', 'UTC-04', 'East Caribbean dollar']
# ['Samoa', 'Apia', 'WS', 'WSM', '+685', 'UTC-11:00', 'Samoan tala']
# ['San Marino', 'San Marino', 'SM', 'SMR', '+378', 'UTC+01:00', 'Euro']
# ['Sao Tome and PrÃ\xadncipe', 'SÃ£o TomÃ©', 'ST', 'STP', '+239', 'UTC', 'SÃ£o TomÃ© and PrÃ\xadncipe dobra']
# ['Saudi Arabia', 'Riyadh', 'SA', 'SAU', '+966', 'UTC+03:00', 'Saudi riyal']
# ['Senegal', 'Dakar', 'SN', 'SEN', '+221', 'UTC', 'West African CFA franc']
# ['Serbia', 'Belgrade', 'RS', 'SRB', '+381', 'UTC+01:00', 'Serbian dinar']
# ['Seychelles', 'Victoria', 'SC', 'SYC', '+248', 'UTC+04:00', 'Seychellois rupee']
# ['Sierra Leone', 'Freetown', 'SL', 'SLE', '+232', 'UTC', 'Sierra Leonean leone']
# ['Singapore', 'Singapore', 'SG', 'SGP', '+65', 'UTC+08:00', 'Brunei dollar']
# ['Sint Maarten', 'Philipsburg', 'SX', 'SXM', '+599 5', 'UTC-04:00', 'Netherlands Antillean guilder']
# ['Slovakia', 'Bratislava', 'SK', 'SVK', '+421', 'UTC+01:00', 'Euro']
# ['Slovenia', 'Ljubljana', 'SI', 'SVN', '+386', 'UTC+01:00', 'Euro']
# ['Solomon Islands', 'Honiara', 'SB', 'SLB', '+677', 'UTC+11:00', 'Solomon Islands dollar']
# ['Somalia', 'Mogadishu', 'SO', 'SOM', '+252', 'UTC+03:00', 'Somali shilling']
# ['South Africa', 'Pretoria', 'ZA', 'ZAF', '+27', 'UTC+02:00', 'South African rand']
# ['South Georgia and the South Sandwich Islands', 'Grytviken', 'GS', 'SGS', '', 'UTC-02', 'British pound']
# ['South Korea', 'Seoul', 'KR', 'KOR', '+82', 'UTC+09:00', 'South Korean won']
# ['Spain', 'Madrid', 'ES', 'ESP', '+34', 'UTC+01:00', 'Euro']
# ['Sri Lanka', 'Sri Jayawardenapura Kotte', 'LK', 'LKA', '+94', 'UTC+05:30', 'Sri Lankan rupee']
# ['Sudan', 'Khartoum', 'SD', 'SDN', '+249', 'UTC+02:00', 'Sudanese pound']
# ['Suriname', 'Paramaribo', 'SR', 'SUR', '+597', 'UTC-03:30', 'Surinamese dollar']
# ['Svalbard and Jan Mayen', '', 'SJ', 'SJM', '+47', 'UTC+01:00', 'Norwegian krone']
# ['Swaziland', 'Mbabane', 'SZ', 'SWZ', '+268', 'UTC+02:00', 'Swazi lilangeni']
# ['Sweden', 'Stockholm', 'SE', 'SWE', '+46', 'UTC+01:00', 'Swedish krona']
# ['Switzerland', 'Bern', 'CH', 'CHE', '+41', 'UTC+01:00', 'Swiss franc']
# ['Syrian Arab Republic', 'Damascus', 'SY', 'SYR', '+963', 'UTC+02:00', 'Syrian pound']
# ['Taiwan', 'Taipei', 'TW', 'TWN', '+886', 'UTC+08:00', 'New Taiwan dollar']
# ['Tajikistan', 'Dushanbe', 'TJ', 'TJK', '+992', 'UTC+06:00', 'Tajikistani somoni']
# ['Tanzania', 'Dodoma', 'TZ', 'TZA', '+255', 'UTC+03:00', 'Tanzanian shilling']
# ['Thailand', 'Bangkok', 'TH', 'THA', '+66', 'UTC+07:00', 'Thai baht']
# ['Togo', 'LomÃ©', 'TG', 'TGO', '+228', 'UTC', 'West African CFA franc']
# ['Tokelau', 'Rotates annually', 'TK', 'TKL', '+690', 'UTC-10', 'New Zealand dollar']
# ['Tonga', 'Nuku', 'TO', 'TON', '+676', 'UTC+13:00', 'Tongan paÊ»anga']
# ['Trinidad and Tobago', 'Port of Spain', 'TT', 'TTO', '+1 868', 'UTC-04:00', 'Trinidad and Tobago dollar']
# ['Tunisia', 'Tunis', 'TN', 'TUN', '+216', 'UTC+01:00', 'Tunisian dinar']
# ['Turkey', 'Ankara', 'TR', 'TUR', '+90', 'UTC+02:00', 'Turkish lira']
# ['Turkmenistan', 'Ashgabat', 'TM', 'TKM', '+993', 'UTC+05:00', 'Turkmenistani manat']
# ['Turks and Caicos Islands', 'Cockburn Town', 'TC', 'TCA', '+1 649', 'UTC-05:00', 'United States dollar']
# ['Tuvalu', 'Funafuti', 'TV', 'TUV', '+688', 'UTC+12:00', 'Australian dollar']
# ['Uganda', 'Kampala', 'UG', 'UGA', '+256', 'UTC+03:00', 'Ugandan shilling']
# ['Ukraine', 'Kyiv', 'UA', 'UKR', '+380', 'UTC+03:00', 'Ukrainian hryvnia']
# ['United Arab Emirates', 'Abu Dhabi', 'AE', 'ARE', '+971', 'UTC+04:00', 'United Arab Emirates dirham']
# ['United Kingdom', 'London', 'GB', 'GBR', '+44', 'UTC', 'British pound']
# ['United States', 'Washington D.C.', 'US', 'USA', '+1', 'UTC-11:00 - UTC-05:00', 'United States dollar']
# ['United States Minor Outlying Islands', '', 'UM', 'UMI', '+1', '', 'United States dollar']
# ['Uruguay', 'Montevideo', 'UY', 'URY', '+598', 'UTC-03:00', 'Uruguayan peso']
# ['Uzbekistan', 'Tashkent', 'UZ', 'UZB', '+998', 'UTC+06:00', 'Uzbekistani som']
# ['Vanuatu', 'Port Vila', 'VU', 'VUT', '+678', 'UTC+11:00', 'Vanuatu vatu']
# ['Vatican City', 'Vatican City', 'VA', 'VAT', '+39 06 698', 'UTC+01', 'Euro']
# ['Venezuela', 'Caracas', 'VE', 'VEN', '+58', 'UTC-04:00', 'Venezuelan bolÃ\xadvar']
# ['Vietnam', 'Hanoi', 'VN', 'VNM', '+84', 'UTC+07:00', 'Vietnamese Ä‘á»“ng']
# ['Virgin Islands', 'Road Town', 'VG', 'VGB', '+1 284', 'UTC-04', 'British Virgin Islands dollar']
# ['Virgin Islands of the United States', 'Charlotte Amalie', 'VI', 'VIR', '+1 340', 'UTC-04', 'United States dollar']
# ['Wallis and Futuna', 'Mata-Utu', 'WF', 'WLF', '+681', 'UTC+12:00', 'CFP franc']
# ['Western Sahara', 'LaÃ¢youne (El AaiÃºn)', 'EH', 'ESH', '+212 5288/5289', 'UTC+01', 'Moroccan dirham']
# ['Yemen', 'SanaÃ¡', 'YE', 'YEM', '+967', 'UTC+03:00', 'Yemeni rial']
# ['Zambia', 'Lusaka', 'ZM', 'ZMB', '+260', 'UTC+02:00', 'Zambian kwacha']
# ['Zimbabwe', ' Harare', 'ZW', 'ZWE', '+263', 'UTC+02:00', 'Zimbabwean dollar']

# %% [markdown]
# **You can store each column as a list variables, i.e. use the column names 'country', 'capital', 'ccode', 'ccode3', 'iac', 'timezone', 'currency'.**

# %%
with open(input_file) as countries:
    for row in countries:
        data = row.strip().split('|')
        country, capital, ccode, ccode3, iac, timezone, currency = data
        print(country, capital, ccode, ccode3, iac, timezone, currency, sep='\n\t')
# Out:
# Country
# 	Capital
# 	CC
# 	CC3
# 	IAC
# 	TimeZone
# 	Currency
# Afghanistan
# 	Kabul
# 	AF
# 	AFG
# 	+93
# 	UTC+04:30
# 	Afghan afghani
# Aland Islands
# 	Mariehamn
# 	AX
# 	ALA
# 	+358
# 	UTC+02:00
# 	Euro
# Albania
# 	Tirana
# 	AL
# 	ALB
# 	+355
# 	UTC+01:00
# 	Albanian lek
# Algeria
# 	Algiers
# 	DZ
# 	DZA
# 	+213
# 	UTC
# 	Algerian dinar
# American Samoa
# 	Pago Pago
# 	AS
# 	ASM
# 	+1 684
# 	UTC-11:00
#
# Andorra
# 	Andorra la Vella
# 	AD
# 	AND
# 	+376
# 	UTC+01:00
# 	Euro
# Angola
# 	Luanda
# 	AO
# 	AGO
# 	+244
# 	UTC+01:00
# 	Angolan kwanza
# Anguilla
# 	The Valley
# 	AI
# 	AIA
# 	+1 264
# 	UTC-04:00
# 	British Virgin Islands dollar
# Virgin Islands of the United States
# 	Charlotte Amalie
# 	VI
# 	VIR
# 	+1 340
# 	UTC-04
# 	United States dollar
# Wallis and Futuna
# 	Mata-Utu
# 	WF
# 	WLF
# 	+681
# 	UTC+12:00
# 	CFP franc
# Western Sahara
# 	LaÃ¢youne (El AaiÃºn)
# 	EH
# 	ESH
# 	+212 5288/5289
# 	UTC+01
# 	Moroccan dirham
# Yemen
# 	SanaÃ¡
# 	YE
# 	YEM
# 	+967
# 	UTC+03:00
# 	Yemeni rial
# Zambia
# 	Lusaka
# 	ZM
# 	ZMB
# 	+260
# 	UTC+02:00
# 	Zambian kwacha
# Zimbabwe
# 	 Harare
# 	ZW
# 	ZWE
# 	+263
# 	UTC+02:00
# 	Zimbabwean dollar

# %% [markdown]
# **You can print each row of data as values in a dictionary, within the loop. You can see how it is formatted in a dictionary.**

# %%
with open(input_file) as countries:
    countries.readline()
    for row in countries:
        data = row.strip().split('|')
        country, capital, ccode, ccode3, iac, timezone, currency = data
        country_dict = {
            'country': country, 
            'capital': capital,
            'ccode': ccode,
            'ccode3': ccode3, 
            'dial_code': iac, 
            'timezone': timezone,
            'currency': currency
        }
        print(country_dict)
# Out:
# {'country': 'Afghanistan', 'capital': 'Kabul', 'ccode': 'AF', 'ccode3': 'AFG', 'dial_code': '+93', 'timezone': 'UTC+04:30', 'currency': 'Afghan afghani'}
# {'country': 'Aland Islands', 'capital': 'Mariehamn', 'ccode': 'AX', 'ccode3': 'ALA', 'dial_code': '+358', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'country': 'Albania', 'capital': 'Tirana', 'ccode': 'AL', 'ccode3': 'ALB', 'dial_code': '+355', 'timezone': 'UTC+01:00', 'currency': 'Albanian lek'}
# {'country': 'Algeria', 'capital': 'Algiers', 'ccode': 'DZ', 'ccode3': 'DZA', 'dial_code': '+213', 'timezone': 'UTC', 'currency': 'Algerian dinar'}
# {'country': 'American Samoa', 'capital': 'Pago Pago', 'ccode': 'AS', 'ccode3': 'ASM', 'dial_code': '+1 684', 'timezone': 'UTC-11:00', 'currency': ''}
# {'country': 'Andorra', 'capital': 'Andorra la Vella', 'ccode': 'AD', 'ccode3': 'AND', 'dial_code': '+376', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Angola', 'capital': 'Luanda', 'ccode': 'AO', 'ccode3': 'AGO', 'dial_code': '+244', 'timezone': 'UTC+01:00', 'currency': 'Angolan kwanza'}
# {'country': 'Anguilla', 'capital': 'The Valley', 'ccode': 'AI', 'ccode3': 'AIA', 'dial_code': '+1 264', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Antarctica', 'capital': '', 'ccode': 'AQ', 'ccode3': 'ATA', 'dial_code': '', 'timezone': '', 'currency': ''}
# {'country': 'Antigua and Barbuda', 'capital': "St. John's", 'ccode': 'AG', 'ccode3': 'ATG', 'dial_code': '+1 268', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Argentina', 'capital': 'Buenos Aires', 'ccode': 'AR', 'ccode3': 'ARG', 'dial_code': '+54', 'timezone': 'UTC-03:00', 'currency': 'Argentine peso'}
# {'country': 'Armenia', 'capital': 'Yerevan', 'ccode': 'AM', 'ccode3': 'ARM', 'dial_code': '+374', 'timezone': 'UTC+04:00', 'currency': 'Armenian dram'}
# {'country': 'Aruba', 'capital': 'Oranjestad', 'ccode': 'AW', 'ccode3': 'ABW', 'dial_code': '+297', 'timezone': 'UTC-04:00', 'currency': 'Aruban florin'}
# {'country': 'Australia', 'capital': 'Canberra', 'ccode': 'AU', 'ccode3': 'AUS', 'dial_code': '+61', 'timezone': 'UTC+07:00 - UTC+10:00', 'currency': 'Australian dollar'}
# {'country': 'Austria', 'capital': 'Vienna', 'ccode': 'AT', 'ccode3': 'AUT', 'dial_code': '+43', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Azerbaijan', 'capital': 'Baku', 'ccode': 'AZ', 'ccode3': 'AZE', 'dial_code': '+994', 'timezone': 'UTC+04:00', 'currency': 'Azerbaijani manat'}
# {'country': 'Bahamas', 'capital': 'Nassau', 'ccode': 'BS', 'ccode3': 'BHS', 'dial_code': '+1 242', 'timezone': 'UTC-05:00', 'currency': 'Bahamian dollar'}
# {'country': 'Bahrain', 'capital': 'Manama', 'ccode': 'BH', 'ccode3': 'BHR', 'dial_code': '+973', 'timezone': 'UTC+03:00', 'currency': 'Bahraini dinar'}
# {'country': 'Bangladesh', 'capital': 'Dhaka', 'ccode': 'BD', 'ccode3': 'BGD', 'dial_code': '+880', 'timezone': 'UTC+06:00', 'currency': 'Bangladeshi taka'}
# {'country': 'Barbados', 'capital': 'Bridgetown', 'ccode': 'BB', 'ccode3': 'BRB', 'dial_code': '+1 246', 'timezone': 'UTC-04:00', 'currency': 'Barbadian dollar'}
# {'country': 'Belarus', 'capital': 'Minsk', 'ccode': 'BY', 'ccode3': 'BLR', 'dial_code': '+375', 'timezone': 'UTC+03:00', 'currency': 'Belarusian ruble'}
# {'country': 'Belgium', 'capital': 'Brussels', 'ccode': 'BE', 'ccode3': 'BEL', 'dial_code': '+32', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Belize', 'capital': 'Belmopan', 'ccode': 'BZ', 'ccode3': 'BLZ', 'dial_code': '+501', 'timezone': 'UTC-06:00', 'currency': 'Belize dollar'}
# {'country': 'Benin', 'capital': 'Porto-Novo', 'ccode': 'BJ', 'ccode3': 'BEN', 'dial_code': '+229', 'timezone': 'UTC+01:00', 'currency': 'West African CFA franc'}
# {'country': 'Bermuda', 'capital': 'Hamilton', 'ccode': 'BM', 'ccode3': 'BMU', 'dial_code': '+1 441', 'timezone': 'UTC-04:00', 'currency': 'Bermudian dollar'}
# {'country': 'Bhutan', 'capital': 'Thimphu', 'ccode': 'BT', 'ccode3': 'BTN', 'dial_code': '+975', 'timezone': 'UTC+05:30', 'currency': 'Bhutanese ngultrum'}
# {'country': 'Bolivia', 'capital': 'Sucre', 'ccode': 'BO', 'ccode3': 'BOL', 'dial_code': '+591', 'timezone': 'UTC-04:00', 'currency': 'Bolivian boliviano'}
# {'country': 'Bonaire', 'capital': 'Kralendijk', 'ccode': 'BQ', 'ccode3': 'BES', 'dial_code': '+599', 'timezone': 'UTC-04:00', 'currency': 'United States dollar'}
# {'country': 'Bosnia and Herzegovina', 'capital': 'Sarajevo', 'ccode': 'BA', 'ccode3': 'BIH', 'dial_code': '+387', 'timezone': 'UTC+01:00', 'currency': 'Bosnia and Herzegovina convertible mark'}
# {'country': 'Botswana', 'capital': 'Gaborone', 'ccode': 'BW', 'ccode3': 'BWA', 'dial_code': '+267', 'timezone': 'UTC+02:00', 'currency': 'Botswana pula'}
# {'country': 'Bouvet Island', 'capital': '', 'ccode': 'BV', 'ccode3': 'BVT', 'dial_code': '', 'timezone': 'UTC+01:00', 'currency': ''}
# {'country': 'Brazil', 'capital': 'BrasÃ\xadlia', 'ccode': 'BR', 'ccode3': 'BRA', 'dial_code': '+55', 'timezone': 'UTC-05:00 - UTC-03:00', 'currency': 'Brazilian real'}
# {'country': 'British Indian Ocean Territory', 'capital': 'Diego Garcia', 'ccode': 'IO', 'ccode3': 'IOT', 'dial_code': '+246', 'timezone': 'UTC+06', 'currency': 'United States dollar'}
# {'country': 'Brunei', 'capital': 'Bandar Seri Begawan', 'ccode': 'BN', 'ccode3': 'BRN', 'dial_code': '+673', 'timezone': 'UTC+08:00', 'currency': 'Brunei dollar'}
# {'country': 'Bulgaria', 'capital': 'Sofia', 'ccode': 'BG', 'ccode3': 'BGR', 'dial_code': '+359', 'timezone': 'UTC+02:00', 'currency': 'Bulgarian lev'}
# {'country': 'Burkina Faso', 'capital': 'Ouagadougou', 'ccode': 'BF', 'ccode3': 'BFA', 'dial_code': '+226', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Burundi', 'capital': 'Bujumbura', 'ccode': 'BI', 'ccode3': 'BDI', 'dial_code': '+257', 'timezone': 'UTC+02:00', 'currency': 'Burundian franc'}
# {'country': 'Cambodia', 'capital': 'Phnom Penh', 'ccode': 'KH', 'ccode3': 'KHM', 'dial_code': '+855', 'timezone': 'UTC+07:00', 'currency': 'Cambodian riel'}
# {'country': 'Cameroon', 'capital': 'YaoundÃ©', 'ccode': 'CM', 'ccode3': 'CMR', 'dial_code': '+237', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Canada', 'capital': 'Ottawa', 'ccode': 'CA', 'ccode3': 'CAN', 'dial_code': '+1', 'timezone': 'UTC-08:00 - UTC-04:00', 'currency': 'Canadian dollar'}
# {'country': 'Cape Verde', 'capital': 'Praia', 'ccode': 'CV', 'ccode3': 'CPV', 'dial_code': '+238', 'timezone': 'UTC-01:00', 'currency': 'Cape Verdean escudo'}
# {'country': 'Cayman Islands', 'capital': 'George Town', 'ccode': 'KY', 'ccode3': 'CYM', 'dial_code': '+1 345', 'timezone': 'UTC-05:00', 'currency': 'Cayman Islands dollar'}
# {'country': 'Central African Republic', 'capital': 'Bangui', 'ccode': 'CF', 'ccode3': 'CAF', 'dial_code': '+236', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Chad', 'capital': "N'Djamena", 'ccode': 'TD', 'ccode3': 'TCD', 'dial_code': '+235', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Chile', 'capital': 'Santiago', 'ccode': 'CL', 'ccode3': 'CHL', 'dial_code': '+56', 'timezone': 'UTC-04:00', 'currency': 'Chilean peso'}
# {'country': 'China', 'capital': 'Beijing', 'ccode': 'CN', 'ccode3': 'CHN', 'dial_code': '+86', 'timezone': 'UTC+08:00', 'currency': 'Chinese yuan'}
# {'country': 'Christmas Island', 'capital': 'Flying Fish Cove', 'ccode': 'CX', 'ccode3': 'CXR', 'dial_code': '+61 8 9164', 'timezone': 'UTC+07', 'currency': 'Australian dollar'}
# {'country': 'Cocos (Keeling) Islands', 'capital': 'West Island', 'ccode': 'CC', 'ccode3': 'CCK', 'dial_code': '+61 8 9162', 'timezone': 'UTC+06:30', 'currency': 'Australian dollar'}
# {'country': 'Colombia', 'capital': 'BogotÃ¡', 'ccode': 'CO', 'ccode3': 'COL', 'dial_code': '+57', 'timezone': 'UTC-05:00', 'currency': 'Colombian peso'}
# {'country': 'Comoros', 'capital': 'Moroni', 'ccode': 'KM', 'ccode3': 'COM', 'dial_code': '+269', 'timezone': 'UTC+03:00', 'currency': 'Comorian franc'}
# {'country': 'Congo, Republic of the', 'capital': 'Brazzaville', 'ccode': 'CG', 'ccode3': 'COG', 'dial_code': '+242', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Congo, Democratic Republic of the', 'capital': 'Kinshasa', 'ccode': 'CD', 'ccode3': 'COD', 'dial_code': '+243', 'timezone': 'UTC+01:00 - UTC+02:00', 'currency': 'Congolese franc'}
# {'country': 'Cook Islands', 'capital': 'Avarua', 'ccode': 'CK', 'ccode3': 'COK', 'dial_code': '+682', 'timezone': 'UTC-10:00', 'currency': 'New Zealand dollar'}
# {'country': 'Costa Rica', 'capital': 'San JosÃ©', 'ccode': 'CR', 'ccode3': 'CRI', 'dial_code': '+506', 'timezone': 'UTC-06:00', 'currency': 'Costa Rican colÃ³n'}
# {'country': "CÃ´te d'Ivoire", 'capital': 'Yamoussoukro', 'ccode': 'CI', 'ccode3': 'CIV', 'dial_code': '+225', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Croatia', 'capital': 'Zagreb', 'ccode': 'HR', 'ccode3': 'HRV', 'dial_code': '+385', 'timezone': 'UTC+01:00', 'currency': 'Croatian kuna'}
# {'country': 'Cuba', 'capital': 'Havana', 'ccode': 'CU', 'ccode3': 'CUB', 'dial_code': '+53', 'timezone': 'UTC-03:00', 'currency': 'Cuban convertible peso'}
# {'country': 'Curacao', 'capital': 'Willemstad', 'ccode': 'CW', 'ccode3': 'CUW', 'dial_code': '+599 9', 'timezone': 'UTC-04:00', 'currency': 'Netherlands Antillean guilder'}
# {'country': 'Cyprus', 'capital': 'Nicosia', 'ccode': 'CY', 'ccode3': 'CYP', 'dial_code': '+357', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'country': 'Czech Republic', 'capital': 'Prague', 'ccode': 'CZ', 'ccode3': 'CZE', 'dial_code': '+420', 'timezone': 'UTC+01:00', 'currency': 'Czech koruna'}
# {'country': 'Denmark', 'capital': 'Copenhagen', 'ccode': 'DK', 'ccode3': 'DNK', 'dial_code': '+45', 'timezone': 'UTC+01:00', 'currency': 'Danish krone'}
# {'country': 'Djibouti', 'capital': 'Djibouti', 'ccode': 'DJ', 'ccode3': 'DJI', 'dial_code': '+253', 'timezone': 'UTC+03:00', 'currency': 'Djiboutian franc'}
# {'country': 'Dominica', 'capital': 'Roseau', 'ccode': 'DM', 'ccode3': 'DMA', 'dial_code': '+1 767', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Dominican Republic', 'capital': 'Santo Domingo', 'ccode': 'DO', 'ccode3': 'DOM', 'dial_code': '+1 809/829/849', 'timezone': 'UTC-04:00', 'currency': 'Dominican peso'}
# {'country': 'East Timor', 'capital': 'Dili', 'ccode': 'TL', 'ccode3': 'TLS', 'dial_code': '+670', 'timezone': 'UTC+09', 'currency': 'United States dollar'}
# {'country': 'Ecuador', 'capital': 'Quito', 'ccode': 'EC', 'ccode3': 'ECU', 'dial_code': '+593', 'timezone': 'UTC-05:00', 'currency': 'United States dollar'}
# {'country': 'Egypt', 'capital': 'Cairo', 'ccode': 'EG', 'ccode3': 'EGY', 'dial_code': '+20', 'timezone': 'UTC+02:00', 'currency': 'Egyptian pound'}
# {'country': 'El Salvador', 'capital': 'San Salvador', 'ccode': 'SV', 'ccode3': 'SLV', 'dial_code': '+503', 'timezone': 'UTC-06:00', 'currency': 'Salvadoran colÃ³n'}
# {'country': 'Equatorial Guinea', 'capital': 'Malabo', 'ccode': 'GQ', 'ccode3': 'GNQ', 'dial_code': '+240', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Eritrea', 'capital': 'Asmara', 'ccode': 'ER', 'ccode3': 'ERI', 'dial_code': '+291', 'timezone': 'UTC+03:00', 'currency': 'Eritrean nakfa'}
# {'country': 'Estonia', 'capital': 'Tallinn', 'ccode': 'EE', 'ccode3': 'EST', 'dial_code': '+372', 'timezone': 'UTC+03:00', 'currency': 'Euro'}
# {'country': 'Ethiopia', 'capital': 'Addis Ababa', 'ccode': 'ET', 'ccode3': 'ETH', 'dial_code': '+251', 'timezone': 'UTC+03:00', 'currency': 'Ethiopian birr'}
# {'country': 'Falkland Islands (Malvinas)', 'capital': 'Stanley', 'ccode': 'FK', 'ccode3': 'FLK', 'dial_code': '+500', 'timezone': 'UTC-04:00', 'currency': 'Falkland Islands pound'}
# {'country': 'Faroe Islands', 'capital': 'TÃ³rshavn', 'ccode': 'FO', 'ccode3': 'FRO', 'dial_code': '+298', 'timezone': 'UTC', 'currency': 'Danish krone'}
# {'country': 'Fiji', 'capital': 'Suva', 'ccode': 'FJ', 'ccode3': 'FJI', 'dial_code': '+679', 'timezone': 'UTC+12:00', 'currency': 'Fijian dollar'}
# {'country': 'Finland', 'capital': 'Helsinki', 'ccode': 'FI', 'ccode3': 'FIN', 'dial_code': '+358', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'country': 'France', 'capital': 'Paris', 'ccode': 'FR', 'ccode3': 'FRA', 'dial_code': '+33', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'French Guiana', 'capital': 'Cayenne', 'ccode': 'GF', 'ccode3': 'GUF', 'dial_code': '+594', 'timezone': 'UTC-01:00', 'currency': 'Euro'}
# {'country': 'French Polynesia', 'capital': 'Papeete', 'ccode': 'PF', 'ccode3': 'PYF', 'dial_code': '+689', 'timezone': 'UTC-10:00', 'currency': 'CFP franc'}
# {'country': 'French Southern Territories', 'capital': 'Port-aux-FranÃ§ais', 'ccode': 'TF', 'ccode3': 'ATF', 'dial_code': '', 'timezone': 'UTC+05:00', 'currency': 'Euro'}
# {'country': 'Gabon', 'capital': 'Libreville', 'ccode': 'GA', 'ccode3': 'GAB', 'dial_code': '+241', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Gambia', 'capital': 'Banjul', 'ccode': 'GM', 'ccode3': 'GMB', 'dial_code': '+220', 'timezone': 'UTC', 'currency': 'Gambian dalasi'}
# {'country': 'Georgia', 'capital': 'Tbilisi', 'ccode': 'GE', 'ccode3': 'GEO', 'dial_code': '+995', 'timezone': 'UTC+04:00', 'currency': 'Georgian lari'}
# {'country': 'Germany', 'capital': 'Berlin', 'ccode': 'DE', 'ccode3': 'DEU', 'dial_code': '+49', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Ghana', 'capital': 'Accra', 'ccode': 'GH', 'ccode3': 'GHA', 'dial_code': '+233', 'timezone': 'UTC', 'currency': 'Ghanaian cedi'}
# {'country': 'Gibraltar', 'capital': 'Gibraltar', 'ccode': 'GI', 'ccode3': 'GIB', 'dial_code': '+350', 'timezone': 'UTC+01:00', 'currency': 'Gibraltar pound'}
# {'country': 'Greece', 'capital': 'Athens', 'ccode': 'GR', 'ccode3': 'GRC', 'dial_code': '+30', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'country': 'Greenland', 'capital': 'Nuuk', 'ccode': 'GL', 'ccode3': 'GRL', 'dial_code': '+299', 'timezone': 'UTC-03:00', 'currency': 'Danish krone'}
# {'country': 'Grenada', 'capital': "St. George's", 'ccode': 'GD', 'ccode3': 'GRD', 'dial_code': '+1 473', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Guadeloupe', 'capital': 'Basse-Terre', 'ccode': 'GP', 'ccode3': 'GLP', 'dial_code': '+590', 'timezone': 'UTC-04:00', 'currency': 'Euro'}
# {'country': 'Guam', 'capital': 'HagÃ¥tÃ±a', 'ccode': 'GU', 'ccode3': 'GUM', 'dial_code': '+1 671', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'country': 'Guatemala', 'capital': 'Guatemala City', 'ccode': 'GT', 'ccode3': 'GTM', 'dial_code': '+502', 'timezone': 'UTC-06:00', 'currency': 'Guatemalan quetzal'}
# {'country': 'Guernsey', 'capital': 'St. Peter Port', 'ccode': 'GG', 'ccode3': 'GGY', 'dial_code': '+44 1481', 'timezone': 'UTC', 'currency': 'British pound'}
# {'country': 'Guinea', 'capital': 'Conakry', 'ccode': 'GN', 'ccode3': 'GIN', 'dial_code': '+224', 'timezone': 'UTC', 'currency': 'Guinean franc'}
# {'country': 'Guinea-Bissau', 'capital': 'Bissau', 'ccode': 'GW', 'ccode3': 'GNB', 'dial_code': '+245', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Guyana', 'capital': 'Georgetown', 'ccode': 'GY', 'ccode3': 'GUY', 'dial_code': '+592', 'timezone': 'UTC-03:00', 'currency': 'Guyanese dollar'}
# {'country': 'Haiti', 'capital': 'Port-au-Prince', 'ccode': 'HT', 'ccode3': 'HTI', 'dial_code': '+509', 'timezone': 'UTC-05:00', 'currency': 'Haitian gourde'}
# {'country': 'Heard Island and McDonald Islands', 'capital': '', 'ccode': 'HM', 'ccode3': 'HMD', 'dial_code': '', 'timezone': 'UTC+05', 'currency': ''}
# {'country': 'Honduras', 'capital': 'Tegucigalpa', 'ccode': 'HN', 'ccode3': 'HND', 'dial_code': '+504', 'timezone': 'UTC-06:00', 'currency': 'Honduran lempira'}
# {'country': 'Hong Kong', 'capital': '', 'ccode': 'HK', 'ccode3': 'HKG', 'dial_code': '+852', 'timezone': 'UTC+08:00', 'currency': 'Hong Kong dollar'}
# {'country': 'Hungary', 'capital': 'Budapest', 'ccode': 'HU', 'ccode3': 'HUN', 'dial_code': '+36', 'timezone': 'UTC+01:00', 'currency': 'Hungarian forint'}
# {'country': 'Iceland', 'capital': 'ReykjavÃ\xadk', 'ccode': 'IS', 'ccode3': 'ISL', 'dial_code': '+354', 'timezone': 'UTC', 'currency': 'Icelandic krÃ³na'}
# {'country': 'India', 'capital': 'New Delhi', 'ccode': 'IN', 'ccode3': 'IND', 'dial_code': '+91', 'timezone': 'UTC+05:30', 'currency': 'Indian rupee'}
# {'country': 'Indonesia', 'capital': 'Jakarta', 'ccode': 'ID', 'ccode3': 'IDN', 'dial_code': '+62', 'timezone': 'UTC+07:00 - UTC+09:00', 'currency': 'Indonesian rupiah'}
# {'country': 'Iran', 'capital': 'Tehran', 'ccode': 'IR', 'ccode3': 'IRN', 'dial_code': '+98', 'timezone': 'UTC+03:30', 'currency': 'Iranian rial'}
# {'country': 'Iraq', 'capital': 'Baghdad', 'ccode': 'IQ', 'ccode3': 'IRQ', 'dial_code': '+964', 'timezone': 'UTC+03:00', 'currency': 'Iraqi dinar'}
# {'country': 'Ireland', 'capital': 'Dublin', 'ccode': 'IE', 'ccode3': 'IRL', 'dial_code': '+353', 'timezone': 'UTC', 'currency': 'Euro'}
# {'country': 'Isle of Man', 'capital': 'Douglas', 'ccode': 'IM', 'ccode3': 'IMN', 'dial_code': '+44 1624', 'timezone': 'UTC', 'currency': 'British pound'}
# {'country': 'Israel', 'capital': 'Jerusalem', 'ccode': 'IL', 'ccode3': 'ISR', 'dial_code': '+972', 'timezone': 'UTC+02:00', 'currency': 'Israeli new shekel'}
# {'country': 'Italy', 'capital': 'Rome', 'ccode': 'IT', 'ccode3': 'ITA', 'dial_code': '+39', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Jamaica', 'capital': 'Kingston', 'ccode': 'JM', 'ccode3': 'JAM', 'dial_code': '+1 876', 'timezone': 'UTC-05:00', 'currency': 'Jamaican dollar'}
# {'country': 'Japan', 'capital': 'Tokyo', 'ccode': 'JP', 'ccode3': 'JPN', 'dial_code': '+81', 'timezone': 'UTC+09:00', 'currency': 'Japanese yen'}
# {'country': 'Jersey', 'capital': 'St. Helier', 'ccode': 'JE', 'ccode3': 'JEY', 'dial_code': '+44 1534', 'timezone': 'UTC', 'currency': 'British pound'}
# {'country': 'Jordan', 'capital': 'Amman', 'ccode': 'JO', 'ccode3': 'JOR', 'dial_code': '+962', 'timezone': 'UTC+02:00', 'currency': 'Jordanian dinar'}
# {'country': 'Kazakhstan', 'capital': 'Astana', 'ccode': 'KZ', 'ccode3': 'KAZ', 'dial_code': '+7 6xx/7xx', 'timezone': 'UTC+06:00', 'currency': 'Kazakhstani tenge'}
# {'country': 'Kenya', 'capital': 'Nairobi', 'ccode': 'KE', 'ccode3': 'KEN', 'dial_code': '+254', 'timezone': 'UTC+03:00', 'currency': 'Kenyan shilling'}
# {'country': 'Kiribati', 'capital': 'Tarawa', 'ccode': 'KI', 'ccode3': 'KIR', 'dial_code': '+686', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'country': 'Kuwait', 'capital': 'Kuwait City', 'ccode': 'KW', 'ccode3': 'KWT', 'dial_code': '+965', 'timezone': 'UTC+03:00', 'currency': 'Kuwaiti dinar'}
# {'country': 'Kyrgyzstan', 'capital': 'Bishkek', 'ccode': 'KG', 'ccode3': 'KGZ', 'dial_code': '+996', 'timezone': 'UTC+06:00', 'currency': 'Kyrgyzstani som'}
# {'country': 'Laos', 'capital': 'Vientiane', 'ccode': 'LA', 'ccode3': 'LAO', 'dial_code': '+856', 'timezone': 'UTC+07:00', 'currency': 'Lao kip'}
# {'country': 'Latvia', 'capital': 'Riga', 'ccode': 'LV', 'ccode3': 'LVA', 'dial_code': '+371', 'timezone': 'UTC+03:00', 'currency': 'Latvian lats'}
# {'country': 'Lebanon', 'capital': 'Beirut', 'ccode': 'LB', 'ccode3': 'LBN', 'dial_code': '+961', 'timezone': 'UTC+02:00', 'currency': 'Lebanese pound'}
# {'country': 'Lesotho', 'capital': 'Maseru', 'ccode': 'LS', 'ccode3': 'LSO', 'dial_code': '+266', 'timezone': 'UTC+02:00', 'currency': 'Lesotho loti'}
# {'country': 'Liberia', 'capital': 'Monrovia', 'ccode': 'LR', 'ccode3': 'LBR', 'dial_code': '+231', 'timezone': 'UTC', 'currency': 'Liberian dollar'}
# {'country': 'Libya', 'capital': 'Tripoli', 'ccode': 'LY', 'ccode3': 'LBY', 'dial_code': '+218', 'timezone': 'UTC+02:00', 'currency': 'Libyan dinar'}
# {'country': 'Liechtenstein', 'capital': 'Vaduz', 'ccode': 'LI', 'ccode3': 'LIE', 'dial_code': '+423', 'timezone': 'UTC+01:00', 'currency': 'Swiss franc'}
# {'country': 'Lithuania', 'capital': 'Vilnius', 'ccode': 'LT', 'ccode3': 'LTU', 'dial_code': '+370', 'timezone': 'UTC+02:00', 'currency': 'Lithuanian litas'}
# {'country': 'Luxembourg', 'capital': 'Luxembourg', 'ccode': 'LU', 'ccode3': 'LUX', 'dial_code': '+352', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Macau', 'capital': '', 'ccode': 'MO', 'ccode3': 'MAC', 'dial_code': '+853', 'timezone': 'UTC+08:00', 'currency': 'Macanese pataca'}
# {'country': 'Macedonia', 'capital': 'Skopje', 'ccode': 'MK', 'ccode3': 'MKD', 'dial_code': '+389', 'timezone': 'UTC+01:00', 'currency': 'Macedonian denar'}
# {'country': 'Madagascar', 'capital': 'Antananarivo', 'ccode': 'MG', 'ccode3': 'MDG', 'dial_code': '+261', 'timezone': 'UTC+03:00', 'currency': 'Malagasy ariary'}
# {'country': 'Malawi', 'capital': 'Lilongwe', 'ccode': 'MW', 'ccode3': 'MWI', 'dial_code': '+265', 'timezone': 'UTC+02:00', 'currency': 'Malawian kwacha'}
# {'country': 'Malaysia', 'capital': 'Kuala Lumpur', 'ccode': 'MY', 'ccode3': 'MYS', 'dial_code': '+60', 'timezone': 'UTC+08:00', 'currency': 'Malaysian ringgit'}
# {'country': 'Maldives', 'capital': 'MalÃ©', 'ccode': 'MV', 'ccode3': 'MDV', 'dial_code': '+960', 'timezone': 'UTC+05:00', 'currency': 'Maldivian rufiyaa'}
# {'country': 'Mali', 'capital': 'Bamako', 'ccode': 'ML', 'ccode3': 'MLI', 'dial_code': '+223', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Malta', 'capital': 'Valletta', 'ccode': 'MT', 'ccode3': 'MLT', 'dial_code': '+356', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Marshall Islands', 'capital': 'Majuro', 'ccode': 'MH', 'ccode3': 'MHL', 'dial_code': '+692', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'country': 'Martinique', 'capital': 'Fort-de-France', 'ccode': 'MQ', 'ccode3': 'MTQ', 'dial_code': '+596', 'timezone': 'UTC-04:00', 'currency': 'Euro'}
# {'country': 'Mauritania', 'capital': 'Nouakchott', 'ccode': 'MR', 'ccode3': 'MRT', 'dial_code': '+222', 'timezone': 'UTC', 'currency': 'Mauritanian ouguiya'}
# {'country': 'Mauritius', 'capital': 'Port Louis', 'ccode': 'MU', 'ccode3': 'MUS', 'dial_code': '+230', 'timezone': 'UTC+04:00', 'currency': 'Mauritian rupee'}
# {'country': 'Mayotte', 'capital': 'Mamoudzou', 'ccode': 'YT', 'ccode3': 'MYT', 'dial_code': '+262 269/639', 'timezone': 'UTC+03:00', 'currency': 'Euro'}
# {'country': 'Mexico', 'capital': 'Mexico City', 'ccode': 'MX', 'ccode3': 'MEX', 'dial_code': '+52', 'timezone': 'UTC-08:00 - UTC-06:00', 'currency': 'Mexican peso'}
# {'country': 'Micronesia', 'capital': 'Palikir', 'ccode': 'FM', 'ccode3': 'FSM', 'dial_code': '+691', 'timezone': 'UTC+10:00', 'currency': 'Micronesian dollar'}
# {'country': 'Moldova', 'capital': 'Chisinau', 'ccode': 'MD', 'ccode3': 'MDA', 'dial_code': '+373', 'timezone': 'UTC+03:00', 'currency': 'Moldovan leu'}
# {'country': 'Monaco', 'capital': 'Monaco', 'ccode': 'MC', 'ccode3': 'MCO', 'dial_code': '+377', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Mongolia', 'capital': 'Ulaanbaatar', 'ccode': 'MN', 'ccode3': 'MNG', 'dial_code': '+976', 'timezone': 'UTC+08:00', 'currency': 'Mongolian tÃ¶grÃ¶g'}
# {'country': 'Montenegro', 'capital': 'Podgorica', 'ccode': 'ME', 'ccode3': 'MNE', 'dial_code': '+382', 'timezone': 'UTC+01', 'currency': 'Euro'}
# {'country': 'Montserrat', 'capital': 'Plymouth', 'ccode': 'MS', 'ccode3': 'MSR', 'dial_code': '+1 664', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Morocco', 'capital': 'Rabat', 'ccode': 'MA', 'ccode3': 'MAR', 'dial_code': '+212', 'timezone': 'UTC', 'currency': 'Moroccan dirham'}
# {'country': 'Mozambique', 'capital': 'Maputo', 'ccode': 'MZ', 'ccode3': 'MOZ', 'dial_code': '+258', 'timezone': 'UTC+02:00', 'currency': 'Mozambican metical'}
# {'country': 'Myanmar (Burma)', 'capital': 'Naypyidaw', 'ccode': 'MM', 'ccode3': 'MMR', 'dial_code': '+95', 'timezone': 'UTC+06:30', 'currency': 'Myanma kyat'}
# {'country': 'Namibia', 'capital': 'Windhoek', 'ccode': 'NA', 'ccode3': 'NAM', 'dial_code': '+264', 'timezone': 'UTC+02:00', 'currency': 'Namibian dollar'}
# {'country': 'Nauru', 'capital': 'Yaren', 'ccode': 'NR', 'ccode3': 'NRU', 'dial_code': '+674', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'country': 'Nepal', 'capital': 'Kathmandu', 'ccode': 'NP', 'ccode3': 'NPL', 'dial_code': '+977', 'timezone': 'UTC+05:30', 'currency': 'Nepalese rupee'}
# {'country': 'Netherlands', 'capital': 'Amsterdam', 'ccode': 'NL', 'ccode3': 'NLD', 'dial_code': '+31', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'New Caledonia', 'capital': 'NoumÃ©a', 'ccode': 'NC', 'ccode3': 'NCL', 'dial_code': '+687', 'timezone': 'UTC+11:00', 'currency': 'CFP franc'}
# {'country': 'New Zealand', 'capital': 'Wellington', 'ccode': 'NZ', 'ccode3': 'NZL', 'dial_code': '+64', 'timezone': 'UTC+12:00', 'currency': 'New Zealand dollar'}
# {'country': 'Nicaragua', 'capital': 'Managua', 'ccode': 'NI', 'ccode3': 'NIC', 'dial_code': '+505', 'timezone': 'UTC-06:00', 'currency': 'Nicaraguan cÃ³rdoba'}
# {'country': 'Niger', 'capital': 'Niamey', 'ccode': 'NE', 'ccode3': 'NER', 'dial_code': '+227', 'timezone': 'UTC+01:00', 'currency': 'West African CFA franc'}
# {'country': 'Nigeria', 'capital': 'Abuja', 'ccode': 'NG', 'ccode3': 'NGA', 'dial_code': '+234', 'timezone': 'UTC+01:00', 'currency': 'Nigerian naira'}
# {'country': 'Niue', 'capital': 'Alofi', 'ccode': 'NU', 'ccode3': 'NIU', 'dial_code': '+683', 'timezone': 'UTC-11:00', 'currency': 'New Zealand dollar'}
# {'country': 'Norfolk Island', 'capital': 'Kingston', 'ccode': 'NF', 'ccode3': 'NFK', 'dial_code': '+672 3', 'timezone': 'UTC+11:30', 'currency': 'Australian dollar'}
# {'country': 'North Korea', 'capital': 'Pyongyang', 'ccode': 'KP', 'ccode3': 'PRK', 'dial_code': '+850', 'timezone': 'UTC+09:00', 'currency': 'North Korean won'}
# {'country': 'Northern Mariana Islands', 'capital': 'Saipan', 'ccode': 'MP', 'ccode3': 'MNP', 'dial_code': '+1 670', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'country': 'Norway', 'capital': 'Oslo', 'ccode': 'NO', 'ccode3': 'NOR', 'dial_code': '+47', 'timezone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'country': 'Oman', 'capital': 'Muscat', 'ccode': 'OM', 'ccode3': 'OMN', 'dial_code': '+968', 'timezone': 'UTC+04:00', 'currency': 'Omani rial'}
# {'country': 'Pakistan', 'capital': 'Islamabad', 'ccode': 'PK', 'ccode3': 'PAK', 'dial_code': '+92', 'timezone': 'UTC+05:00', 'currency': 'Pakistani rupee'}
# {'country': 'Palau', 'capital': 'Ngerulmud', 'ccode': 'PW', 'ccode3': 'PLW', 'dial_code': '+680', 'timezone': 'UTC+09:00', 'currency': 'Palauan dollar'}
# {'country': 'Panama', 'capital': 'Panama City', 'ccode': 'PA', 'ccode3': 'PAN', 'dial_code': '+507', 'timezone': 'UTC-05:00', 'currency': 'Panamanian balboa'}
# {'country': 'Papua New Guinea', 'capital': 'Port Moresby', 'ccode': 'PG', 'ccode3': 'PNG', 'dial_code': '+675', 'timezone': 'UTC+10:00', 'currency': 'Papua New Guinean kina'}
# {'country': 'Paraguay', 'capital': 'AsunciÃ³n', 'ccode': 'PY', 'ccode3': 'PRY', 'dial_code': '+595', 'timezone': 'UTC-04:00', 'currency': 'Paraguayan guaranÃ\xad'}
# {'country': 'Peru', 'capital': 'Lima', 'ccode': 'PE', 'ccode3': 'PER', 'dial_code': '+51', 'timezone': 'UTC-05:00', 'currency': 'Peruvian nuevo sol'}
# {'country': 'Philippines', 'capital': 'Manila', 'ccode': 'PH', 'ccode3': 'PHL', 'dial_code': '+63', 'timezone': 'UTC+08:00', 'currency': 'Philippine peso'}
# {'country': 'Pitcairn', 'capital': 'Adamstown', 'ccode': 'PN', 'ccode3': 'PCN', 'dial_code': '+872', 'timezone': 'UTC-08', 'currency': 'New Zealand dollar'}
# {'country': 'Poland', 'capital': 'Warsaw', 'ccode': 'PL', 'ccode3': 'POL', 'dial_code': '+48', 'timezone': 'UTC+01:00', 'currency': 'Polish zÅ‚oty'}
# {'country': 'Portugal', 'capital': 'Lisbon', 'ccode': 'PT', 'ccode3': 'PRT', 'dial_code': '+351', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Puerto Rico', 'capital': 'San Juan', 'ccode': 'PR', 'ccode3': 'PRI', 'dial_code': '+1 787/939', 'timezone': 'UTC-04:00', 'currency': 'United States dollar'}
# {'country': 'Qatar', 'capital': 'Doha', 'ccode': 'QA', 'ccode3': 'QAT', 'dial_code': '+974', 'timezone': 'UTC+03:00', 'currency': 'Qatari riyal'}
# {'country': 'Reunion', 'capital': '', 'ccode': 'RE', 'ccode3': 'REU', 'dial_code': '+262', 'timezone': 'UTC+04:00', 'currency': 'Euro'}
# {'country': 'Romania', 'capital': 'Bucharest', 'ccode': 'RO', 'ccode3': 'ROU', 'dial_code': '+40', 'timezone': 'UTC+02:00', 'currency': 'Romanian leu'}
# {'country': 'Russia', 'capital': 'Moscow', 'ccode': 'RU', 'ccode3': 'RUS', 'dial_code': '+7', 'timezone': 'UTC+03:00', 'currency': 'Russian ruble'}
# {'country': 'Rwanda', 'capital': 'Kigali', 'ccode': 'RW', 'ccode3': 'RWA', 'dial_code': '+250', 'timezone': 'UTC+02:00', 'currency': 'Rwandan franc'}
# {'country': 'Saint Barthelemy', 'capital': 'Gustavia', 'ccode': 'BL', 'ccode3': 'BLM', 'dial_code': '+590', 'timezone': 'UTC-04', 'currency': 'Euro'}
# {'country': 'Saint Helena', 'capital': 'Jamestown', 'ccode': 'SH', 'ccode3': 'SHN', 'dial_code': '+290', 'timezone': 'UTC', 'currency': 'Saint Helena pound'}
# {'country': 'Saint Kitts and Nevis', 'capital': 'Basseterre', 'ccode': 'KN', 'ccode3': 'KNA', 'dial_code': '+1 869', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Saint Lucia', 'capital': 'Castries', 'ccode': 'LC', 'ccode3': 'LCA', 'dial_code': '+1 758', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Saint Martin', 'capital': 'Marigot', 'ccode': 'MF', 'ccode3': 'MAF', 'dial_code': '+590', 'timezone': 'UTC-04', 'currency': 'Euro'}
# {'country': 'Saint Pierre and Miquelon', 'capital': 'St. Pierre', 'ccode': 'PM', 'ccode3': 'SPM', 'dial_code': '+508', 'timezone': 'UTC-03', 'currency': 'Euro'}
# {'country': 'Saint Vincent and the Grenadines', 'capital': 'Kingstown', 'ccode': 'VC', 'ccode3': 'VCT', 'dial_code': '+1 784', 'timezone': 'UTC-04', 'currency': 'East Caribbean dollar'}
# {'country': 'Samoa', 'capital': 'Apia', 'ccode': 'WS', 'ccode3': 'WSM', 'dial_code': '+685', 'timezone': 'UTC-11:00', 'currency': 'Samoan tala'}
# {'country': 'San Marino', 'capital': 'San Marino', 'ccode': 'SM', 'ccode3': 'SMR', 'dial_code': '+378', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Sao Tome and PrÃ\xadncipe', 'capital': 'SÃ£o TomÃ©', 'ccode': 'ST', 'ccode3': 'STP', 'dial_code': '+239', 'timezone': 'UTC', 'currency': 'SÃ£o TomÃ© and PrÃ\xadncipe dobra'}
# {'country': 'Saudi Arabia', 'capital': 'Riyadh', 'ccode': 'SA', 'ccode3': 'SAU', 'dial_code': '+966', 'timezone': 'UTC+03:00', 'currency': 'Saudi riyal'}
# {'country': 'Senegal', 'capital': 'Dakar', 'ccode': 'SN', 'ccode3': 'SEN', 'dial_code': '+221', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Serbia', 'capital': 'Belgrade', 'ccode': 'RS', 'ccode3': 'SRB', 'dial_code': '+381', 'timezone': 'UTC+01:00', 'currency': 'Serbian dinar'}
# {'country': 'Seychelles', 'capital': 'Victoria', 'ccode': 'SC', 'ccode3': 'SYC', 'dial_code': '+248', 'timezone': 'UTC+04:00', 'currency': 'Seychellois rupee'}
# {'country': 'Sierra Leone', 'capital': 'Freetown', 'ccode': 'SL', 'ccode3': 'SLE', 'dial_code': '+232', 'timezone': 'UTC', 'currency': 'Sierra Leonean leone'}
# {'country': 'Singapore', 'capital': 'Singapore', 'ccode': 'SG', 'ccode3': 'SGP', 'dial_code': '+65', 'timezone': 'UTC+08:00', 'currency': 'Brunei dollar'}
# {'country': 'Sint Maarten', 'capital': 'Philipsburg', 'ccode': 'SX', 'ccode3': 'SXM', 'dial_code': '+599 5', 'timezone': 'UTC-04:00', 'currency': 'Netherlands Antillean guilder'}
# {'country': 'Slovakia', 'capital': 'Bratislava', 'ccode': 'SK', 'ccode3': 'SVK', 'dial_code': '+421', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Slovenia', 'capital': 'Ljubljana', 'ccode': 'SI', 'ccode3': 'SVN', 'dial_code': '+386', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Solomon Islands', 'capital': 'Honiara', 'ccode': 'SB', 'ccode3': 'SLB', 'dial_code': '+677', 'timezone': 'UTC+11:00', 'currency': 'Solomon Islands dollar'}
# {'country': 'Somalia', 'capital': 'Mogadishu', 'ccode': 'SO', 'ccode3': 'SOM', 'dial_code': '+252', 'timezone': 'UTC+03:00', 'currency': 'Somali shilling'}
# {'country': 'South Africa', 'capital': 'Pretoria', 'ccode': 'ZA', 'ccode3': 'ZAF', 'dial_code': '+27', 'timezone': 'UTC+02:00', 'currency': 'South African rand'}
# {'country': 'South Georgia and the South Sandwich Islands', 'capital': 'Grytviken', 'ccode': 'GS', 'ccode3': 'SGS', 'dial_code': '', 'timezone': 'UTC-02', 'currency': 'British pound'}
# {'country': 'South Korea', 'capital': 'Seoul', 'ccode': 'KR', 'ccode3': 'KOR', 'dial_code': '+82', 'timezone': 'UTC+09:00', 'currency': 'South Korean won'}
# {'country': 'Spain', 'capital': 'Madrid', 'ccode': 'ES', 'ccode3': 'ESP', 'dial_code': '+34', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Sri Lanka', 'capital': 'Sri Jayawardenapura Kotte', 'ccode': 'LK', 'ccode3': 'LKA', 'dial_code': '+94', 'timezone': 'UTC+05:30', 'currency': 'Sri Lankan rupee'}
# {'country': 'Sudan', 'capital': 'Khartoum', 'ccode': 'SD', 'ccode3': 'SDN', 'dial_code': '+249', 'timezone': 'UTC+02:00', 'currency': 'Sudanese pound'}
# {'country': 'Suriname', 'capital': 'Paramaribo', 'ccode': 'SR', 'ccode3': 'SUR', 'dial_code': '+597', 'timezone': 'UTC-03:30', 'currency': 'Surinamese dollar'}
# {'country': 'Svalbard and Jan Mayen', 'capital': '', 'ccode': 'SJ', 'ccode3': 'SJM', 'dial_code': '+47', 'timezone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'country': 'Swaziland', 'capital': 'Mbabane', 'ccode': 'SZ', 'ccode3': 'SWZ', 'dial_code': '+268', 'timezone': 'UTC+02:00', 'currency': 'Swazi lilangeni'}
# {'country': 'Sweden', 'capital': 'Stockholm', 'ccode': 'SE', 'ccode3': 'SWE', 'dial_code': '+46', 'timezone': 'UTC+01:00', 'currency': 'Swedish krona'}
# {'country': 'Switzerland', 'capital': 'Bern', 'ccode': 'CH', 'ccode3': 'CHE', 'dial_code': '+41', 'timezone': 'UTC+01:00', 'currency': 'Swiss franc'}
# {'country': 'Syrian Arab Republic', 'capital': 'Damascus', 'ccode': 'SY', 'ccode3': 'SYR', 'dial_code': '+963', 'timezone': 'UTC+02:00', 'currency': 'Syrian pound'}
# {'country': 'Taiwan', 'capital': 'Taipei', 'ccode': 'TW', 'ccode3': 'TWN', 'dial_code': '+886', 'timezone': 'UTC+08:00', 'currency': 'New Taiwan dollar'}
# {'country': 'Tajikistan', 'capital': 'Dushanbe', 'ccode': 'TJ', 'ccode3': 'TJK', 'dial_code': '+992', 'timezone': 'UTC+06:00', 'currency': 'Tajikistani somoni'}
# {'country': 'Tanzania', 'capital': 'Dodoma', 'ccode': 'TZ', 'ccode3': 'TZA', 'dial_code': '+255', 'timezone': 'UTC+03:00', 'currency': 'Tanzanian shilling'}
# {'country': 'Thailand', 'capital': 'Bangkok', 'ccode': 'TH', 'ccode3': 'THA', 'dial_code': '+66', 'timezone': 'UTC+07:00', 'currency': 'Thai baht'}
# {'country': 'Togo', 'capital': 'LomÃ©', 'ccode': 'TG', 'ccode3': 'TGO', 'dial_code': '+228', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Tokelau', 'capital': 'Rotates annually', 'ccode': 'TK', 'ccode3': 'TKL', 'dial_code': '+690', 'timezone': 'UTC-10', 'currency': 'New Zealand dollar'}
# {'country': 'Tonga', 'capital': 'Nuku', 'ccode': 'TO', 'ccode3': 'TON', 'dial_code': '+676', 'timezone': 'UTC+13:00', 'currency': 'Tongan paÊ»anga'}
# {'country': 'Trinidad and Tobago', 'capital': 'Port of Spain', 'ccode': 'TT', 'ccode3': 'TTO', 'dial_code': '+1 868', 'timezone': 'UTC-04:00', 'currency': 'Trinidad and Tobago dollar'}
# {'country': 'Tunisia', 'capital': 'Tunis', 'ccode': 'TN', 'ccode3': 'TUN', 'dial_code': '+216', 'timezone': 'UTC+01:00', 'currency': 'Tunisian dinar'}
# {'country': 'Turkey', 'capital': 'Ankara', 'ccode': 'TR', 'ccode3': 'TUR', 'dial_code': '+90', 'timezone': 'UTC+02:00', 'currency': 'Turkish lira'}
# {'country': 'Turkmenistan', 'capital': 'Ashgabat', 'ccode': 'TM', 'ccode3': 'TKM', 'dial_code': '+993', 'timezone': 'UTC+05:00', 'currency': 'Turkmenistani manat'}
# {'country': 'Turks and Caicos Islands', 'capital': 'Cockburn Town', 'ccode': 'TC', 'ccode3': 'TCA', 'dial_code': '+1 649', 'timezone': 'UTC-05:00', 'currency': 'United States dollar'}
# {'country': 'Tuvalu', 'capital': 'Funafuti', 'ccode': 'TV', 'ccode3': 'TUV', 'dial_code': '+688', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'country': 'Uganda', 'capital': 'Kampala', 'ccode': 'UG', 'ccode3': 'UGA', 'dial_code': '+256', 'timezone': 'UTC+03:00', 'currency': 'Ugandan shilling'}
# {'country': 'Ukraine', 'capital': 'Kyiv', 'ccode': 'UA', 'ccode3': 'UKR', 'dial_code': '+380', 'timezone': 'UTC+03:00', 'currency': 'Ukrainian hryvnia'}
# {'country': 'United Arab Emirates', 'capital': 'Abu Dhabi', 'ccode': 'AE', 'ccode3': 'ARE', 'dial_code': '+971', 'timezone': 'UTC+04:00', 'currency': 'United Arab Emirates dirham'}
# {'country': 'United Kingdom', 'capital': 'London', 'ccode': 'GB', 'ccode3': 'GBR', 'dial_code': '+44', 'timezone': 'UTC', 'currency': 'British pound'}
# {'country': 'United States', 'capital': 'Washington D.C.', 'ccode': 'US', 'ccode3': 'USA', 'dial_code': '+1', 'timezone': 'UTC-11:00 - UTC-05:00', 'currency': 'United States dollar'}
# {'country': 'United States Minor Outlying Islands', 'capital': '', 'ccode': 'UM', 'ccode3': 'UMI', 'dial_code': '+1', 'timezone': '', 'currency': 'United States dollar'}
# {'country': 'Uruguay', 'capital': 'Montevideo', 'ccode': 'UY', 'ccode3': 'URY', 'dial_code': '+598', 'timezone': 'UTC-03:00', 'currency': 'Uruguayan peso'}
# {'country': 'Uzbekistan', 'capital': 'Tashkent', 'ccode': 'UZ', 'ccode3': 'UZB', 'dial_code': '+998', 'timezone': 'UTC+06:00', 'currency': 'Uzbekistani som'}
# {'country': 'Vanuatu', 'capital': 'Port Vila', 'ccode': 'VU', 'ccode3': 'VUT', 'dial_code': '+678', 'timezone': 'UTC+11:00', 'currency': 'Vanuatu vatu'}
# {'country': 'Vatican City', 'capital': 'Vatican City', 'ccode': 'VA', 'ccode3': 'VAT', 'dial_code': '+39 06 698', 'timezone': 'UTC+01', 'currency': 'Euro'}
# {'country': 'Venezuela', 'capital': 'Caracas', 'ccode': 'VE', 'ccode3': 'VEN', 'dial_code': '+58', 'timezone': 'UTC-04:00', 'currency': 'Venezuelan bolÃ\xadvar'}
# {'country': 'Vietnam', 'capital': 'Hanoi', 'ccode': 'VN', 'ccode3': 'VNM', 'dial_code': '+84', 'timezone': 'UTC+07:00', 'currency': 'Vietnamese Ä‘á»“ng'}
# {'country': 'Virgin Islands', 'capital': 'Road Town', 'ccode': 'VG', 'ccode3': 'VGB', 'dial_code': '+1 284', 'timezone': 'UTC-04', 'currency': 'British Virgin Islands dollar'}
# {'country': 'Virgin Islands of the United States', 'capital': 'Charlotte Amalie', 'ccode': 'VI', 'ccode3': 'VIR', 'dial_code': '+1 340', 'timezone': 'UTC-04', 'currency': 'United States dollar'}
# {'country': 'Wallis and Futuna', 'capital': 'Mata-Utu', 'ccode': 'WF', 'ccode3': 'WLF', 'dial_code': '+681', 'timezone': 'UTC+12:00', 'currency': 'CFP franc'}
# {'country': 'Western Sahara', 'capital': 'LaÃ¢youne (El AaiÃºn)', 'ccode': 'EH', 'ccode3': 'ESH', 'dial_code': '+212 5288/5289', 'timezone': 'UTC+01', 'currency': 'Moroccan dirham'}
# {'country': 'Yemen', 'capital': 'SanaÃ¡', 'ccode': 'YE', 'ccode3': 'YEM', 'dial_code': '+967', 'timezone': 'UTC+03:00', 'currency': 'Yemeni rial'}
# {'country': 'Zambia', 'capital': 'Lusaka', 'ccode': 'ZM', 'ccode3': 'ZMB', 'dial_code': '+260', 'timezone': 'UTC+02:00', 'currency': 'Zambian kwacha'}
# {'country': 'Zimbabwe', 'capital': ' Harare', 'ccode': 'ZW', 'ccode3': 'ZWE', 'dial_code': '+263', 'timezone': 'UTC+02:00', 'currency': 'Zimbabwean dollar'}

# %% [markdown]
# **You can put each of these dictionaries as values in another dictionary, using country name as the key.**

# %%
country_info_dict = {}

with open(input_file, encoding='utf-8') as countries:
    countries.readline()
    for row in countries:
        data = row.strip().split('|')
        country, capital, ccode, ccode3, iac, timezone, currency = data
        country_dict = {
            'country': country, 
            'capital': capital,
            'ccode': ccode,
            'ccode3': ccode3, 
            'dial_code': iac, 
            'timezone': timezone,
            'currency': currency
        }
        country_info_dict[country.casefold()] = country_dict

# %%
print(country_info_dict)
# Out:
# {'afghanistan': {'country': 'Afghanistan', 'capital': 'Kabul', 'ccode': 'AF', 'ccode3': 'AFG', 'dial_code': '+93', 'timezone': 'UTC+04:30', 'currency': 'Afghan afghani'}, 'aland islands': {'country': 'Aland Islands', 'capital': 'Mariehamn', 'ccode': 'AX', 'ccode3': 'ALA', 'dial_code': '+358', 'timezone': 'UTC+02:00', 'currency': 'Euro'}, 'albania': {'country': 'Albania', 'capital': 'Tirana', 'ccode': 'AL', 'ccode3': 'ALB', 'dial_code': '+355', 'timezone': 'UTC+01:00', 'currency': 'Albanian lek'}, 'algeria': {'country': 'Algeria', 'capital': 'Algiers', 'ccode': 'DZ', 'ccode3': 'DZA', 'dial_code': '+213', 'timezone': 'UTC', 'currency': 'Algerian dinar'}, 'american samoa': {'country': 'American Samoa', 'capital': 'Pago Pago', 'ccode': 'AS', 'ccode3': 'ASM', 'dial_code': '+1 684', 'timezone': 'UTC-11:00', 'currency': ''}, 'andorra': {'country': 'Andorra', 'capital': 'Andorra la Vella', 'ccode': 'AD', 'ccode3': 'AND', 'dial_code': '+376', 'timezone': 'UTC+01:00', 'currency': 'Euro'}, 'angola': {'country': 'Angola', 'capital': 'Luanda', 'ccode': 'AO', 'ccode3': 'AGO', 'dial_code': '+244', 'timezone': 'UTC+01:00', 'currency': 'Angolan kwanza'}, 'anguilla': {'country': 'Anguilla', 'capital': 'The Valley', 'ccode': 'AI', 'ccode3': 'AIA', 'dial_code': '+1 264', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}, 'antarctica': {'country': 'Antarctica', 'capital': '', 'ccode': 'AQ', 'ccode3': 'ATA', 'dial_code': '', 'timezone': '', 'currency': ''}, 'antigua and barbuda': {'country': 'Antigua and Barbuda', 'capital': "St. John's", 'ccode': 'AG', 'ccode3': 'ATG', 'dial_code': '+1 268', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}, 'argentina': {'country': 'Argentina', 'capital': 'Buenos Aires', 'ccode': 'AR', 'ccode3': 'ARG', 'dial_code': '+54', 'timezone': 'UTC-03:00', 'currency': 'Argentine peso'}, 'armenia': {'country': 'Armenia', 'capital': 'Yerevan', 'ccode': 'AM', 'ccode3': 'ARM', 'dial_code': '+374', 'timezone': 'UTC+04:00', 'currency': 'Armenian dram'}, 'aruba': {'country': 'Aruba', 'capital': 'Oranjestad', 'ccode': 'AW', 'ccode3': 'ABW', 'dial_code': '+297', 'timezone': 'UTC-04:00', 'currency': 'Aruban florin'}, 'australia': {'country': 'Australia', 'capital': 'Canberra', 'ccode': 'AU', 'ccode3': 'AUS', 'dial_code': '+61', 'timezone': 'UTC+07:00 - UTC+10:00', 'currency': 'Australian dollar'}, 'austria': {'country': 'Austria', 'capital': 'Vienna', 'ccode': 'AT', 'ccode3': 'AUT', 'dial_code': '+43', 'timezone': 'UTC+01:00', 'currency': 'Euro'}, 'azerbaijan': {'country': 'Azerbaijan', 'capital': 'Baku', 'ccode': 'AZ', 'ccode3': 'AZE', 'dial_code': '+994', 'timezone': 'UTC+04:00', 'currency': 'Azerbaijani manat'}, 'bahamas': {'country': 'Bahamas', 'capital': 'Nassau', 'ccode': 'BS', 'ccode3': 'BHS', 'dial_code': '+1 242', 'timezone': 'UTC-05:00', 'currency': 'Bahamian dollar'}, 'bahrain': {'country': 'Bahrain', 'capital': 'Manama', 'ccode': 'BH', 'ccode3': 'BHR', 'dial_code': '+973', 'timezone': 'UTC+03:00', 'currency': 'Bahraini dinar'}, 'bangladesh': {'country': 'Bangladesh', 'capital': 'Dhaka', 'ccode': 'BD', 'ccode3': 'BGD', 'dial_code': '+880', 'timezone': 'UTC+06:00', 'currency': 'Bangladeshi taka'}, 'barbados': {'country': 'Barbados', 'capital': 'Bridgetown', 'ccode': 'BB', 'ccode3': 'BRB', 'dial_code': '+1 246', 'timezone': 'UTC-04:00', 'currency': 'Barbadian dollar'}, 'belarus': {'country': 'Belarus', 'capital': 'Minsk', 'ccode': 'BY', 'ccode3': 'BLR', 'dial_code': '+375', 'timezone': 'UTC+03:00', 'currency': 'Belarusian ruble'}, 'belgium': {'country': 'Belgium', 'capital': 'Brussels', 'ccode': 'BE', 'ccode3': 'BEL', 'dial_code': '+32', 'timezone': 'UTC+01:00', 'currency': 'Euro'}, 'belize': {'country': 'Belize', 'capital': 'Belmopan', 'ccode': 'BZ', 'ccode3': 'BLZ', 'dial_code': '+501', 'timezone': 'UTC-06:00', 'currency': 'Belize dollar'}, 'benin': {'country': 'Benin', 'capital': 'Porto-Novo', 'ccode': 'BJ', 'ccode3': 'BEN', 'dial_code': '+229', 'timezone': 'UTC+01:00', 'currency': 'West African C ...

# %% [markdown]
# **Now you can extract and analyse data more easily, e.g. display the info for any country.**

# %%
print("Please enter country name")
country_name = input().casefold()
print()

while country_name:
    if country_name in country_info_dict:
        country_data = country_info_dict[country_name]
        for key, value in country_data.items():
            print(f"{key}: {value}")
    else:
        print("Country does not exist.")
    break
# Out:
# Please enter country name
# Yemen
#
# country: Yemen
# capital: Sanaá
# ccode: YE
# ccode3: YEM
# dial_code: +967
# timezone: UTC+03:00
# currency: Yemeni rial

# %%
# Enter 'quit' to exit program

while True:
    country_name = input("Enter country name ").casefold()
    if country_name in country_info_dict:
        country_data = country_info_dict[country_name]
        print(f"The capital of {country_data['country']} is {country_data['capital']}")
    elif country_name == 'quit':
        break
    elif country_name not in country_info_dict:
        print("Country does not exist. Try again ")
        country_name = input().casefold()
        country_data = country_info_dict[country_name]
        print(f"The capital of {country_data['country']} is {country_data['capital']}")
        print()
# Out:
# Enter country name Yeemeen
# Country does not exist. Try again
# Yemen
# The capital of Yemen is Sanaá
#
# Enter country name France
# The capital of France is Paris
# Enter country name Italy
# The capital of Italy is Rome
# Enter country name quit

# %% [markdown]
# **You can use the dictionary in other ways, e.g. look up country names given a country code. In this case, you need to access the nested dictionary values.**

# %%
country_code = input("Enter country code ").upper()

for dict_values in country_info_dict.values():
    for value in dict_values.values():
        if country_code in value:
            print(dict_values)
# Out:
# Enter country code sa
# {'country': 'Saudi Arabia', 'capital': 'Riyadh', 'ccode': 'SA', 'ccode3': 'SAU', 'dial_code': '+966', 'timezone': 'UTC+03:00', 'currency': 'Saudi riyal'}
# {'country': 'Saudi Arabia', 'capital': 'Riyadh', 'ccode': 'SA', 'ccode3': 'SAU', 'dial_code': '+966', 'timezone': 'UTC+03:00', 'currency': 'Saudi riyal'}
# {'country': 'United States', 'capital': 'Washington D.C.', 'ccode': 'US', 'ccode3': 'USA', 'dial_code': '+1', 'timezone': 'UTC-11:00 - UTC-05:00', 'currency': 'United States dollar'}

# %% [markdown]
# **List all the countries that do not have any capital cities, e.g. Antarctica. Note that two countries have no timezones (Antarctica and United States Minor Outlying Islands). This is because they are polar regions where all 24 timezones collide at a single point, rendering it meaningless.**

# %%
for dict_values in country_info_dict.values():
    if dict_values['capital'] == '':
        country_name = dict_values['country']
        country_timezone = dict_values['timezone']
        print(f"{country_name}\t ({country_timezone})")
# Out:
# Antarctica	 ()
# Bouvet Island	 (UTC+01:00)
# Heard Island and McDonald Islands	 (UTC+05)
# Hong Kong	 (UTC+08:00)
# Macau	 (UTC+08:00)
# Reunion	 (UTC+04:00)
# Svalbard and Jan Mayen	 (UTC+01:00)
# United States Minor Outlying Islands	 ()

# %%
for dict_values in country_info_dict.values():
    if dict_values['capital'] == '':
        print(dict_values)
# Out:
# {'country': 'Antarctica', 'capital': '', 'ccode': 'AQ', 'ccode3': 'ATA', 'dial_code': '', 'timezone': '', 'currency': ''}
# {'country': 'Bouvet Island', 'capital': '', 'ccode': 'BV', 'ccode3': 'BVT', 'dial_code': '', 'timezone': 'UTC+01:00', 'currency': ''}
# {'country': 'Heard Island and McDonald Islands', 'capital': '', 'ccode': 'HM', 'ccode3': 'HMD', 'dial_code': '', 'timezone': 'UTC+05', 'currency': ''}
# {'country': 'Hong Kong', 'capital': '', 'ccode': 'HK', 'ccode3': 'HKG', 'dial_code': '+852', 'timezone': 'UTC+08:00', 'currency': 'Hong Kong dollar'}
# {'country': 'Macau', 'capital': '', 'ccode': 'MO', 'ccode3': 'MAC', 'dial_code': '+853', 'timezone': 'UTC+08:00', 'currency': 'Macanese pataca'}
# {'country': 'Reunion', 'capital': '', 'ccode': 'RE', 'ccode3': 'REU', 'dial_code': '+262', 'timezone': 'UTC+04:00', 'currency': 'Euro'}
# {'country': 'Svalbard and Jan Mayen', 'capital': '', 'ccode': 'SJ', 'ccode3': 'SJM', 'dial_code': '+47', 'timezone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'country': 'United States Minor Outlying Islands', 'capital': '', 'ccode': 'UM', 'ccode3': 'UMI', 'dial_code': '+1', 'timezone': '', 'currency': 'United States dollar'}
