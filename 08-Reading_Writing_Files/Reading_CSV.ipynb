# %% [markdown]
# # Reading in CSV file
#
# **Even though CSV stands for Comma-Separated Values, the values can be separated by any plain text character, e.g. '|', '\t', '/' etc. Python `csv` module is built to handle different CSV formats.**
#
# **Using samples with different formats, read the data into Python format.**
#
# **Always open the file in Python editor before reading it in to see the format and number of values, or fields.**
#
#     Rank,Country,Gold,Silver,Bronze,Total
#     1,United States,39,41,33,113
#     2,China,38,32,18,88
#     3,Japan,27,14,17,58
#     ...

# %%
import csv

# %%
csv_file = 'data/OlympicMedals_2020.csv'

# %%
with open(csv_file, encoding='utf-8', newline='') as csv_data:
    reader = csv.reader(csv_data)
    for row in reader:
        print(row)
# Out:
# ['Rank', 'Country', 'Gold', 'Silver', 'Bronze', 'Total']
# ['1', 'United States', '39', '41', '33', '113']
# ['2', 'China', '38', '32', '18', '88']
# ['3', 'Japan', '27', '14', '17', '58']
# ['4', 'Great Britain', '22', '21', '22', '65']
# ['5', 'ROC', '20', '28', '23', '71']
# ['6', 'Australia', '17', '7', '22', '46']
# ['7', 'Netherlands', '10', '12', '14', '36']
# ['8', 'France', '10', '12', '11', '33']
# ['9', 'Germany', '10', '11', '16', '37']
# ['10', 'Italy', '10', '10', '20', '40']
# ['11', 'Canada', '7', '6', '11', '24']
# ['12', 'Brazil', '7', '6', '8', '21']
# ['13', 'New Zealand', '7', '6', '7', '20']
# ['14', 'Cuba', '7', '3', '5', '15']
# ['15', 'Hungary', '6', '7', '7', '20']
# ['16', 'South Korea', '6', '4', '10', '20']
# ['17', 'Poland', '4', '5', '5', '14']
# ['18', 'Czech Republic', '4', '4', '3', '11']
# ['19', 'Kenya', '4', '4', '2', '10']
# ['20', 'Norway', '4', '2', '2', '8']
# ['21', 'Jamaica', '4', '1', '4', '9']
# ['22', 'Spain', '3', '8', '6', '17']
# ['23', 'Sweden', '3', '6', '0', '9']
# ['24', 'Switzerland', '3', '4', '6', '13']
# ['25', 'Denmark', '3', '4', '4', '11']
# ['26', 'Croatia', '3', '3', '2', '8']
# ['27', 'Iran', '3', '2', '2', '7']
# ['28', 'Serbia', '3', '1', '5', '9']
# ['29', 'Belgium', '3', '1', '3', '7']
# ['30', 'Bulgaria', '3', '1', '2', '6']
# ['31', 'Slovenia', '3', '1', '1', '5']
# ['32', 'Uzbekistan', '3', '0', '2', '5']
# ['33', 'Georgia', '2', '5', '1', '8']
# ['34', 'Chinese Taipei', '2', '4', '6', '12']
# ['35', 'Turkey', '2', '2', '9', '13']
# ['36', 'Greece', '2', '1', '1', '4']
# ['36', 'Uganda', '2', '1', '1', '4']
# ['38', 'Ecuador', '2', '1', '0', '3']
# ['39', 'Ireland', '2', '0', '2', '4']
# ['39', 'Israel', '2', '0', '2', '4']
# ['41', 'Qatar', '2', '0', '1', '3']
# ['42', 'Bahamas', '2', '0', '0', '2']
# ['42', 'Kosovo', '2', '0', '0', '2']
# ['44', 'Ukraine', '1', '6', '12', '19']
# ['45', 'Belarus', '1', '3', '3', '7']
# ['46', 'Romania', '1', '3', '0', '4']
# ['46', 'Venezuela', '1', '3', '0', '4']
# ['48', 'India', '1', '2', '4', '7']
# ['49', 'Hong Kong', '1', '2', '3', '6']
# ['50', 'Philippines', '1', '2', '1', '4']
# ['50', 'Slovakia', '1', '2', '1', '4']
# ['52', 'South Africa', '1', '2', '0', '3']
# ['53', 'Austria', '1', '1', '5', '7']
# ['54', 'Egypt', '1', '1', '4', '6']
# ['55', 'Indonesia', '1', '1', '3', '5']
# ['56', 'Ethiopia', '1', '1', '2', '4']
# ['56', 'Portugal', '1', '1', '2', '4']
# ['58', 'Tunisia', '1', '1', '0', '2']
# ['59', 'Estonia', '1', '0', '1', '2']
# ['59', 'Fiji', '1', '0', '1', '2']
# ['59', 'Latvia', '1', '0', '1', '2']
# ['59', 'Thailand', '1', '0', '1', '2']
# ['63', 'Bermuda', '1', '0', '0', '1']
# ['63', 'Morocco', '1', '0', '0', '1']
# ['63', 'Puerto Rico', '1', '0', '0', '1']
# ['66', 'Colombia', '0', '4', '1', '5']
# ['67', 'Azerbaijan', '0', '3', '4', '7']
# ['68', 'Dominican Republic', '0', '3', '2', '5']
# ['69', 'Armenia', '0', '2', '2', '4']
# ['70', 'Kyrgyzstan', '0', '2', '1', '3']
# ['71', 'Mongolia', '0', '1', '3', '4']
# ['72', 'Argentina', '0', '1', '2', '3']
# ['72', 'San Marino', '0', '1', '2', '3']
# ['74', 'Jordan', '0', '1', '1', '2']
# ['74', 'Malaysia', '0', '1', '1', '2']
# ['74', 'Nigeria', '0', '1', '1', '2']
# ['77', 'Bahrain', '0', '1', '0', '1']
# ['77', 'Saudi Arabia', '0', '1', '0', '1']
# ['77', 'Lithuania', '0', '1', '0', '1']
# ['77', 'North Macedonia', '0', '1', '0', '1']
# ['77', 'Namibia', '0', '1', '0', '1']
# ['77', 'Turkmenistan', '0', '1', '0', '1']
# ['83', 'Kazakhstan', '0', '0', '8', '8']
# ['84', 'Mexico', '0', '0', '4', '4']
# ['85', 'Finland', '0', '0', '2', '2']
# ['86', 'Botswana', '0', '0', '1', '1']
# ['86', 'Burkina Faso', '0', '0', '1', '1']
# ['86', "Côte d'Ivoire", '0', '0', '1', '1']
# ['86', 'Ghana', '0', '0', '1', '1']
# ['86', 'Grenada', '0', '0', '1', '1']
# ['86', 'Kuwait', '0', '0', '1', '1']
# ['86', 'Moldova', '0', '0', '1', '1']
# ['86', 'Syria', '0', '0', '1', '1']

# %% [markdown]
# **Each row is contained in a list, showing the number of fields (6) and commas separating each field. The first row is almost always column headers for the fields, i.e. 'Rank', 'Country', 'Gold', 'Silver', 'Bronze' and 'Total'. Using CSV module, you can convert the data to dictionary using the headers as keys, with the corresponding values. You could also store the headers separately to then format the data in any way you want.**

# %%
with open(csv_file, encoding='utf-8', newline='') as csv_data:
    headers = csv_data.readline().strip('\n').split(',')
    print(f"Column headers are: {headers}")
    reader = csv.reader(csv_data)
    for row in reader:
        print(row)
# Out:
# Column headers are: ['Rank', 'Country', 'Gold', 'Silver', 'Bronze', 'Total']
# ['1', 'United States', '39', '41', '33', '113']
# ['2', 'China', '38', '32', '18', '88']
# ['3', 'Japan', '27', '14', '17', '58']
# ['4', 'Great Britain', '22', '21', '22', '65']
# ['5', 'ROC', '20', '28', '23', '71']
# ['6', 'Australia', '17', '7', '22', '46']
# ['7', 'Netherlands', '10', '12', '14', '36']
# ['8', 'France', '10', '12', '11', '33']
# ['9', 'Germany', '10', '11', '16', '37']
# ['10', 'Italy', '10', '10', '20', '40']
# ['11', 'Canada', '7', '6', '11', '24']
# ['12', 'Brazil', '7', '6', '8', '21']
# ['13', 'New Zealand', '7', '6', '7', '20']
# ['14', 'Cuba', '7', '3', '5', '15']
# ['15', 'Hungary', '6', '7', '7', '20']
# ['16', 'South Korea', '6', '4', '10', '20']
# ['17', 'Poland', '4', '5', '5', '14']
# ['18', 'Czech Republic', '4', '4', '3', '11']
# ['19', 'Kenya', '4', '4', '2', '10']
# ['20', 'Norway', '4', '2', '2', '8']
# ['21', 'Jamaica', '4', '1', '4', '9']
# ['22', 'Spain', '3', '8', '6', '17']
# ['23', 'Sweden', '3', '6', '0', '9']
# ['24', 'Switzerland', '3', '4', '6', '13']
# ['25', 'Denmark', '3', '4', '4', '11']
# ['26', 'Croatia', '3', '3', '2', '8']
# ['27', 'Iran', '3', '2', '2', '7']
# ['28', 'Serbia', '3', '1', '5', '9']
# ['29', 'Belgium', '3', '1', '3', '7']
# ['30', 'Bulgaria', '3', '1', '2', '6']
# ['31', 'Slovenia', '3', '1', '1', '5']
# ['32', 'Uzbekistan', '3', '0', '2', '5']
# ['33', 'Georgia', '2', '5', '1', '8']
# ['34', 'Chinese Taipei', '2', '4', '6', '12']
# ['35', 'Turkey', '2', '2', '9', '13']
# ['36', 'Greece', '2', '1', '1', '4']
# ['36', 'Uganda', '2', '1', '1', '4']
# ['38', 'Ecuador', '2', '1', '0', '3']
# ['39', 'Ireland', '2', '0', '2', '4']
# ['39', 'Israel', '2', '0', '2', '4']
# ['41', 'Qatar', '2', '0', '1', '3']
# ['42', 'Bahamas', '2', '0', '0', '2']
# ['42', 'Kosovo', '2', '0', '0', '2']
# ['44', 'Ukraine', '1', '6', '12', '19']
# ['45', 'Belarus', '1', '3', '3', '7']
# ['46', 'Romania', '1', '3', '0', '4']
# ['46', 'Venezuela', '1', '3', '0', '4']
# ['48', 'India', '1', '2', '4', '7']
# ['49', 'Hong Kong', '1', '2', '3', '6']
# ['50', 'Philippines', '1', '2', '1', '4']
# ['50', 'Slovakia', '1', '2', '1', '4']
# ['52', 'South Africa', '1', '2', '0', '3']
# ['53', 'Austria', '1', '1', '5', '7']
# ['54', 'Egypt', '1', '1', '4', '6']
# ['55', 'Indonesia', '1', '1', '3', '5']
# ['56', 'Ethiopia', '1', '1', '2', '4']
# ['56', 'Portugal', '1', '1', '2', '4']
# ['58', 'Tunisia', '1', '1', '0', '2']
# ['59', 'Estonia', '1', '0', '1', '2']
# ['59', 'Fiji', '1', '0', '1', '2']
# ['59', 'Latvia', '1', '0', '1', '2']
# ['59', 'Thailand', '1', '0', '1', '2']
# ['63', 'Bermuda', '1', '0', '0', '1']
# ['63', 'Morocco', '1', '0', '0', '1']
# ['63', 'Puerto Rico', '1', '0', '0', '1']
# ['66', 'Colombia', '0', '4', '1', '5']
# ['67', 'Azerbaijan', '0', '3', '4', '7']
# ['68', 'Dominican Republic', '0', '3', '2', '5']
# ['69', 'Armenia', '0', '2', '2', '4']
# ['70', 'Kyrgyzstan', '0', '2', '1', '3']
# ['71', 'Mongolia', '0', '1', '3', '4']
# ['72', 'Argentina', '0', '1', '2', '3']
# ['72', 'San Marino', '0', '1', '2', '3']
# ['74', 'Jordan', '0', '1', '1', '2']
# ['74', 'Malaysia', '0', '1', '1', '2']
# ['74', 'Nigeria', '0', '1', '1', '2']
# ['77', 'Bahrain', '0', '1', '0', '1']
# ['77', 'Saudi Arabia', '0', '1', '0', '1']
# ['77', 'Lithuania', '0', '1', '0', '1']
# ['77', 'North Macedonia', '0', '1', '0', '1']
# ['77', 'Namibia', '0', '1', '0', '1']
# ['77', 'Turkmenistan', '0', '1', '0', '1']
# ['83', 'Kazakhstan', '0', '0', '8', '8']
# ['84', 'Mexico', '0', '0', '4', '4']
# ['85', 'Finland', '0', '0', '2', '2']
# ['86', 'Botswana', '0', '0', '1', '1']
# ['86', 'Burkina Faso', '0', '0', '1', '1']
# ['86', "Côte d'Ivoire", '0', '0', '1', '1']
# ['86', 'Ghana', '0', '0', '1', '1']
# ['86', 'Grenada', '0', '0', '1', '1']
# ['86', 'Kuwait', '0', '0', '1', '1']
# ['86', 'Moldova', '0', '0', '1', '1']
# ['86', 'Syria', '0', '0', '1', '1']

# %% [markdown]
# **Python knows to start `csv.reader` on the next line, i.e. excluding the headers, because you already read in the first line. HOWEVER, you cannot access the reader object outside the `with` statement.**
#
# **Note that all numbers are parsed to string objects, and you will need to convert those to integers. However, you cannot easily identify which values are strings or which are integers. CSV module provides 'quoting' functionality to surround string data like names and labels with quotation marks, thus differentiating string and non-string values.**
#
# ### Quoting CSV data
#
# **Open the csv file in Jupyter to see the double quotation marks around the names, which shows that string types have been quoted correctly in CSV source.**
#
#     "Cereal","Calories","Fat","Protein","Fibre","Vitamin E"
#     "Barley",556,1.7,32.9,10.1,13.8
#     "Durum",339,5,27.4,4.09,9.7
#     "Fonio",240,1,4,1.7,0.05
#     ...
#
# **When reading the content in, you can add specification through `quoting` argument to indicate that the quotation marks around values means they are strings, i.e. non-numeric.**

# %%
csv_filename = 'data/cereal_grains.csv'

# %%
with open(csv_filename, encoding='utf-8', newline='') as csv_data:
    reader = csv.reader(csv_data)
    for row in reader:
        print(row)
# Out:
# ['Cereal', 'Calories', 'Fat', 'Protein', 'Fibre', 'Vitamin E']
# ['Barley', '556', '1.7', '32.9', '10.1', '13.8']
# ['Durum', '339', '5', '27.4', '4.09', '9.7']
# ['Fonio', '240', '1', '4', '1.7', '0.05']
# ['Maize', '442', '7.4', '37.45', '6.15', '11.03']
# ['Millet', '484', '2', '37.9', '13.4', '9.15']
# ['Oats', '231', '9.2', '35.1', '10.3', '3.73']
# ['Rice (Brown)', '346', '2.8', '38.1', '9.9', '0.8']
# ['Rice (White)', '345', '3.6', '37.6', '5.4', '0.1']
# ['Rye', '422', '2', '31.4', '18.2', '21.2']
# ['Sorghum', '316', '3', '37.8', '9.92', '9.15']
# ['Triticale', '338', '1.81', '36.6', '19', '0.9']
# ['Wheat', '407', '1.2', '27.8', '12.9', '13.8']

# %% [markdown]
# **As you can see the parser returns all values as strings when file read in without any customization. Add the specification that non-numeric values have been quoted with `csv.QUOTE_NONNUMERIC` constant.**

# %%
with open(csv_filename, encoding='utf-8', newline='') as csv_data:
    reader = csv.reader(csv_data, quoting=csv.QUOTE_NONNUMERIC)
    for row in reader:
        print(row)
# Out:
# ['Cereal', 'Calories', 'Fat', 'Protein', 'Fibre', 'Vitamin E']
# ['Barley', 556.0, 1.7, 32.9, 10.1, 13.8]
# ['Durum', 339.0, 5.0, 27.4, 4.09, 9.7]
# ['Fonio', 240.0, 1.0, 4.0, 1.7, 0.05]
# ['Maize', 442.0, 7.4, 37.45, 6.15, 11.03]
# ['Millet', 484.0, 2.0, 37.9, 13.4, 9.15]
# ['Oats', 231.0, 9.2, 35.1, 10.3, 3.73]
# ['Rice (Brown)', 346.0, 2.8, 38.1, 9.9, 0.8]
# ['Rice (White)', 345.0, 3.6, 37.6, 5.4, 0.1]
# ['Rye', 422.0, 2.0, 31.4, 18.2, 21.2]
# ['Sorghum', 316.0, 3.0, 37.8, 9.92, 9.15]
# ['Triticale', 338.0, 1.81, 36.6, 19.0, 0.9]
# ['Wheat', 407.0, 1.2, 27.8, 12.9, 13.8]

# %% [markdown]
# **Voila! But this only works if non-numeric values have quotations in the source CSV file, and you are happy if the numbers are converted to floats. To convert to integers is another step.**
#
# **If the string values are not quoted in source CSV, like the Olympic Medals dataset, there is another way to deal with numeric and non-numeric data. You can use `Sniffer().sniff()` to 'sniff' out what the separator is and any characters used to delimit strings.**
#
# **The Sniffer creates a 'dialect', which groups the various format options in a single object.**

# %%
# NOTE - you can read in text files with csv module

input_filename = 'data/country_info.txt'

with open(input_filename, encoding='utf-8', newline='') as countries_data:
    sample = ""
    for line in range(3):
        sample += countries_data.readline()
    
    countries_dialect = csv.Sniffer().sniff(sample)
    
    # Tell Python to go back to start of file
    countries_data.seek(0)
    country_reader = csv.reader(countries_data, dialect=countries_dialect)
    
    for row in country_reader:
        print(row)
# Out:
# ['Country', 'Capital', 'CC', 'CC3', 'IAC', 'TimeZone', 'Currency']
# ['Afghanistan', 'Kabul', 'AF', 'AFG', '+93', 'UTC+04:30', 'Afghan afghani']
# ['Aland Islands', 'Mariehamn', 'AX', 'ALA', '+358', 'UTC+02:00', 'Euro']
# ['Albania', 'Tirana', 'AL', 'ALB', '+355', 'UTC+01:00', 'Albanian lek']
# ['Algeria', 'Algiers', 'DZ', 'DZA', '+213', 'UTC', 'Algerian dinar']
# ['American Samoa', 'Pago Pago', 'AS', 'ASM', '+1 684', 'UTC-11:00', '']
# ['Andorra', 'Andorra la Vella', 'AD', 'AND', '+376', 'UTC+01:00', 'Euro']
# ['Angola', 'Luanda', 'AO', 'AGO', '+244', 'UTC+01:00', 'Angolan kwanza']
# ['Anguilla', 'The Valley', 'AI', 'AIA', '+1 264', 'UTC-04:00', 'East Caribbean dollar']
# ['Antarctica', '', 'AQ', 'ATA', '', '', '']
# ['Antigua and Barbuda', "St. John's", 'AG', 'ATG', '+1 268', 'UTC-04:00', 'East Caribbean dollar']
# ['Argentina', 'Buenos Aires', 'AR', 'ARG', '+54', 'UTC-03:00', 'Argentine peso']
# ['Armenia', 'Yerevan', 'AM', 'ARM', '+374', 'UTC+04:00', 'Armenian dram']
# ['Aruba', 'Oranjestad', 'AW', 'ABW', '+297', 'UTC-04:00', 'Aruban florin']
# ['Australia', 'Canberra', 'AU', 'AUS', '+61', 'UTC+07:00 - UTC+10:00', 'Australian dollar']
# ['Austria', 'Vienna', 'AT', 'AUT', '+43', 'UTC+01:00', 'Euro']
# ['Azerbaijan', 'Baku', 'AZ', 'AZE', '+994', 'UTC+04:00', 'Azerbaijani manat']
# ['Bahamas', 'Nassau', 'BS', 'BHS', '+1 242', 'UTC-05:00', 'Bahamian dollar']
# ['Bahrain', 'Manama', 'BH', 'BHR', '+973', 'UTC+03:00', 'Bahraini dinar']
# ['Bangladesh', 'Dhaka', 'BD', 'BGD', '+880', 'UTC+06:00', 'Bangladeshi taka']
# ['Barbados', 'Bridgetown', 'BB', 'BRB', '+1 246', 'UTC-04:00', 'Barbadian dollar']
# ['Belarus', 'Minsk', 'BY', 'BLR', '+375', 'UTC+03:00', 'Belarusian ruble']
# ['Belgium', 'Brussels', 'BE', 'BEL', '+32', 'UTC+01:00', 'Euro']
# ['Belize', 'Belmopan', 'BZ', 'BLZ', '+501', 'UTC-06:00', 'Belize dollar']
# ['Benin', 'Porto-Novo', 'BJ', 'BEN', '+229', 'UTC+01:00', 'West African CFA franc']
# ['Bermuda', 'Hamilton', 'BM', 'BMU', '+1 441', 'UTC-04:00', 'Bermudian dollar']
# ['Bhutan', 'Thimphu', 'BT', 'BTN', '+975', 'UTC+05:30', 'Bhutanese ngultrum']
# ['Bolivia', 'Sucre', 'BO', 'BOL', '+591', 'UTC-04:00', 'Bolivian boliviano']
# ['Bonaire', 'Kralendijk', 'BQ', 'BES', '+599', 'UTC-04:00', 'United States dollar']
# ['Bosnia and Herzegovina', 'Sarajevo', 'BA', 'BIH', '+387', 'UTC+01:00', 'Bosnia and Herzegovina convertible mark']
# ['Botswana', 'Gaborone', 'BW', 'BWA', '+267', 'UTC+02:00', 'Botswana pula']
# ['Bouvet Island', '', 'BV', 'BVT', '', 'UTC+01:00', '']
# ['Brazil', 'Brasília', 'BR', 'BRA', '+55', 'UTC-05:00 - UTC-03:00', 'Brazilian real']
# ['British Indian Ocean Territory', 'Diego Garcia', 'IO', 'IOT', '+246', 'UTC+06', 'United States dollar']
# ['Brunei', 'Bandar Seri Begawan', 'BN', 'BRN', '+673', 'UTC+08:00', 'Brunei dollar']
# ['Bulgaria', 'Sofia', 'BG', 'BGR', '+359', 'UTC+02:00', 'Bulgarian lev']
# ['Burkina Faso', 'Ouagadougou', 'BF', 'BFA', '+226', 'UTC', 'West African CFA franc']
# ['Burundi', 'Bujumbura', 'BI', 'BDI', '+257', 'UTC+02:00', 'Burundian franc']
# ['Cambodia', 'Phnom Penh', 'KH', 'KHM', '+855', 'UTC+07:00', 'Cambodian riel']
# ['Cameroon', 'Yaoundé', 'CM', 'CMR', '+237', 'UTC+01:00', 'Central African CFA franc']
# ['Canada', 'Ottawa', 'CA', 'CAN', '+1', 'UTC-08:00 - UTC-04:00', 'Canadian dollar']
# ['Cape Verde', 'Praia', 'CV', 'CPV', '+238', 'UTC-01:00', 'Cape Verdean escudo']
# ['Cayman Islands', 'George Town', 'KY', 'CYM', '+1 345', 'UTC-05:00', 'Cayman Islands dollar']
# ['Central African Republic', 'Bangui', 'CF', 'CAF', '+236', 'UTC+01:00', 'Central African CFA franc']
# ['Chad', "N'Djamena", 'TD', 'TCD', '+235', 'UTC+01:00', 'Central African CFA franc']
# ['Chile', 'Santiago', 'CL', 'CHL', '+56', 'UTC-04:00', 'Chilean peso']
# ['China', 'Beijing', 'CN', 'CHN', '+86', 'UTC+08:00', 'Chinese yuan']
# ['Christmas Island', 'Flying Fish Cove', 'CX', 'CXR', '+61 8 9164', 'UTC+07', 'Australian dollar']
# ['Cocos (Keeling) Islands', 'West Island', 'CC', 'CCK', '+61 8 9162', 'UTC+06:30', 'Australian dollar']
# ['Colombia', 'Bogotá', 'CO', 'COL', '+57', 'UTC-05:00', 'Colombian peso']
# ['Comoros', 'Moroni', 'KM', 'COM', '+269', 'UTC+03:00', 'Comorian franc']
# ['Congo, Republic of the', 'Brazzaville', 'CG', 'COG', '+242', 'UTC+01:00', 'Central African CFA franc']
# ['Congo, Democratic Republic of the', 'Kinshasa', 'CD', 'COD', '+243', 'UTC+01:00 - UTC+02:00', 'Congolese franc']
# ['Cook Islands', 'Avarua', 'CK', 'COK', '+682', 'UTC-10:00', 'New Zealand dollar']
# ['Costa Rica', 'San José', 'CR', 'CRI', '+506', 'UTC-06:00', 'Costa Rican colón']
# ["Côte d'Ivoire", 'Yamoussoukro', 'CI', 'CIV', '+225', 'UTC', 'West African CFA franc']
# ['Croatia', 'Zagreb', 'HR', 'HRV', '+385', 'UTC+01:00', 'Croatian kuna']
# ['Cuba', 'Havana', 'CU', 'CUB', '+53', 'UTC-03:00', 'Cuban convertible peso']
# ['Curacao', 'Willemstad', 'CW', 'CUW', '+599 9', 'UTC-04:00', 'Netherlands Antillean guilder']
# ['Cyprus', 'Nicosia', 'CY', 'CYP', '+357', 'UTC+02:00', 'Euro']
# ['Czech Republic', 'Prague', 'CZ', 'CZE', '+420', 'UTC+01:00', 'Czech koruna']
# ['Denmark', 'Copenhagen', 'DK', 'DNK', '+45', 'UTC+01:00', 'Danish krone']
# ['Djibouti', 'Djibouti', 'DJ', 'DJI', '+253', 'UTC+03:00', 'Djiboutian franc']
# ['Dominica', 'Roseau', 'DM', 'DMA', '+1 767', 'UTC-04:00', 'East Caribbean dollar']
# ['Dominican Republic', 'Santo Domingo', 'DO', 'DOM', '+1 809/829/849', 'UTC-04:00', 'Dominican peso']
# ['East Timor', 'Dili', 'TL', 'TLS', '+670', 'UTC+09', 'United States dollar']
# ['Ecuador', 'Quito', 'EC', 'ECU', '+593', 'UTC-05:00', 'United States dollar']
# ['Egypt', 'Cairo', 'EG', 'EGY', '+20', 'UTC+02:00', 'Egyptian pound']
# ['El Salvador', 'San Salvador', 'SV', 'SLV', '+503', 'UTC-06:00', 'Salvadoran colón']
# ['Equatorial Guinea', 'Malabo', 'GQ', 'GNQ', '+240', 'UTC+01:00', 'Central African CFA franc']
# ['Eritrea', 'Asmara', 'ER', 'ERI', '+291', 'UTC+03:00', 'Eritrean nakfa']
# ['Estonia', 'Tallinn', 'EE', 'EST', '+372', 'UTC+03:00', 'Euro']
# ['Ethiopia', 'Addis Ababa', 'ET', 'ETH', '+251', 'UTC+03:00', 'Ethiopian birr']
# ['Falkland Islands (Malvinas)', 'Stanley', 'FK', 'FLK', '+500', 'UTC-04:00', 'Falkland Islands pound']
# ['Faroe Islands', 'Tórshavn', 'FO', 'FRO', '+298', 'UTC', 'Danish krone']
# ['Fiji', 'Suva', 'FJ', 'FJI', '+679', 'UTC+12:00', 'Fijian dollar']
# ['Finland', 'Helsinki', 'FI', 'FIN', '+358', 'UTC+02:00', 'Euro']
# ['France', 'Paris', 'FR', 'FRA', '+33', 'UTC+01:00', 'Euro']
# ['French Guiana', 'Cayenne', 'GF', 'GUF', '+594', 'UTC-01:00', 'Euro']
# ['French Polynesia', 'Papeete', 'PF', 'PYF', '+689', 'UTC-10:00', 'CFP franc']
# ['French Southern Territories', 'Port-aux-Français', 'TF', 'ATF', '', 'UTC+05:00', 'Euro']
# ['Gabon', 'Libreville', 'GA', 'GAB', '+241', 'UTC+01:00', 'Central African CFA franc']
# ['Gambia', 'Banjul', 'GM', 'GMB', '+220', 'UTC', 'Gambian dalasi']
# ['Georgia', 'Tbilisi', 'GE', 'GEO', '+995', 'UTC+04:00', 'Georgian lari']
# ['Germany', 'Berlin', 'DE', 'DEU', '+49', 'UTC+01:00', 'Euro']
# ['Ghana', 'Accra', 'GH', 'GHA', '+233', 'UTC', 'Ghanaian cedi']
# ['Gibraltar', 'Gibraltar', 'GI', 'GIB', '+350', 'UTC+01:00', 'Gibraltar pound']
# ['Greece', 'Athens', 'GR', 'GRC', '+30', 'UTC+02:00', 'Euro']
# ['Greenland', 'Nuuk', 'GL', 'GRL', '+299', 'UTC-03:00', 'Danish krone']
# ['Grenada', "St. George's", 'GD', 'GRD', '+1 473', 'UTC-04:00', 'East Caribbean dollar']
# ['Guadeloupe', 'Basse-Terre', 'GP', 'GLP', '+590', 'UTC-04:00', 'Euro']
# ['Guam', 'Hagåtña', 'GU', 'GUM', '+1 671', 'UTC+10:00', 'United States dollar']
# ['Guatemala', 'Guatemala City', 'GT', 'GTM', '+502', 'UTC-06:00', 'Guatemalan quetzal']
# ['Guernsey', 'St. Peter Port', 'GG', 'GGY', '+44 1481', 'UTC', 'British pound']
# ['Guinea', 'Conakry', 'GN', 'GIN', '+224', 'UTC', 'Guinean franc']
# ['Guinea-Bissau', 'Bissau', 'GW', 'GNB', '+245', 'UTC', 'West African CFA franc']
# ['Guyana', 'Georgetown', 'GY', 'GUY', '+592', 'UTC-03:00', 'Guyanese dollar']
# ['Haiti', 'Port-au-Prince', 'HT', 'HTI', '+509', 'UTC-05:00', 'Haitian gourde']
# ['Heard Island and McDonald Islands', '', 'HM', 'HMD', '', 'UTC+05', '']
# ['Honduras', 'Tegucigalpa', 'HN', 'HND', '+504', 'UTC-06:00', 'Honduran lempira']
# ['Hong Kong', '', 'HK', 'HKG', '+852', 'UTC+08:00', 'Hong Kong dollar']
# ['Hungary', 'Budapest', 'HU', 'HUN', '+36', 'UTC+01:00', 'Hungarian forint']
# ['Iceland', 'Reykjavík', 'IS', 'ISL', '+354', 'UTC', 'Icelandic króna']
# ['India', 'New Delhi', 'IN', 'IND', '+91', 'UTC+05:30', 'Indian rupee']
# ['Indonesia', 'Jakarta', 'ID', 'IDN', '+62', 'UTC+07:00 - UTC+09:00', 'Indonesian rupiah']
# ['Iran', 'Tehran', 'IR', 'IRN', '+98', 'UTC+03:30', 'Iranian rial']
# ['Iraq', 'Baghdad', 'IQ', 'IRQ', '+964', 'UTC+03:00', 'Iraqi dinar']
# ['Ireland', 'Dublin', 'IE', 'IRL', '+353', 'UTC', 'Euro']
# ['Isle of Man', 'Douglas', 'IM', 'IMN', '+44 1624', 'UTC', 'British pound']
# ['Israel', 'Jerusalem', 'IL', 'ISR', '+972', 'UTC+02:00', 'Israeli new shekel']
# ['Italy', 'Rome', 'IT', 'ITA', '+39', 'UTC+01:00', 'Euro']
# ['Jamaica', 'Kingston', 'JM', 'JAM', '+1 876', 'UTC-05:00', 'Jamaican dollar']
# ['Japan', 'Tokyo', 'JP', 'JPN', '+81', 'UTC+09:00', 'Japanese yen']
# ['Jersey', 'St. Helier', 'JE', 'JEY', '+44 1534', 'UTC', 'British pound']
# ['Jordan', 'Amman', 'JO', 'JOR', '+962', 'UTC+02:00', 'Jordanian dinar']
# ['Kazakhstan', 'Astana', 'KZ', 'KAZ', '+7 6xx/7xx', 'UTC+06:00', 'Kazakhstani tenge']
# ['Kenya', 'Nairobi', 'KE', 'KEN', '+254', 'UTC+03:00', 'Kenyan shilling']
# ['Kiribati', 'Tarawa', 'KI', 'KIR', '+686', 'UTC+12:00', 'Australian dollar']
# ['Kuwait', 'Kuwait City', 'KW', 'KWT', '+965', 'UTC+03:00', 'Kuwaiti dinar']
# ['Kyrgyzstan', 'Bishkek', 'KG', 'KGZ', '+996', 'UTC+06:00', 'Kyrgyzstani som']
# ['Laos', 'Vientiane', 'LA', 'LAO', '+856', 'UTC+07:00', 'Lao kip']
# ['Latvia', 'Riga', 'LV', 'LVA', '+371', 'UTC+03:00', 'Latvian lats']
# ['Lebanon', 'Beirut', 'LB', 'LBN', '+961', 'UTC+02:00', 'Lebanese pound']
# ['Lesotho', 'Maseru', 'LS', 'LSO', '+266', 'UTC+02:00', 'Lesotho loti']
# ['Liberia', 'Monrovia', 'LR', 'LBR', '+231', 'UTC', 'Liberian dollar']
# ['Libya', 'Tripoli', 'LY', 'LBY', '+218', 'UTC+02:00', 'Libyan dinar']
# ['Liechtenstein', 'Vaduz', 'LI', 'LIE', '+423', 'UTC+01:00', 'Swiss franc']
# ['Lithuania', 'Vilnius', 'LT', 'LTU', '+370', 'UTC+02:00', 'Lithuanian litas']
# ['Luxembourg', 'Luxembourg', 'LU', 'LUX', '+352', 'UTC+01:00', 'Euro']
# ['Macau', '', 'MO', 'MAC', '+853', 'UTC+08:00', 'Macanese pataca']
# ['Macedonia', 'Skopje', 'MK', 'MKD', '+389', 'UTC+01:00', 'Macedonian denar']
# ['Madagascar', 'Antananarivo', 'MG', 'MDG', '+261', 'UTC+03:00', 'Malagasy ariary']
# ['Malawi', 'Lilongwe', 'MW', 'MWI', '+265', 'UTC+02:00', 'Malawian kwacha']
# ['Malaysia', 'Kuala Lumpur', 'MY', 'MYS', '+60', 'UTC+08:00', 'Malaysian ringgit']
# ['Maldives', 'Malé', 'MV', 'MDV', '+960', 'UTC+05:00', 'Maldivian rufiyaa']
# ['Mali', 'Bamako', 'ML', 'MLI', '+223', 'UTC', 'West African CFA franc']
# ['Malta', 'Valletta', 'MT', 'MLT', '+356', 'UTC+01:00', 'Euro']
# ['Marshall Islands', 'Majuro', 'MH', 'MHL', '+692', 'UTC+10:00', 'United States dollar']
# ['Martinique', 'Fort-de-France', 'MQ', 'MTQ', '+596', 'UTC-04:00', 'Euro']
# ['Mauritania', 'Nouakchott', 'MR', 'MRT', '+222', 'UTC', 'Mauritanian ouguiya']
# ['Mauritius', 'Port Louis', 'MU', 'MUS', '+230', 'UTC+04:00', 'Mauritian rupee']
# ['Mayotte', 'Mamoudzou', 'YT', 'MYT', '+262 269/639', 'UTC+03:00', 'Euro']
# ['Mexico', 'Mexico City', 'MX', 'MEX', '+52', 'UTC-08:00 - UTC-06:00', 'Mexican peso']
# ['Micronesia', 'Palikir', 'FM', 'FSM', '+691', 'UTC+10:00', 'Micronesian dollar']
# ['Moldova', 'Chisinau', 'MD', 'MDA', '+373', 'UTC+03:00', 'Moldovan leu']
# ['Monaco', 'Monaco', 'MC', 'MCO', '+377', 'UTC+01:00', 'Euro']
# ['Mongolia', 'Ulaanbaatar', 'MN', 'MNG', '+976', 'UTC+08:00', 'Mongolian tögrög']
# ['Montenegro', 'Podgorica', 'ME', 'MNE', '+382', 'UTC+01', 'Euro']
# ['Montserrat', 'Plymouth', 'MS', 'MSR', '+1 664', 'UTC-04:00', 'East Caribbean dollar']
# ['Morocco', 'Rabat', 'MA', 'MAR', '+212', 'UTC', 'Moroccan dirham']
# ['Mozambique', 'Maputo', 'MZ', 'MOZ', '+258', 'UTC+02:00', 'Mozambican metical']
# ['Myanmar (Burma)', 'Naypyidaw', 'MM', 'MMR', '+95', 'UTC+06:30', 'Myanma kyat']
# ['Namibia', 'Windhoek', 'NA', 'NAM', '+264', 'UTC+02:00', 'Namibian dollar']
# ['Nauru', 'Yaren', 'NR', 'NRU', '+674', 'UTC+12:00', 'Australian dollar']
# ['Nepal', 'Kathmandu', 'NP', 'NPL', '+977', 'UTC+05:30', 'Nepalese rupee']
# ['Netherlands', 'Amsterdam', 'NL', 'NLD', '+31', 'UTC+01:00', 'Euro']
# ['New Caledonia', 'Nouméa', 'NC', 'NCL', '+687', 'UTC+11:00', 'CFP franc']
# ['New Zealand', 'Wellington', 'NZ', 'NZL', '+64', 'UTC+12:00', 'New Zealand dollar']
# ['Nicaragua', 'Managua', 'NI', 'NIC', '+505', 'UTC-06:00', 'Nicaraguan córdoba']
# ['Niger', 'Niamey', 'NE', 'NER', '+227', 'UTC+01:00', 'West African CFA franc']
# ['Nigeria', 'Abuja', 'NG', 'NGA', '+234', 'UTC+01:00', 'Nigerian naira']
# ['Niue', 'Alofi', 'NU', 'NIU', '+683', 'UTC-11:00', 'New Zealand dollar']
# ['Norfolk Island', 'Kingston', 'NF', 'NFK', '+672 3', 'UTC+11:30', 'Australian dollar']
# ['North Korea', 'Pyongyang', 'KP', 'PRK', '+850', 'UTC+09:00', 'North Korean won']
# ['Northern Mariana Islands', 'Saipan', 'MP', 'MNP', '+1 670', 'UTC+10:00', 'United States dollar']
# ['Norway', 'Oslo', 'NO', 'NOR', '+47', 'UTC+01:00', 'Norwegian krone']
# ['Oman', 'Muscat', 'OM', 'OMN', '+968', 'UTC+04:00', 'Omani rial']
# ['Pakistan', 'Islamabad', 'PK', 'PAK', '+92', 'UTC+05:00', 'Pakistani rupee']
# ['Palau', 'Ngerulmud', 'PW', 'PLW', '+680', 'UTC+09:00', 'Palauan dollar']
# ['Panama', 'Panama City', 'PA', 'PAN', '+507', 'UTC-05:00', 'Panamanian balboa']
# ['Papua New Guinea', 'Port Moresby', 'PG', 'PNG', '+675', 'UTC+10:00', 'Papua New Guinean kina']
# ['Paraguay', 'Asunción', 'PY', 'PRY', '+595', 'UTC-04:00', 'Paraguayan guaraní']
# ['Peru', 'Lima', 'PE', 'PER', '+51', 'UTC-05:00', 'Peruvian nuevo sol']
# ['Philippines', 'Manila', 'PH', 'PHL', '+63', 'UTC+08:00', 'Philippine peso']
# ['Pitcairn', 'Adamstown', 'PN', 'PCN', '+872', 'UTC-08', 'New Zealand dollar']
# ['Poland', 'Warsaw', 'PL', 'POL', '+48', 'UTC+01:00', 'Polish złoty']
# ['Portugal', 'Lisbon', 'PT', 'PRT', '+351', 'UTC+01:00', 'Euro']
# ['Puerto Rico', 'San Juan', 'PR', 'PRI', '+1 787/939', 'UTC-04:00', 'United States dollar']
# ['Qatar', 'Doha', 'QA', 'QAT', '+974', 'UTC+03:00', 'Qatari riyal']
# ['Reunion', '', 'RE', 'REU', '+262', 'UTC+04:00', 'Euro']
# ['Romania', 'Bucharest', 'RO', 'ROU', '+40', 'UTC+02:00', 'Romanian leu']
# ['Russia', 'Moscow', 'RU', 'RUS', '+7', 'UTC+03:00', 'Russian ruble']
# ['Rwanda', 'Kigali', 'RW', 'RWA', '+250', 'UTC+02:00', 'Rwandan franc']
# ['Saint Barthelemy', 'Gustavia', 'BL', 'BLM', '+590', 'UTC-04', 'Euro']
# ['Saint Helena', 'Jamestown', 'SH', 'SHN', '+290', 'UTC', 'Saint Helena pound']
# ['Saint Kitts and Nevis', 'Basseterre', 'KN', 'KNA', '+1 869', 'UTC-04:00', 'East Caribbean dollar']
# ['Saint Lucia', 'Castries', 'LC', 'LCA', '+1 758', 'UTC-04:00', 'East Caribbean dollar']
# ['Saint Martin', 'Marigot', 'MF', 'MAF', '+590', 'UTC-04', 'Euro']
# ['Saint Pierre and Miquelon', 'St. Pierre', 'PM', 'SPM', '+508', 'UTC-03', 'Euro']
# ['Saint Vincent and the Grenadines', 'Kingstown', 'VC', 'VCT', '+1 784', 'UTC-04', 'East Caribbean dollar']
# ['Samoa', 'Apia', 'WS', 'WSM', '+685', 'UTC-11:00', 'Samoan tala']
# ['San Marino', 'San Marino', 'SM', 'SMR', '+378', 'UTC+01:00', 'Euro']
# ['Sao Tome and Príncipe', 'São Tomé', 'ST', 'STP', '+239', 'UTC', 'São Tomé and Príncipe dobra']
# ['Saudi Arabia', 'Riyadh', 'SA', 'SAU', '+966', 'UTC+03:00', 'Saudi riyal']
# ['Senegal', 'Dakar', 'SN', 'SEN', '+221', 'UTC', 'West African CFA franc']
# ['Serbia', 'Belgrade', 'RS', 'SRB', '+381', 'UTC+01:00', 'Serbian dinar']
# ['Seychelles', 'Victoria', 'SC', 'SYC', '+248', 'UTC+04:00', 'Seychellois rupee']
# ['Sierra Leone', 'Freetown', 'SL', 'SLE', '+232', 'UTC', 'Sierra Leonean leone']
# ['Singapore', 'Singapore', 'SG', 'SGP', '+65', 'UTC+08:00', 'Brunei dollar']
# ['Sint Maarten', 'Philipsburg', 'SX', 'SXM', '+599 5', 'UTC-04:00', 'Netherlands Antillean guilder']
# ['Slovakia', 'Bratislava', 'SK', 'SVK', '+421', 'UTC+01:00', 'Euro']
# ['Slovenia', 'Ljubljana', 'SI', 'SVN', '+386', 'UTC+01:00', 'Euro']
# ['Solomon Islands', 'Honiara', 'SB', 'SLB', '+677', 'UTC+11:00', 'Solomon Islands dollar']
# ['Somalia', 'Mogadishu', 'SO', 'SOM', '+252', 'UTC+03:00', 'Somali shilling']
# ['South Africa', 'Pretoria', 'ZA', 'ZAF', '+27', 'UTC+02:00', 'South African rand']
# ['South Georgia and the South Sandwich Islands', 'Grytviken', 'GS', 'SGS', '', 'UTC-02', 'British pound']
# ['South Korea', 'Seoul', 'KR', 'KOR', '+82', 'UTC+09:00', 'South Korean won']
# ['Spain', 'Madrid', 'ES', 'ESP', '+34', 'UTC+01:00', 'Euro']
# ['Sri Lanka', 'Sri Jayawardenapura Kotte', 'LK', 'LKA', '+94', 'UTC+05:30', 'Sri Lankan rupee']
# ['Sudan', 'Khartoum', 'SD', 'SDN', '+249', 'UTC+02:00', 'Sudanese pound']
# ['Suriname', 'Paramaribo', 'SR', 'SUR', '+597', 'UTC-03:30', 'Surinamese dollar']
# ['Svalbard and Jan Mayen', '', 'SJ', 'SJM', '+47', 'UTC+01:00', 'Norwegian krone']
# ['Swaziland', 'Mbabane', 'SZ', 'SWZ', '+268', 'UTC+02:00', 'Swazi lilangeni']
# ['Sweden', 'Stockholm', 'SE', 'SWE', '+46', 'UTC+01:00', 'Swedish krona']
# ['Switzerland', 'Bern', 'CH', 'CHE', '+41', 'UTC+01:00', 'Swiss franc']
# ['Syrian Arab Republic', 'Damascus', 'SY', 'SYR', '+963', 'UTC+02:00', 'Syrian pound']
# ['Taiwan', 'Taipei', 'TW', 'TWN', '+886', 'UTC+08:00', 'New Taiwan dollar']
# ['Tajikistan', 'Dushanbe', 'TJ', 'TJK', '+992', 'UTC+06:00', 'Tajikistani somoni']
# ['Tanzania', 'Dodoma', 'TZ', 'TZA', '+255', 'UTC+03:00', 'Tanzanian shilling']
# ['Thailand', 'Bangkok', 'TH', 'THA', '+66', 'UTC+07:00', 'Thai baht']
# ['Togo', 'Lomé', 'TG', 'TGO', '+228', 'UTC', 'West African CFA franc']
# ['Tokelau', 'Rotates annually', 'TK', 'TKL', '+690', 'UTC-10', 'New Zealand dollar']
# ['Tonga', 'Nuku', 'TO', 'TON', '+676', 'UTC+13:00', 'Tongan paʻanga']
# ['Trinidad and Tobago', 'Port of Spain', 'TT', 'TTO', '+1 868', 'UTC-04:00', 'Trinidad and Tobago dollar']
# ['Tunisia', 'Tunis', 'TN', 'TUN', '+216', 'UTC+01:00', 'Tunisian dinar']
# ['Turkey', 'Ankara', 'TR', 'TUR', '+90', 'UTC+02:00', 'Turkish lira']
# ['Turkmenistan', 'Ashgabat', 'TM', 'TKM', '+993', 'UTC+05:00', 'Turkmenistani manat']
# ['Turks and Caicos Islands', 'Cockburn Town', 'TC', 'TCA', '+1 649', 'UTC-05:00', 'United States dollar']
# ['Tuvalu', 'Funafuti', 'TV', 'TUV', '+688', 'UTC+12:00', 'Australian dollar']
# ['Uganda', 'Kampala', 'UG', 'UGA', '+256', 'UTC+03:00', 'Ugandan shilling']
# ['Ukraine', 'Kyiv', 'UA', 'UKR', '+380', 'UTC+03:00', 'Ukrainian hryvnia']
# ['United Arab Emirates', 'Abu Dhabi', 'AE', 'ARE', '+971', 'UTC+04:00', 'United Arab Emirates dirham']
# ['United Kingdom', 'London', 'GB', 'GBR', '+44', 'UTC', 'British pound']
# ['United States', 'Washington D.C.', 'US', 'USA', '+1', 'UTC-11:00 - UTC-05:00', 'United States dollar']
# ['United States Minor Outlying Islands', '', 'UM', 'UMI', '+1', '', 'United States dollar']
# ['Uruguay', 'Montevideo', 'UY', 'URY', '+598', 'UTC-03:00', 'Uruguayan peso']
# ['Uzbekistan', 'Tashkent', 'UZ', 'UZB', '+998', 'UTC+06:00', 'Uzbekistani som']
# ['Vanuatu', 'Port Vila', 'VU', 'VUT', '+678', 'UTC+11:00', 'Vanuatu vatu']
# ['Vatican City', 'Vatican City', 'VA', 'VAT', '+39 06 698', 'UTC+01', 'Euro']
# ['Venezuela', 'Caracas', 'VE', 'VEN', '+58', 'UTC-04:00', 'Venezuelan bolívar']
# ['Vietnam', 'Hanoi', 'VN', 'VNM', '+84', 'UTC+07:00', 'Vietnamese đồng']
# ['Virgin Islands', 'Road Town', 'VG', 'VGB', '+1 284', 'UTC-04', 'British Virgin Islands dollar']
# ['Virgin Islands of the United States', 'Charlotte Amalie', 'VI', 'VIR', '+1 340', 'UTC-04', 'United States dollar']
# ['Wallis and Futuna', 'Mata-Utu', 'WF', 'WLF', '+681', 'UTC+12:00', 'CFP franc']
# ['Western Sahara', 'Laâyoune (El Aaiún)', 'EH', 'ESH', '+212 5288/5289', 'UTC+01', 'Moroccan dirham']
# ['Yemen', 'Sanaá', 'YE', 'YEM', '+967', 'UTC+03:00', 'Yemeni rial']
# ['Zambia', 'Lusaka', 'ZM', 'ZMB', '+260', 'UTC+02:00', 'Zambian kwacha']
# ['Zimbabwe', ' Harare', 'ZW', 'ZWE', '+263', 'UTC+02:00', 'Zimbabwean dollar']

# %% [markdown]
# **As you can see, Sniffer knew that the separator was a pipe character. You can view all the attributes of the dialect object using the `dir()` function. You can only use `csv.get_dialect()` function if you register your dialect object first.**

# %%
print(dir(countries_dialect))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_name', '_valid', '_validate', 'delimiter', 'doublequote', 'escapechar', 'lineterminator', 'quotechar', 'quoting', 'skipinitialspace']

# %%
# List attributes you are interested in
attributes = [
    'delimiter', 
    'doublequote', 
    'escapechar', 
    'lineterminator', 
    'quotechar', 
    'quoting', 
    'skipinitialspace'
]

for attribute in attributes:
    print(f"{attribute}: {getattr(countries_dialect, attribute)}")
# Out:
# delimiter: |
# doublequote: False
# escapechar: None
# lineterminator:
#
# quotechar: "
# quoting: 0
# skipinitialspace: False

# %% [markdown]
# * DELIMITER: **The `delimiter` is `|` character.**
#
# * DOUBLEQUOTE: **There is no 'doubling-up' of quotes if string value already contains quotations.**
#
# * ESCAPECHAR: **There is no escape character to escape the `delimiter` or `quotechar` characters.**
#
# * LINETERMINATOR: **There is no specific character used for line termination.**
#
# * QUOTECHAR: **The way of quoting strings, or values containing special characters, is with double quotation marks.**
#
# * QUOTING: **There are no quoting rules applied, like `QUOTE_NONNUMERIC`. This is only used when you are writing content to CSV.**
#
# * SKIPINITIALSPACE: **Do not ignore leading whitespaces, just after each separator, i.e. keep them. Leading whitespaces are trimmed if set to `True`.**
#
# **You can edit the dialect object in case you want to change an attribute value, like setting `skipinitialspace` to True, by running the program again and add update to dialect.**

# %%
with open(input_filename, encoding='utf-8', newline='') as countries_data:
    sample = ""
    for line in range(3):
        sample += countries_data.readline()
    
    countries_dialect = csv.Sniffer().sniff(sample)
    # Update dialect to trim leading whitespaces
    countries_dialect.skipinitialspace = True
    
    # Tell Python to go back to start of file
    countries_data.seek(0)
    country_reader = csv.reader(countries_data, dialect=countries_dialect)
    
    for row in country_reader:
        print(row)
# Out:
# ['Country', 'Capital', 'CC', 'CC3', 'IAC', 'TimeZone', 'Currency']
# ['Afghanistan', 'Kabul', 'AF', 'AFG', '+93', 'UTC+04:30', 'Afghan afghani']
# ['Aland Islands', 'Mariehamn', 'AX', 'ALA', '+358', 'UTC+02:00', 'Euro']
# ['Albania', 'Tirana', 'AL', 'ALB', '+355', 'UTC+01:00', 'Albanian lek']
# ['Algeria', 'Algiers', 'DZ', 'DZA', '+213', 'UTC', 'Algerian dinar']
# ['American Samoa', 'Pago Pago', 'AS', 'ASM', '+1 684', 'UTC-11:00', '']
# ['Andorra', 'Andorra la Vella', 'AD', 'AND', '+376', 'UTC+01:00', 'Euro']
# ['Angola', 'Luanda', 'AO', 'AGO', '+244', 'UTC+01:00', 'Angolan kwanza']
# ['Anguilla', 'The Valley', 'AI', 'AIA', '+1 264', 'UTC-04:00', 'East Caribbean dollar']
# ['Antarctica', '', 'AQ', 'ATA', '', '', '']
# ['Antigua and Barbuda', "St. John's", 'AG', 'ATG', '+1 268', 'UTC-04:00', 'East Caribbean dollar']
# ['Argentina', 'Buenos Aires', 'AR', 'ARG', '+54', 'UTC-03:00', 'Argentine peso']
# ['Armenia', 'Yerevan', 'AM', 'ARM', '+374', 'UTC+04:00', 'Armenian dram']
# ['Aruba', 'Oranjestad', 'AW', 'ABW', '+297', 'UTC-04:00', 'Aruban florin']
# ['Australia', 'Canberra', 'AU', 'AUS', '+61', 'UTC+07:00 - UTC+10:00', 'Australian dollar']
# ['Austria', 'Vienna', 'AT', 'AUT', '+43', 'UTC+01:00', 'Euro']
# ['Azerbaijan', 'Baku', 'AZ', 'AZE', '+994', 'UTC+04:00', 'Azerbaijani manat']
# ['Bahamas', 'Nassau', 'BS', 'BHS', '+1 242', 'UTC-05:00', 'Bahamian dollar']
# ['Bahrain', 'Manama', 'BH', 'BHR', '+973', 'UTC+03:00', 'Bahraini dinar']
# ['Bangladesh', 'Dhaka', 'BD', 'BGD', '+880', 'UTC+06:00', 'Bangladeshi taka']
# ['Barbados', 'Bridgetown', 'BB', 'BRB', '+1 246', 'UTC-04:00', 'Barbadian dollar']
# ['Belarus', 'Minsk', 'BY', 'BLR', '+375', 'UTC+03:00', 'Belarusian ruble']
# ['Belgium', 'Brussels', 'BE', 'BEL', '+32', 'UTC+01:00', 'Euro']
# ['Belize', 'Belmopan', 'BZ', 'BLZ', '+501', 'UTC-06:00', 'Belize dollar']
# ['Benin', 'Porto-Novo', 'BJ', 'BEN', '+229', 'UTC+01:00', 'West African CFA franc']
# ['Bermuda', 'Hamilton', 'BM', 'BMU', '+1 441', 'UTC-04:00', 'Bermudian dollar']
# ['Bhutan', 'Thimphu', 'BT', 'BTN', '+975', 'UTC+05:30', 'Bhutanese ngultrum']
# ['Bolivia', 'Sucre', 'BO', 'BOL', '+591', 'UTC-04:00', 'Bolivian boliviano']
# ['Bonaire', 'Kralendijk', 'BQ', 'BES', '+599', 'UTC-04:00', 'United States dollar']
# ['Bosnia and Herzegovina', 'Sarajevo', 'BA', 'BIH', '+387', 'UTC+01:00', 'Bosnia and Herzegovina convertible mark']
# ['Botswana', 'Gaborone', 'BW', 'BWA', '+267', 'UTC+02:00', 'Botswana pula']
# ['Bouvet Island', '', 'BV', 'BVT', '', 'UTC+01:00', '']
# ['Brazil', 'Brasília', 'BR', 'BRA', '+55', 'UTC-05:00 - UTC-03:00', 'Brazilian real']
# ['British Indian Ocean Territory', 'Diego Garcia', 'IO', 'IOT', '+246', 'UTC+06', 'United States dollar']
# ['Brunei', 'Bandar Seri Begawan', 'BN', 'BRN', '+673', 'UTC+08:00', 'Brunei dollar']
# ['Bulgaria', 'Sofia', 'BG', 'BGR', '+359', 'UTC+02:00', 'Bulgarian lev']
# ['Burkina Faso', 'Ouagadougou', 'BF', 'BFA', '+226', 'UTC', 'West African CFA franc']
# ['Burundi', 'Bujumbura', 'BI', 'BDI', '+257', 'UTC+02:00', 'Burundian franc']
# ['Cambodia', 'Phnom Penh', 'KH', 'KHM', '+855', 'UTC+07:00', 'Cambodian riel']
# ['Cameroon', 'Yaoundé', 'CM', 'CMR', '+237', 'UTC+01:00', 'Central African CFA franc']
# ['Canada', 'Ottawa', 'CA', 'CAN', '+1', 'UTC-08:00 - UTC-04:00', 'Canadian dollar']
# ['Cape Verde', 'Praia', 'CV', 'CPV', '+238', 'UTC-01:00', 'Cape Verdean escudo']
# ['Cayman Islands', 'George Town', 'KY', 'CYM', '+1 345', 'UTC-05:00', 'Cayman Islands dollar']
# ['Central African Republic', 'Bangui', 'CF', 'CAF', '+236', 'UTC+01:00', 'Central African CFA franc']
# ['Chad', "N'Djamena", 'TD', 'TCD', '+235', 'UTC+01:00', 'Central African CFA franc']
# ['Chile', 'Santiago', 'CL', 'CHL', '+56', 'UTC-04:00', 'Chilean peso']
# ['China', 'Beijing', 'CN', 'CHN', '+86', 'UTC+08:00', 'Chinese yuan']
# ['Christmas Island', 'Flying Fish Cove', 'CX', 'CXR', '+61 8 9164', 'UTC+07', 'Australian dollar']
# ['Cocos (Keeling) Islands', 'West Island', 'CC', 'CCK', '+61 8 9162', 'UTC+06:30', 'Australian dollar']
# ['Colombia', 'Bogotá', 'CO', 'COL', '+57', 'UTC-05:00', 'Colombian peso']
# ['Comoros', 'Moroni', 'KM', 'COM', '+269', 'UTC+03:00', 'Comorian franc']
# ['Congo, Republic of the', 'Brazzaville', 'CG', 'COG', '+242', 'UTC+01:00', 'Central African CFA franc']
# ['Congo, Democratic Republic of the', 'Kinshasa', 'CD', 'COD', '+243', 'UTC+01:00 - UTC+02:00', 'Congolese franc']
# ['Cook Islands', 'Avarua', 'CK', 'COK', '+682', 'UTC-10:00', 'New Zealand dollar']
# ['Costa Rica', 'San José', 'CR', 'CRI', '+506', 'UTC-06:00', 'Costa Rican colón']
# ["Côte d'Ivoire", 'Yamoussoukro', 'CI', 'CIV', '+225', 'UTC', 'West African CFA franc']
# ['Croatia', 'Zagreb', 'HR', 'HRV', '+385', 'UTC+01:00', 'Croatian kuna']
# ['Cuba', 'Havana', 'CU', 'CUB', '+53', 'UTC-03:00', 'Cuban convertible peso']
# ['Curacao', 'Willemstad', 'CW', 'CUW', '+599 9', 'UTC-04:00', 'Netherlands Antillean guilder']
# ['Cyprus', 'Nicosia', 'CY', 'CYP', '+357', 'UTC+02:00', 'Euro']
# ['Czech Republic', 'Prague', 'CZ', 'CZE', '+420', 'UTC+01:00', 'Czech koruna']
# ['Denmark', 'Copenhagen', 'DK', 'DNK', '+45', 'UTC+01:00', 'Danish krone']
# ['Djibouti', 'Djibouti', 'DJ', 'DJI', '+253', 'UTC+03:00', 'Djiboutian franc']
# ['Dominica', 'Roseau', 'DM', 'DMA', '+1 767', 'UTC-04:00', 'East Caribbean dollar']
# ['Dominican Republic', 'Santo Domingo', 'DO', 'DOM', '+1 809/829/849', 'UTC-04:00', 'Dominican peso']
# ['East Timor', 'Dili', 'TL', 'TLS', '+670', 'UTC+09', 'United States dollar']
# ['Ecuador', 'Quito', 'EC', 'ECU', '+593', 'UTC-05:00', 'United States dollar']
# ['Egypt', 'Cairo', 'EG', 'EGY', '+20', 'UTC+02:00', 'Egyptian pound']
# ['El Salvador', 'San Salvador', 'SV', 'SLV', '+503', 'UTC-06:00', 'Salvadoran colón']
# ['Equatorial Guinea', 'Malabo', 'GQ', 'GNQ', '+240', 'UTC+01:00', 'Central African CFA franc']
# ['Eritrea', 'Asmara', 'ER', 'ERI', '+291', 'UTC+03:00', 'Eritrean nakfa']
# ['Estonia', 'Tallinn', 'EE', 'EST', '+372', 'UTC+03:00', 'Euro']
# ['Ethiopia', 'Addis Ababa', 'ET', 'ETH', '+251', 'UTC+03:00', 'Ethiopian birr']
# ['Falkland Islands (Malvinas)', 'Stanley', 'FK', 'FLK', '+500', 'UTC-04:00', 'Falkland Islands pound']
# ['Faroe Islands', 'Tórshavn', 'FO', 'FRO', '+298', 'UTC', 'Danish krone']
# ['Fiji', 'Suva', 'FJ', 'FJI', '+679', 'UTC+12:00', 'Fijian dollar']
# ['Finland', 'Helsinki', 'FI', 'FIN', '+358', 'UTC+02:00', 'Euro']
# ['France', 'Paris', 'FR', 'FRA', '+33', 'UTC+01:00', 'Euro']
# ['French Guiana', 'Cayenne', 'GF', 'GUF', '+594', 'UTC-01:00', 'Euro']
# ['French Polynesia', 'Papeete', 'PF', 'PYF', '+689', 'UTC-10:00', 'CFP franc']
# ['French Southern Territories', 'Port-aux-Français', 'TF', 'ATF', '', 'UTC+05:00', 'Euro']
# ['Gabon', 'Libreville', 'GA', 'GAB', '+241', 'UTC+01:00', 'Central African CFA franc']
# ['Gambia', 'Banjul', 'GM', 'GMB', '+220', 'UTC', 'Gambian dalasi']
# ['Georgia', 'Tbilisi', 'GE', 'GEO', '+995', 'UTC+04:00', 'Georgian lari']
# ['Germany', 'Berlin', 'DE', 'DEU', '+49', 'UTC+01:00', 'Euro']
# ['Ghana', 'Accra', 'GH', 'GHA', '+233', 'UTC', 'Ghanaian cedi']
# ['Gibraltar', 'Gibraltar', 'GI', 'GIB', '+350', 'UTC+01:00', 'Gibraltar pound']
# ['Greece', 'Athens', 'GR', 'GRC', '+30', 'UTC+02:00', 'Euro']
# ['Greenland', 'Nuuk', 'GL', 'GRL', '+299', 'UTC-03:00', 'Danish krone']
# ['Grenada', "St. George's", 'GD', 'GRD', '+1 473', 'UTC-04:00', 'East Caribbean dollar']
# ['Guadeloupe', 'Basse-Terre', 'GP', 'GLP', '+590', 'UTC-04:00', 'Euro']
# ['Guam', 'Hagåtña', 'GU', 'GUM', '+1 671', 'UTC+10:00', 'United States dollar']
# ['Guatemala', 'Guatemala City', 'GT', 'GTM', '+502', 'UTC-06:00', 'Guatemalan quetzal']
# ['Guernsey', 'St. Peter Port', 'GG', 'GGY', '+44 1481', 'UTC', 'British pound']
# ['Guinea', 'Conakry', 'GN', 'GIN', '+224', 'UTC', 'Guinean franc']
# ['Guinea-Bissau', 'Bissau', 'GW', 'GNB', '+245', 'UTC', 'West African CFA franc']
# ['Guyana', 'Georgetown', 'GY', 'GUY', '+592', 'UTC-03:00', 'Guyanese dollar']
# ['Haiti', 'Port-au-Prince', 'HT', 'HTI', '+509', 'UTC-05:00', 'Haitian gourde']
# ['Heard Island and McDonald Islands', '', 'HM', 'HMD', '', 'UTC+05', '']
# ['Honduras', 'Tegucigalpa', 'HN', 'HND', '+504', 'UTC-06:00', 'Honduran lempira']
# ['Hong Kong', '', 'HK', 'HKG', '+852', 'UTC+08:00', 'Hong Kong dollar']
# ['Hungary', 'Budapest', 'HU', 'HUN', '+36', 'UTC+01:00', 'Hungarian forint']
# ['Iceland', 'Reykjavík', 'IS', 'ISL', '+354', 'UTC', 'Icelandic króna']
# ['India', 'New Delhi', 'IN', 'IND', '+91', 'UTC+05:30', 'Indian rupee']
# ['Indonesia', 'Jakarta', 'ID', 'IDN', '+62', 'UTC+07:00 - UTC+09:00', 'Indonesian rupiah']
# ['Iran', 'Tehran', 'IR', 'IRN', '+98', 'UTC+03:30', 'Iranian rial']
# ['Iraq', 'Baghdad', 'IQ', 'IRQ', '+964', 'UTC+03:00', 'Iraqi dinar']
# ['Ireland', 'Dublin', 'IE', 'IRL', '+353', 'UTC', 'Euro']
# ['Isle of Man', 'Douglas', 'IM', 'IMN', '+44 1624', 'UTC', 'British pound']
# ['Israel', 'Jerusalem', 'IL', 'ISR', '+972', 'UTC+02:00', 'Israeli new shekel']
# ['Italy', 'Rome', 'IT', 'ITA', '+39', 'UTC+01:00', 'Euro']
# ['Jamaica', 'Kingston', 'JM', 'JAM', '+1 876', 'UTC-05:00', 'Jamaican dollar']
# ['Japan', 'Tokyo', 'JP', 'JPN', '+81', 'UTC+09:00', 'Japanese yen']
# ['Jersey', 'St. Helier', 'JE', 'JEY', '+44 1534', 'UTC', 'British pound']
# ['Jordan', 'Amman', 'JO', 'JOR', '+962', 'UTC+02:00', 'Jordanian dinar']
# ['Kazakhstan', 'Astana', 'KZ', 'KAZ', '+7 6xx/7xx', 'UTC+06:00', 'Kazakhstani tenge']
# ['Kenya', 'Nairobi', 'KE', 'KEN', '+254', 'UTC+03:00', 'Kenyan shilling']
# ['Kiribati', 'Tarawa', 'KI', 'KIR', '+686', 'UTC+12:00', 'Australian dollar']
# ['Kuwait', 'Kuwait City', 'KW', 'KWT', '+965', 'UTC+03:00', 'Kuwaiti dinar']
# ['Kyrgyzstan', 'Bishkek', 'KG', 'KGZ', '+996', 'UTC+06:00', 'Kyrgyzstani som']
# ['Laos', 'Vientiane', 'LA', 'LAO', '+856', 'UTC+07:00', 'Lao kip']
# ['Latvia', 'Riga', 'LV', 'LVA', '+371', 'UTC+03:00', 'Latvian lats']
# ['Lebanon', 'Beirut', 'LB', 'LBN', '+961', 'UTC+02:00', 'Lebanese pound']
# ['Lesotho', 'Maseru', 'LS', 'LSO', '+266', 'UTC+02:00', 'Lesotho loti']
# ['Liberia', 'Monrovia', 'LR', 'LBR', '+231', 'UTC', 'Liberian dollar']
# ['Libya', 'Tripoli', 'LY', 'LBY', '+218', 'UTC+02:00', 'Libyan dinar']
# ['Liechtenstein', 'Vaduz', 'LI', 'LIE', '+423', 'UTC+01:00', 'Swiss franc']
# ['Lithuania', 'Vilnius', 'LT', 'LTU', '+370', 'UTC+02:00', 'Lithuanian litas']
# ['Luxembourg', 'Luxembourg', 'LU', 'LUX', '+352', 'UTC+01:00', 'Euro']
# ['Macau', '', 'MO', 'MAC', '+853', 'UTC+08:00', 'Macanese pataca']
# ['Macedonia', 'Skopje', 'MK', 'MKD', '+389', 'UTC+01:00', 'Macedonian denar']
# ['Madagascar', 'Antananarivo', 'MG', 'MDG', '+261', 'UTC+03:00', 'Malagasy ariary']
# ['Malawi', 'Lilongwe', 'MW', 'MWI', '+265', 'UTC+02:00', 'Malawian kwacha']
# ['Malaysia', 'Kuala Lumpur', 'MY', 'MYS', '+60', 'UTC+08:00', 'Malaysian ringgit']
# ['Maldives', 'Malé', 'MV', 'MDV', '+960', 'UTC+05:00', 'Maldivian rufiyaa']
# ['Mali', 'Bamako', 'ML', 'MLI', '+223', 'UTC', 'West African CFA franc']
# ['Malta', 'Valletta', 'MT', 'MLT', '+356', 'UTC+01:00', 'Euro']
# ['Marshall Islands', 'Majuro', 'MH', 'MHL', '+692', 'UTC+10:00', 'United States dollar']
# ['Martinique', 'Fort-de-France', 'MQ', 'MTQ', '+596', 'UTC-04:00', 'Euro']
# ['Mauritania', 'Nouakchott', 'MR', 'MRT', '+222', 'UTC', 'Mauritanian ouguiya']
# ['Mauritius', 'Port Louis', 'MU', 'MUS', '+230', 'UTC+04:00', 'Mauritian rupee']
# ['Mayotte', 'Mamoudzou', 'YT', 'MYT', '+262 269/639', 'UTC+03:00', 'Euro']
# ['Mexico', 'Mexico City', 'MX', 'MEX', '+52', 'UTC-08:00 - UTC-06:00', 'Mexican peso']
# ['Micronesia', 'Palikir', 'FM', 'FSM', '+691', 'UTC+10:00', 'Micronesian dollar']
# ['Moldova', 'Chisinau', 'MD', 'MDA', '+373', 'UTC+03:00', 'Moldovan leu']
# ['Monaco', 'Monaco', 'MC', 'MCO', '+377', 'UTC+01:00', 'Euro']
# ['Mongolia', 'Ulaanbaatar', 'MN', 'MNG', '+976', 'UTC+08:00', 'Mongolian tögrög']
# ['Montenegro', 'Podgorica', 'ME', 'MNE', '+382', 'UTC+01', 'Euro']
# ['Montserrat', 'Plymouth', 'MS', 'MSR', '+1 664', 'UTC-04:00', 'East Caribbean dollar']
# ['Morocco', 'Rabat', 'MA', 'MAR', '+212', 'UTC', 'Moroccan dirham']
# ['Mozambique', 'Maputo', 'MZ', 'MOZ', '+258', 'UTC+02:00', 'Mozambican metical']
# ['Myanmar (Burma)', 'Naypyidaw', 'MM', 'MMR', '+95', 'UTC+06:30', 'Myanma kyat']
# ['Namibia', 'Windhoek', 'NA', 'NAM', '+264', 'UTC+02:00', 'Namibian dollar']
# ['Nauru', 'Yaren', 'NR', 'NRU', '+674', 'UTC+12:00', 'Australian dollar']
# ['Nepal', 'Kathmandu', 'NP', 'NPL', '+977', 'UTC+05:30', 'Nepalese rupee']
# ['Netherlands', 'Amsterdam', 'NL', 'NLD', '+31', 'UTC+01:00', 'Euro']
# ['New Caledonia', 'Nouméa', 'NC', 'NCL', '+687', 'UTC+11:00', 'CFP franc']
# ['New Zealand', 'Wellington', 'NZ', 'NZL', '+64', 'UTC+12:00', 'New Zealand dollar']
# ['Nicaragua', 'Managua', 'NI', 'NIC', '+505', 'UTC-06:00', 'Nicaraguan córdoba']
# ['Niger', 'Niamey', 'NE', 'NER', '+227', 'UTC+01:00', 'West African CFA franc']
# ['Nigeria', 'Abuja', 'NG', 'NGA', '+234', 'UTC+01:00', 'Nigerian naira']
# ['Niue', 'Alofi', 'NU', 'NIU', '+683', 'UTC-11:00', 'New Zealand dollar']
# ['Norfolk Island', 'Kingston', 'NF', 'NFK', '+672 3', 'UTC+11:30', 'Australian dollar']
# ['North Korea', 'Pyongyang', 'KP', 'PRK', '+850', 'UTC+09:00', 'North Korean won']
# ['Northern Mariana Islands', 'Saipan', 'MP', 'MNP', '+1 670', 'UTC+10:00', 'United States dollar']
# ['Norway', 'Oslo', 'NO', 'NOR', '+47', 'UTC+01:00', 'Norwegian krone']
# ['Oman', 'Muscat', 'OM', 'OMN', '+968', 'UTC+04:00', 'Omani rial']
# ['Pakistan', 'Islamabad', 'PK', 'PAK', '+92', 'UTC+05:00', 'Pakistani rupee']
# ['Palau', 'Ngerulmud', 'PW', 'PLW', '+680', 'UTC+09:00', 'Palauan dollar']
# ['Panama', 'Panama City', 'PA', 'PAN', '+507', 'UTC-05:00', 'Panamanian balboa']
# ['Papua New Guinea', 'Port Moresby', 'PG', 'PNG', '+675', 'UTC+10:00', 'Papua New Guinean kina']
# ['Paraguay', 'Asunción', 'PY', 'PRY', '+595', 'UTC-04:00', 'Paraguayan guaraní']
# ['Peru', 'Lima', 'PE', 'PER', '+51', 'UTC-05:00', 'Peruvian nuevo sol']
# ['Philippines', 'Manila', 'PH', 'PHL', '+63', 'UTC+08:00', 'Philippine peso']
# ['Pitcairn', 'Adamstown', 'PN', 'PCN', '+872', 'UTC-08', 'New Zealand dollar']
# ['Poland', 'Warsaw', 'PL', 'POL', '+48', 'UTC+01:00', 'Polish złoty']
# ['Portugal', 'Lisbon', 'PT', 'PRT', '+351', 'UTC+01:00', 'Euro']
# ['Puerto Rico', 'San Juan', 'PR', 'PRI', '+1 787/939', 'UTC-04:00', 'United States dollar']
# ['Qatar', 'Doha', 'QA', 'QAT', '+974', 'UTC+03:00', 'Qatari riyal']
# ['Reunion', '', 'RE', 'REU', '+262', 'UTC+04:00', 'Euro']
# ['Romania', 'Bucharest', 'RO', 'ROU', '+40', 'UTC+02:00', 'Romanian leu']
# ['Russia', 'Moscow', 'RU', 'RUS', '+7', 'UTC+03:00', 'Russian ruble']
# ['Rwanda', 'Kigali', 'RW', 'RWA', '+250', 'UTC+02:00', 'Rwandan franc']
# ['Saint Barthelemy', 'Gustavia', 'BL', 'BLM', '+590', 'UTC-04', 'Euro']
# ['Saint Helena', 'Jamestown', 'SH', 'SHN', '+290', 'UTC', 'Saint Helena pound']
# ['Saint Kitts and Nevis', 'Basseterre', 'KN', 'KNA', '+1 869', 'UTC-04:00', 'East Caribbean dollar']
# ['Saint Lucia', 'Castries', 'LC', 'LCA', '+1 758', 'UTC-04:00', 'East Caribbean dollar']
# ['Saint Martin', 'Marigot', 'MF', 'MAF', '+590', 'UTC-04', 'Euro']
# ['Saint Pierre and Miquelon', 'St. Pierre', 'PM', 'SPM', '+508', 'UTC-03', 'Euro']
# ['Saint Vincent and the Grenadines', 'Kingstown', 'VC', 'VCT', '+1 784', 'UTC-04', 'East Caribbean dollar']
# ['Samoa', 'Apia', 'WS', 'WSM', '+685', 'UTC-11:00', 'Samoan tala']
# ['San Marino', 'San Marino', 'SM', 'SMR', '+378', 'UTC+01:00', 'Euro']
# ['Sao Tome and Príncipe', 'São Tomé', 'ST', 'STP', '+239', 'UTC', 'São Tomé and Príncipe dobra']
# ['Saudi Arabia', 'Riyadh', 'SA', 'SAU', '+966', 'UTC+03:00', 'Saudi riyal']
# ['Senegal', 'Dakar', 'SN', 'SEN', '+221', 'UTC', 'West African CFA franc']
# ['Serbia', 'Belgrade', 'RS', 'SRB', '+381', 'UTC+01:00', 'Serbian dinar']
# ['Seychelles', 'Victoria', 'SC', 'SYC', '+248', 'UTC+04:00', 'Seychellois rupee']
# ['Sierra Leone', 'Freetown', 'SL', 'SLE', '+232', 'UTC', 'Sierra Leonean leone']
# ['Singapore', 'Singapore', 'SG', 'SGP', '+65', 'UTC+08:00', 'Brunei dollar']
# ['Sint Maarten', 'Philipsburg', 'SX', 'SXM', '+599 5', 'UTC-04:00', 'Netherlands Antillean guilder']
# ['Slovakia', 'Bratislava', 'SK', 'SVK', '+421', 'UTC+01:00', 'Euro']
# ['Slovenia', 'Ljubljana', 'SI', 'SVN', '+386', 'UTC+01:00', 'Euro']
# ['Solomon Islands', 'Honiara', 'SB', 'SLB', '+677', 'UTC+11:00', 'Solomon Islands dollar']
# ['Somalia', 'Mogadishu', 'SO', 'SOM', '+252', 'UTC+03:00', 'Somali shilling']
# ['South Africa', 'Pretoria', 'ZA', 'ZAF', '+27', 'UTC+02:00', 'South African rand']
# ['South Georgia and the South Sandwich Islands', 'Grytviken', 'GS', 'SGS', '', 'UTC-02', 'British pound']
# ['South Korea', 'Seoul', 'KR', 'KOR', '+82', 'UTC+09:00', 'South Korean won']
# ['Spain', 'Madrid', 'ES', 'ESP', '+34', 'UTC+01:00', 'Euro']
# ['Sri Lanka', 'Sri Jayawardenapura Kotte', 'LK', 'LKA', '+94', 'UTC+05:30', 'Sri Lankan rupee']
# ['Sudan', 'Khartoum', 'SD', 'SDN', '+249', 'UTC+02:00', 'Sudanese pound']
# ['Suriname', 'Paramaribo', 'SR', 'SUR', '+597', 'UTC-03:30', 'Surinamese dollar']
# ['Svalbard and Jan Mayen', '', 'SJ', 'SJM', '+47', 'UTC+01:00', 'Norwegian krone']
# ['Swaziland', 'Mbabane', 'SZ', 'SWZ', '+268', 'UTC+02:00', 'Swazi lilangeni']
# ['Sweden', 'Stockholm', 'SE', 'SWE', '+46', 'UTC+01:00', 'Swedish krona']
# ['Switzerland', 'Bern', 'CH', 'CHE', '+41', 'UTC+01:00', 'Swiss franc']
# ['Syrian Arab Republic', 'Damascus', 'SY', 'SYR', '+963', 'UTC+02:00', 'Syrian pound']
# ['Taiwan', 'Taipei', 'TW', 'TWN', '+886', 'UTC+08:00', 'New Taiwan dollar']
# ['Tajikistan', 'Dushanbe', 'TJ', 'TJK', '+992', 'UTC+06:00', 'Tajikistani somoni']
# ['Tanzania', 'Dodoma', 'TZ', 'TZA', '+255', 'UTC+03:00', 'Tanzanian shilling']
# ['Thailand', 'Bangkok', 'TH', 'THA', '+66', 'UTC+07:00', 'Thai baht']
# ['Togo', 'Lomé', 'TG', 'TGO', '+228', 'UTC', 'West African CFA franc']
# ['Tokelau', 'Rotates annually', 'TK', 'TKL', '+690', 'UTC-10', 'New Zealand dollar']
# ['Tonga', 'Nuku', 'TO', 'TON', '+676', 'UTC+13:00', 'Tongan paʻanga']
# ['Trinidad and Tobago', 'Port of Spain', 'TT', 'TTO', '+1 868', 'UTC-04:00', 'Trinidad and Tobago dollar']
# ['Tunisia', 'Tunis', 'TN', 'TUN', '+216', 'UTC+01:00', 'Tunisian dinar']
# ['Turkey', 'Ankara', 'TR', 'TUR', '+90', 'UTC+02:00', 'Turkish lira']
# ['Turkmenistan', 'Ashgabat', 'TM', 'TKM', '+993', 'UTC+05:00', 'Turkmenistani manat']
# ['Turks and Caicos Islands', 'Cockburn Town', 'TC', 'TCA', '+1 649', 'UTC-05:00', 'United States dollar']
# ['Tuvalu', 'Funafuti', 'TV', 'TUV', '+688', 'UTC+12:00', 'Australian dollar']
# ['Uganda', 'Kampala', 'UG', 'UGA', '+256', 'UTC+03:00', 'Ugandan shilling']
# ['Ukraine', 'Kyiv', 'UA', 'UKR', '+380', 'UTC+03:00', 'Ukrainian hryvnia']
# ['United Arab Emirates', 'Abu Dhabi', 'AE', 'ARE', '+971', 'UTC+04:00', 'United Arab Emirates dirham']
# ['United Kingdom', 'London', 'GB', 'GBR', '+44', 'UTC', 'British pound']
# ['United States', 'Washington D.C.', 'US', 'USA', '+1', 'UTC-11:00 - UTC-05:00', 'United States dollar']
# ['United States Minor Outlying Islands', '', 'UM', 'UMI', '+1', '', 'United States dollar']
# ['Uruguay', 'Montevideo', 'UY', 'URY', '+598', 'UTC-03:00', 'Uruguayan peso']
# ['Uzbekistan', 'Tashkent', 'UZ', 'UZB', '+998', 'UTC+06:00', 'Uzbekistani som']
# ['Vanuatu', 'Port Vila', 'VU', 'VUT', '+678', 'UTC+11:00', 'Vanuatu vatu']
# ['Vatican City', 'Vatican City', 'VA', 'VAT', '+39 06 698', 'UTC+01', 'Euro']
# ['Venezuela', 'Caracas', 'VE', 'VEN', '+58', 'UTC-04:00', 'Venezuelan bolívar']
# ['Vietnam', 'Hanoi', 'VN', 'VNM', '+84', 'UTC+07:00', 'Vietnamese đồng']
# ['Virgin Islands', 'Road Town', 'VG', 'VGB', '+1 284', 'UTC-04', 'British Virgin Islands dollar']
# ['Virgin Islands of the United States', 'Charlotte Amalie', 'VI', 'VIR', '+1 340', 'UTC-04', 'United States dollar']
# ['Wallis and Futuna', 'Mata-Utu', 'WF', 'WLF', '+681', 'UTC+12:00', 'CFP franc']
# ['Western Sahara', 'Laâyoune (El Aaiún)', 'EH', 'ESH', '+212 5288/5289', 'UTC+01', 'Moroccan dirham']
# ['Yemen', 'Sanaá', 'YE', 'YEM', '+967', 'UTC+03:00', 'Yemeni rial']
# ['Zambia', 'Lusaka', 'ZM', 'ZMB', '+260', 'UTC+02:00', 'Zambian kwacha']
# ['Zimbabwe', 'Harare', 'ZW', 'ZWE', '+263', 'UTC+02:00', 'Zimbabwean dollar']

# %%
for attribute in attributes:
    print(f"{attribute}: {getattr(countries_dialect, attribute)}")
# Out:
# delimiter: |
# doublequote: False
# escapechar: None
# lineterminator:
#
# quotechar: "
# quoting: 0
# skipinitialspace: True

# %% [markdown]
# **Now the `skipinitialspace` attribute is set to True, and any leading whitespace has been been removed when reading in the file.**
#
# **Even though it says there are no special line termination characters, this does not mean there is no default character in place. To see how a line really ends, you can use the `repr()` function to see what is really there.**

# %%
for attribute in attributes:
    print(f"{attribute}: {repr(getattr(countries_dialect, attribute))}")
# Out:
# delimiter: '|'
# doublequote: False
# escapechar: None
# lineterminator: '\r\n'
# quotechar: '"'
# quoting: 0
# skipinitialspace: True

# %% [markdown]
# **The `lineterminator` actually contains newline (`\n`) and line feed (`\r`) characters.**

# %% [markdown]
# ## Using `csv.DictReader()` class
#
# **The `DictReader()` class behaves like the normal `csv.reader()` function, with the same parameters, except it parses each row directly into a Python dictionary.**
#
# **CSV File:**
#
#     "Cereal","Calories","Fat","Protein","Fibre","Vitamin E"
#     "Barley",556,1.7,32.9,10.1,13.8
#     "Durum",339,5,27.4,4.09,9.7
#     ...

# %%
csv_filename = 'data/cereal_grains.csv'

with open(csv_filename, encoding='utf-8', newline='') as cereals:
    reader = csv.DictReader(cereals)
    for row in reader:
        print(row)
# Out:
# {'Cereal': 'Barley', 'Calories': '556', 'Fat': '1.7', 'Protein': '32.9', 'Fibre': '10.1', 'Vitamin E': '13.8'}
# {'Cereal': 'Durum', 'Calories': '339', 'Fat': '5', 'Protein': '27.4', 'Fibre': '4.09', 'Vitamin E': '9.7'}
# {'Cereal': 'Fonio', 'Calories': '240', 'Fat': '1', 'Protein': '4', 'Fibre': '1.7', 'Vitamin E': '0.05'}
# {'Cereal': 'Maize', 'Calories': '442', 'Fat': '7.4', 'Protein': '37.45', 'Fibre': '6.15', 'Vitamin E': '11.03'}
# {'Cereal': 'Millet', 'Calories': '484', 'Fat': '2', 'Protein': '37.9', 'Fibre': '13.4', 'Vitamin E': '9.15'}
# {'Cereal': 'Oats', 'Calories': '231', 'Fat': '9.2', 'Protein': '35.1', 'Fibre': '10.3', 'Vitamin E': '3.73'}
# {'Cereal': 'Rice (Brown)', 'Calories': '346', 'Fat': '2.8', 'Protein': '38.1', 'Fibre': '9.9', 'Vitamin E': '0.8'}
# {'Cereal': 'Rice (White)', 'Calories': '345', 'Fat': '3.6', 'Protein': '37.6', 'Fibre': '5.4', 'Vitamin E': '0.1'}
# {'Cereal': 'Rye', 'Calories': '422', 'Fat': '2', 'Protein': '31.4', 'Fibre': '18.2', 'Vitamin E': '21.2'}
# {'Cereal': 'Sorghum', 'Calories': '316', 'Fat': '3', 'Protein': '37.8', 'Fibre': '9.92', 'Vitamin E': '9.15'}
# {'Cereal': 'Triticale', 'Calories': '338', 'Fat': '1.81', 'Protein': '36.6', 'Fibre': '19', 'Vitamin E': '0.9'}
# {'Cereal': 'Wheat', 'Calories': '407', 'Fat': '1.2', 'Protein': '27.8', 'Fibre': '12.9', 'Vitamin E': '13.8'}

# %% [markdown]
# **You can use `csv.DictReader()` class to read in text or JSON files directly to dictionary formmat.**
#
# **You can also read in text files using DictReader. Using country_info.txt, the country names should be the keys and the values in nested dictionaries. Treat the text file as if it were CSV, i.e. include `newline` argument.**
#
# **Text File:**
#
#     Country|Capital|CC|CC3|IAC|TimeZone|Currency
#     Afghanistan|Kabul|AF|AFG|+93|UTC+04:30|Afghan afghani
#     Aland Islands|Mariehamn|AX|ALA|+358|UTC+02:00|Euro
#     Albania|Tirana|AL|ALB|+355|UTC+01:00|Albanian lek
#     ...

# %%
countries_input = 'data/country_info.txt'

with open(countries_input, encoding='utf-8', newline='') as countries:
    dict_reader = csv.DictReader(countries, delimiter='|')
    
    for row in dict_reader:
        print(f"{row['Country']}")
        print(f"\tThe capital is {row['Capital']}")
# Out:
# Afghanistan
# 	The capital is Kabul
# Aland Islands
# 	The capital is Mariehamn
# Albania
# 	The capital is Tirana
# Algeria
# 	The capital is Algiers
# American Samoa
# 	The capital is Pago Pago
# Andorra
# 	The capital is Andorra la Vella
# Angola
# 	The capital is Luanda
# Anguilla
# 	The capital is The Valley
# Antarctica
# 	The capital is
# Antigua and Barbuda
# 	The capital is St. John's
# Argentina
# 	The capital is Buenos Aires
# Armenia
# 	The capital is Yerevan
# Aruba
# 	The capital is Oranjestad
# Australia
# 	The capital is Canberra
# Austria
# 	The capital is Vienna
# Azerbaijan
# 	The capital is Baku
# Bahamas
# 	The capital is Nassau
# Bahrain
# 	The capital is Manama
# Bangladesh
# 	The capital is Dhaka
# Barbados
# 	The capital is Bridgetown
# Belarus
# 	The capital is Minsk
# Belgium
# 	The capital is Brussels
# Belize
# 	The capital is Belmopan
# Benin
# 	The capital is Porto-Novo
# Bermuda
# 	The capital is Hamilton
# Bhutan
# 	The capital is Thimphu
# Bolivia
# 	The capital is Sucre
# Bonaire
# 	The capital is Kralendijk
# Bosnia and Herzegovina
# 	The capital is Sarajevo
# Botswana
# 	The capital is Gaborone
# Bouvet Island
# 	The capital is
# Brazil
# 	The capital is Brasília
# British Indian Ocean Territory
# 	The capital is Diego Garcia
# Brunei
# 	The capital is Bandar Seri Begawan
# Bulgaria
# 	The capital is Sofia
# Burkina Faso
# 	The capital is Ouagadougou
# Burundi
# 	The capital is Bujumbura
# Cambodia
# 	The capital is Phnom Penh
# Cameroon
# 	The capital is Yaoundé
# Canada
# 	The capital is Ottawa
# Cape Verde
# 	The capital is Praia
# Cayman Islands
# 	The capital is George Town
# Central African Republic
# 	The capital is Bangui
# Chad
# 	The capital is N'Djamena
# Chile
# 	The capital is Santiago
# China
# 	The capital is Beijing
# Christmas Island
# 	The capital is Flying Fish Cove
# Cocos (Keeling) Islands
# 	The capital is West Island
# Colombia
# 	The capital is Bogotá
# Comoros
# 	The capital is Moroni
# Congo, Republic of the
# 	The capital is Brazzaville
# Congo, Democratic Republic of the
# 	The capital is Kinshasa
# Cook Islands
# 	The capital is Avarua
# Costa Rica
# 	The capital is San José
# Côte d'Ivoire
# 	The capital is Yamoussoukro
# Croatia
# 	The capital is Zagreb
# Cuba
# 	The capital is Havana
# Curacao
# 	The capital is Willemstad
# Cyprus
# 	The capital is Nicosia
# Czech Republic
# 	The capital is Prague
# Denmark
# 	The capital is Copenhagen
# Djibouti
# 	The capital is Djibouti
# Dominica
# 	The capital is Roseau
# Dominican Republic
# 	The capital is Santo Domingo
# East Timor
# 	The capital is Dili
# Ecuador
# 	The capital is Quito
# Egypt
# 	The capital is Cairo
# El Salvador
# 	The capital is San Salvador
# Equatorial Guinea
# 	The capital is Malabo
# Eritrea
# 	The capital is Asmara
# Estonia
# 	The capital is Tallinn
# Ethiopia
# 	The capital is Addis Ababa
# Falkland Islands (Malvinas)
# 	The capital is Stanley
# Faroe Islands
# 	The capital is Tórshavn
# Fiji
# 	The capital is Suva
# Finland
# 	The capital is Helsinki
# France
# 	The capital is Paris
# French Guiana
# 	The capital is Cayenne
# French Polynesia
# 	The capital is Papeete
# French Southern Territories
# 	The capital is Port-aux-Français
# Gabon
# 	The capital is Libreville
# Gambia
# 	The capital is Banjul
# Georgia
# 	The capital is Tbilisi
# Germany
# 	The capital is Berlin
# Ghana
# 	The capital is Accra
# Gibraltar
# 	The capital is Gibraltar
# Greece
# 	The capital is Athens
# Greenland
# 	The capital is Nuuk
# Grenada
# 	The capital is St. George's
# Guadeloupe
# 	The capital is Basse-Terre
# Guam
# 	The capital is Hagåtña
# Guatemala
# 	The capital is Guatemala City
# Guernsey
# 	The capital is St. Peter Port
# Guinea
# 	The capital is Conakry
# Guinea-Bissau
# 	The capital is Bissau
# Guyana
# 	The capital is Georgetown
# Haiti
# 	The capital is Port-au-Prince
# Heard Island and McDonald Islands
# 	The capital is
# Honduras
# 	The capital is Tegucigalpa
# Hong Kong
# 	The capital is
# Hungary
# 	The capital is Budapest
# Iceland
# 	The capital is Reykjavík
# India
# 	The capital is New Delhi
# Indonesia
# 	The capital is Jakarta
# Iran
# 	The capital is Tehran
# Iraq
# 	The capital is Baghdad
# Ireland
# 	The capital is Dublin
# Isle of Man
# 	The capital is Douglas
# Israel
# 	The capital is Jerusalem
# Italy
# 	The capital is Rome
# Jamaica
# 	The capital is Kingston
# Japan
# 	The capital is Tokyo
# Jersey
# 	The capital is St. Helier
# Jordan
# 	The capital is Amman
# Kazakhstan
# 	The capital is Astana
# Kenya
# 	The capital is Nairobi
# Kiribati
# 	The capital is Tarawa
# Kuwait
# 	The capital is Kuwait City
# Kyrgyzstan
# 	The capital is Bishkek
# Laos
# 	The capital is Vientiane
# Latvia
# 	The capital is Riga
# Lebanon
# 	The capital is Beirut
# Lesotho
# 	The capital is Maseru
# Liberia
# 	The capital is Monrovia
# Libya
# 	The capital is Tripoli
# Liechtenstein
# 	The capital is Vaduz
# Lithuania
# 	The capital is Vilnius
# Luxembourg
# 	The capital is Luxembourg
# Macau
# 	The capital is
# Macedonia
# 	The capital is Skopje
# Madagascar
# 	The capital is Antananarivo
# Malawi
# 	The capital is Lilongwe
# Malaysia
# 	The capital is Kuala Lumpur
# Maldives
# 	The capital is Malé
# Mali
# 	The capital is Bamako
# Malta
# 	The capital is Valletta
# Marshall Islands
# 	The capital is Majuro
# Martinique
# 	The capital is Fort-de-France
# Mauritania
# 	The capital is Nouakchott
# Mauritius
# 	The capital is Port Louis
# Mayotte
# 	The capital is Mamoudzou
# Mexico
# 	The capital is Mexico City
# Micronesia
# 	The capital is Palikir
# Moldova
# 	The capital is Chisinau
# Monaco
# 	The capital is Monaco
# Mongolia
# 	The capital is Ulaanbaatar
# Montenegro
# 	The capital is Podgorica
# Montserrat
# 	The capital is Plymouth
# Morocco
# 	The capital is Rabat
# Mozambique
# 	The capital is Maputo
# Myanmar (Burma)
# 	The capital is Naypyidaw
# Namibia
# 	The capital is Windhoek
# Nauru
# 	The capital is Yaren
# Nepal
# 	The capital is Kathmandu
# Netherlands
# 	The capital is Amsterdam
# New Caledonia
# 	The capital is Nouméa
# New Zealand
# 	The capital is Wellington
# Nicaragua
# 	The capital is Managua
# Niger
# 	The capital is Niamey
# Nigeria
# 	The capital is Abuja
# Niue
# 	The capital is Alofi
# Norfolk Island
# 	The capital is Kingston
# North Korea
# 	The capital is Pyongyang
# Northern Mariana Islands
# 	The capital is Saipan
# Norway
# 	The capital is Oslo
# Oman
# 	The capital is Muscat
# Pakistan
# 	The capital is Islamabad
# Palau
# 	The capital is Ngerulmud
# Panama
# 	The capital is Panama City
# Papua New Guinea
# 	The capital is Port Moresby
# Paraguay
# 	The capital is Asunción
# Peru
# 	The capital is Lima
# Philippines
# 	The capital is Manila
# Pitcairn
# 	The capital is Adamstown
# Poland
# 	The capital is Warsaw
# Portugal
# 	The capital is Lisbon
# Puerto Rico
# 	The capital is San Juan
# Qatar
# 	The capital is Doha
# Reunion
# 	The capital is
# Romania
# 	The capital is Bucharest
# Russia
# 	The capital is Moscow
# Rwanda
# 	The capital is Kigali
# Saint Barthelemy
# 	The capital is Gustavia
# Saint Helena
# 	The capital is Jamestown
# Saint Kitts and Nevis
# 	The capital is Basseterre
# Saint Lucia
# 	The capital is Castries
# Saint Martin
# 	The capital is Marigot
# Saint Pierre and Miquelon
# 	The capital is St. Pierre
# Saint Vincent and the Grenadines
# 	The capital is Kingstown
# Samoa
# 	The capital is Apia
# San Marino
# 	The capital is San Marino
# Sao Tome and Príncipe
# 	The capital is São Tomé
# Saudi Arabia
# 	The capital is Riyadh
# Senegal
# 	The capital is Dakar
# Serbia
# 	The capital is Belgrade
# Seychelles
# 	The capital is Victoria
# Sierra Leone
# 	The capital is Freetown
# Singapore
# 	The capital is Singapore
# Sint Maarten
# 	The capital is Philipsburg
# Slovakia
# 	The capital is Bratislava
# Slovenia
# 	The capital is Ljubljana
# Solomon Islands
# 	The capital is Honiara
# Somalia
# 	The capital is Mogadishu
# South Africa
# 	The capital is Pretoria
# South Georgia and the South Sandwich Islands
# 	The capital is Grytviken
# South Korea
# 	The capital is Seoul
# Spain
# 	The capital is Madrid
# Sri Lanka
# 	The capital is Sri Jayawardenapura Kotte
# Sudan
# 	The capital is Khartoum
# Suriname
# 	The capital is Paramaribo
# Svalbard and Jan Mayen
# 	The capital is
# Swaziland
# 	The capital is Mbabane
# Sweden
# 	The capital is Stockholm
# Switzerland
# 	The capital is Bern
# Syrian Arab Republic
# 	The capital is Damascus
# Taiwan
# 	The capital is Taipei
# Tajikistan
# 	The capital is Dushanbe
# Tanzania
# 	The capital is Dodoma
# Thailand
# 	The capital is Bangkok
# Togo
# 	The capital is Lomé
# Tokelau
# 	The capital is Rotates annually
# Tonga
# 	The capital is Nuku
# Trinidad and Tobago
# 	The capital is Port of Spain
# Tunisia
# 	The capital is Tunis
# Turkey
# 	The capital is Ankara
# Turkmenistan
# 	The capital is Ashgabat
# Turks and Caicos Islands
# 	The capital is Cockburn Town
# Tuvalu
# 	The capital is Funafuti
# Uganda
# 	The capital is Kampala
# Ukraine
# 	The capital is Kyiv
# United Arab Emirates
# 	The capital is Abu Dhabi
# United Kingdom
# 	The capital is London
# United States
# 	The capital is Washington D.C.
# United States Minor Outlying Islands
# 	The capital is
# Uruguay
# 	The capital is Montevideo
# Uzbekistan
# 	The capital is Tashkent
# Vanuatu
# 	The capital is Port Vila
# Vatican City
# 	The capital is Vatican City
# Venezuela
# 	The capital is Caracas
# Vietnam
# 	The capital is Hanoi
# Virgin Islands
# 	The capital is Road Town
# Virgin Islands of the United States
# 	The capital is Charlotte Amalie
# Wallis and Futuna
# 	The capital is Mata-Utu
# Western Sahara
# 	The capital is Laâyoune (El Aaiún)
# Yemen
# 	The capital is Sanaá
# Zambia
# 	The capital is Lusaka
# Zimbabwe
# 	The capital is  Harare

# %% [markdown]
# ### Customized key names
#
# **The column headings start with capital letters, i.e. proper case, which goes against the naming convention for dictionary keys. You can specify a customized list of key names, especially for cases when there are no column headings in the source file at all.**
#
# **In CSV module, there are three registered dialects built in to deal with common format types, like Excel:**
#
# * **`csv.excel`**
# * **`csv.excel_tab`**
# * **`csv.unix_dialect`**
#
# **You can change the settings in a dialect object to apply new rules to how the data is read in.**

# %%
excel_dialect = csv.excel

# Change delimiter to pipe char (instead of comma)
excel_dialect.delimiter = '|'

# %%
with open(countries_input, encoding='utf-8', newline='') as countries:
    headings = countries.readline().strip('\n').split(excel_dialect.delimiter)
    # Lowercase the headings
    for index, heading in enumerate(headings):
        headings[index] = heading.casefold()
    
    dict_reader = csv.DictReader(countries, fieldnames=headings, dialect=excel_dialect)
    
    for row in dict_reader:
        print(row)
# Out:
# {'country': 'Afghanistan', 'capital': 'Kabul', 'cc': 'AF', 'cc3': 'AFG', 'iac': '+93', 'timezone': 'UTC+04:30', 'currency': 'Afghan afghani'}
# {'country': 'Aland Islands', 'capital': 'Mariehamn', 'cc': 'AX', 'cc3': 'ALA', 'iac': '+358', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'country': 'Albania', 'capital': 'Tirana', 'cc': 'AL', 'cc3': 'ALB', 'iac': '+355', 'timezone': 'UTC+01:00', 'currency': 'Albanian lek'}
# {'country': 'Algeria', 'capital': 'Algiers', 'cc': 'DZ', 'cc3': 'DZA', 'iac': '+213', 'timezone': 'UTC', 'currency': 'Algerian dinar'}
# {'country': 'American Samoa', 'capital': 'Pago Pago', 'cc': 'AS', 'cc3': 'ASM', 'iac': '+1 684', 'timezone': 'UTC-11:00', 'currency': ''}
# {'country': 'Andorra', 'capital': 'Andorra la Vella', 'cc': 'AD', 'cc3': 'AND', 'iac': '+376', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Angola', 'capital': 'Luanda', 'cc': 'AO', 'cc3': 'AGO', 'iac': '+244', 'timezone': 'UTC+01:00', 'currency': 'Angolan kwanza'}
# {'country': 'Anguilla', 'capital': 'The Valley', 'cc': 'AI', 'cc3': 'AIA', 'iac': '+1 264', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Antarctica', 'capital': '', 'cc': 'AQ', 'cc3': 'ATA', 'iac': '', 'timezone': '', 'currency': ''}
# {'country': 'Antigua and Barbuda', 'capital': "St. John's", 'cc': 'AG', 'cc3': 'ATG', 'iac': '+1 268', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Argentina', 'capital': 'Buenos Aires', 'cc': 'AR', 'cc3': 'ARG', 'iac': '+54', 'timezone': 'UTC-03:00', 'currency': 'Argentine peso'}
# {'country': 'Armenia', 'capital': 'Yerevan', 'cc': 'AM', 'cc3': 'ARM', 'iac': '+374', 'timezone': 'UTC+04:00', 'currency': 'Armenian dram'}
# {'country': 'Aruba', 'capital': 'Oranjestad', 'cc': 'AW', 'cc3': 'ABW', 'iac': '+297', 'timezone': 'UTC-04:00', 'currency': 'Aruban florin'}
# {'country': 'Australia', 'capital': 'Canberra', 'cc': 'AU', 'cc3': 'AUS', 'iac': '+61', 'timezone': 'UTC+07:00 - UTC+10:00', 'currency': 'Australian dollar'}
# {'country': 'Austria', 'capital': 'Vienna', 'cc': 'AT', 'cc3': 'AUT', 'iac': '+43', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Azerbaijan', 'capital': 'Baku', 'cc': 'AZ', 'cc3': 'AZE', 'iac': '+994', 'timezone': 'UTC+04:00', 'currency': 'Azerbaijani manat'}
# {'country': 'Bahamas', 'capital': 'Nassau', 'cc': 'BS', 'cc3': 'BHS', 'iac': '+1 242', 'timezone': 'UTC-05:00', 'currency': 'Bahamian dollar'}
# {'country': 'Bahrain', 'capital': 'Manama', 'cc': 'BH', 'cc3': 'BHR', 'iac': '+973', 'timezone': 'UTC+03:00', 'currency': 'Bahraini dinar'}
# {'country': 'Bangladesh', 'capital': 'Dhaka', 'cc': 'BD', 'cc3': 'BGD', 'iac': '+880', 'timezone': 'UTC+06:00', 'currency': 'Bangladeshi taka'}
# {'country': 'Barbados', 'capital': 'Bridgetown', 'cc': 'BB', 'cc3': 'BRB', 'iac': '+1 246', 'timezone': 'UTC-04:00', 'currency': 'Barbadian dollar'}
# {'country': 'Belarus', 'capital': 'Minsk', 'cc': 'BY', 'cc3': 'BLR', 'iac': '+375', 'timezone': 'UTC+03:00', 'currency': 'Belarusian ruble'}
# {'country': 'Belgium', 'capital': 'Brussels', 'cc': 'BE', 'cc3': 'BEL', 'iac': '+32', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Belize', 'capital': 'Belmopan', 'cc': 'BZ', 'cc3': 'BLZ', 'iac': '+501', 'timezone': 'UTC-06:00', 'currency': 'Belize dollar'}
# {'country': 'Benin', 'capital': 'Porto-Novo', 'cc': 'BJ', 'cc3': 'BEN', 'iac': '+229', 'timezone': 'UTC+01:00', 'currency': 'West African CFA franc'}
# {'country': 'Bermuda', 'capital': 'Hamilton', 'cc': 'BM', 'cc3': 'BMU', 'iac': '+1 441', 'timezone': 'UTC-04:00', 'currency': 'Bermudian dollar'}
# {'country': 'Bhutan', 'capital': 'Thimphu', 'cc': 'BT', 'cc3': 'BTN', 'iac': '+975', 'timezone': 'UTC+05:30', 'currency': 'Bhutanese ngultrum'}
# {'country': 'Bolivia', 'capital': 'Sucre', 'cc': 'BO', 'cc3': 'BOL', 'iac': '+591', 'timezone': 'UTC-04:00', 'currency': 'Bolivian boliviano'}
# {'country': 'Bonaire', 'capital': 'Kralendijk', 'cc': 'BQ', 'cc3': 'BES', 'iac': '+599', 'timezone': 'UTC-04:00', 'currency': 'United States dollar'}
# {'country': 'Bosnia and Herzegovina', 'capital': 'Sarajevo', 'cc': 'BA', 'cc3': 'BIH', 'iac': '+387', 'timezone': 'UTC+01:00', 'currency': 'Bosnia and Herzegovina convertible mark'}
# {'country': 'Botswana', 'capital': 'Gaborone', 'cc': 'BW', 'cc3': 'BWA', 'iac': '+267', 'timezone': 'UTC+02:00', 'currency': 'Botswana pula'}
# {'country': 'Bouvet Island', 'capital': '', 'cc': 'BV', 'cc3': 'BVT', 'iac': '', 'timezone': 'UTC+01:00', 'currency': ''}
# {'country': 'Brazil', 'capital': 'Brasília', 'cc': 'BR', 'cc3': 'BRA', 'iac': '+55', 'timezone': 'UTC-05:00 - UTC-03:00', 'currency': 'Brazilian real'}
# {'country': 'British Indian Ocean Territory', 'capital': 'Diego Garcia', 'cc': 'IO', 'cc3': 'IOT', 'iac': '+246', 'timezone': 'UTC+06', 'currency': 'United States dollar'}
# {'country': 'Brunei', 'capital': 'Bandar Seri Begawan', 'cc': 'BN', 'cc3': 'BRN', 'iac': '+673', 'timezone': 'UTC+08:00', 'currency': 'Brunei dollar'}
# {'country': 'Bulgaria', 'capital': 'Sofia', 'cc': 'BG', 'cc3': 'BGR', 'iac': '+359', 'timezone': 'UTC+02:00', 'currency': 'Bulgarian lev'}
# {'country': 'Burkina Faso', 'capital': 'Ouagadougou', 'cc': 'BF', 'cc3': 'BFA', 'iac': '+226', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Burundi', 'capital': 'Bujumbura', 'cc': 'BI', 'cc3': 'BDI', 'iac': '+257', 'timezone': 'UTC+02:00', 'currency': 'Burundian franc'}
# {'country': 'Cambodia', 'capital': 'Phnom Penh', 'cc': 'KH', 'cc3': 'KHM', 'iac': '+855', 'timezone': 'UTC+07:00', 'currency': 'Cambodian riel'}
# {'country': 'Cameroon', 'capital': 'Yaoundé', 'cc': 'CM', 'cc3': 'CMR', 'iac': '+237', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Canada', 'capital': 'Ottawa', 'cc': 'CA', 'cc3': 'CAN', 'iac': '+1', 'timezone': 'UTC-08:00 - UTC-04:00', 'currency': 'Canadian dollar'}
# {'country': 'Cape Verde', 'capital': 'Praia', 'cc': 'CV', 'cc3': 'CPV', 'iac': '+238', 'timezone': 'UTC-01:00', 'currency': 'Cape Verdean escudo'}
# {'country': 'Cayman Islands', 'capital': 'George Town', 'cc': 'KY', 'cc3': 'CYM', 'iac': '+1 345', 'timezone': 'UTC-05:00', 'currency': 'Cayman Islands dollar'}
# {'country': 'Central African Republic', 'capital': 'Bangui', 'cc': 'CF', 'cc3': 'CAF', 'iac': '+236', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Chad', 'capital': "N'Djamena", 'cc': 'TD', 'cc3': 'TCD', 'iac': '+235', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Chile', 'capital': 'Santiago', 'cc': 'CL', 'cc3': 'CHL', 'iac': '+56', 'timezone': 'UTC-04:00', 'currency': 'Chilean peso'}
# {'country': 'China', 'capital': 'Beijing', 'cc': 'CN', 'cc3': 'CHN', 'iac': '+86', 'timezone': 'UTC+08:00', 'currency': 'Chinese yuan'}
# {'country': 'Christmas Island', 'capital': 'Flying Fish Cove', 'cc': 'CX', 'cc3': 'CXR', 'iac': '+61 8 9164', 'timezone': 'UTC+07', 'currency': 'Australian dollar'}
# {'country': 'Cocos (Keeling) Islands', 'capital': 'West Island', 'cc': 'CC', 'cc3': 'CCK', 'iac': '+61 8 9162', 'timezone': 'UTC+06:30', 'currency': 'Australian dollar'}
# {'country': 'Colombia', 'capital': 'Bogotá', 'cc': 'CO', 'cc3': 'COL', 'iac': '+57', 'timezone': 'UTC-05:00', 'currency': 'Colombian peso'}
# {'country': 'Comoros', 'capital': 'Moroni', 'cc': 'KM', 'cc3': 'COM', 'iac': '+269', 'timezone': 'UTC+03:00', 'currency': 'Comorian franc'}
# {'country': 'Congo, Republic of the', 'capital': 'Brazzaville', 'cc': 'CG', 'cc3': 'COG', 'iac': '+242', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Congo, Democratic Republic of the', 'capital': 'Kinshasa', 'cc': 'CD', 'cc3': 'COD', 'iac': '+243', 'timezone': 'UTC+01:00 - UTC+02:00', 'currency': 'Congolese franc'}
# {'country': 'Cook Islands', 'capital': 'Avarua', 'cc': 'CK', 'cc3': 'COK', 'iac': '+682', 'timezone': 'UTC-10:00', 'currency': 'New Zealand dollar'}
# {'country': 'Costa Rica', 'capital': 'San José', 'cc': 'CR', 'cc3': 'CRI', 'iac': '+506', 'timezone': 'UTC-06:00', 'currency': 'Costa Rican colón'}
# {'country': "Côte d'Ivoire", 'capital': 'Yamoussoukro', 'cc': 'CI', 'cc3': 'CIV', 'iac': '+225', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Croatia', 'capital': 'Zagreb', 'cc': 'HR', 'cc3': 'HRV', 'iac': '+385', 'timezone': 'UTC+01:00', 'currency': 'Croatian kuna'}
# {'country': 'Cuba', 'capital': 'Havana', 'cc': 'CU', 'cc3': 'CUB', 'iac': '+53', 'timezone': 'UTC-03:00', 'currency': 'Cuban convertible peso'}
# {'country': 'Curacao', 'capital': 'Willemstad', 'cc': 'CW', 'cc3': 'CUW', 'iac': '+599 9', 'timezone': 'UTC-04:00', 'currency': 'Netherlands Antillean guilder'}
# {'country': 'Cyprus', 'capital': 'Nicosia', 'cc': 'CY', 'cc3': 'CYP', 'iac': '+357', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'country': 'Czech Republic', 'capital': 'Prague', 'cc': 'CZ', 'cc3': 'CZE', 'iac': '+420', 'timezone': 'UTC+01:00', 'currency': 'Czech koruna'}
# {'country': 'Denmark', 'capital': 'Copenhagen', 'cc': 'DK', 'cc3': 'DNK', 'iac': '+45', 'timezone': 'UTC+01:00', 'currency': 'Danish krone'}
# {'country': 'Djibouti', 'capital': 'Djibouti', 'cc': 'DJ', 'cc3': 'DJI', 'iac': '+253', 'timezone': 'UTC+03:00', 'currency': 'Djiboutian franc'}
# {'country': 'Dominica', 'capital': 'Roseau', 'cc': 'DM', 'cc3': 'DMA', 'iac': '+1 767', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Dominican Republic', 'capital': 'Santo Domingo', 'cc': 'DO', 'cc3': 'DOM', 'iac': '+1 809/829/849', 'timezone': 'UTC-04:00', 'currency': 'Dominican peso'}
# {'country': 'East Timor', 'capital': 'Dili', 'cc': 'TL', 'cc3': 'TLS', 'iac': '+670', 'timezone': 'UTC+09', 'currency': 'United States dollar'}
# {'country': 'Ecuador', 'capital': 'Quito', 'cc': 'EC', 'cc3': 'ECU', 'iac': '+593', 'timezone': 'UTC-05:00', 'currency': 'United States dollar'}
# {'country': 'Egypt', 'capital': 'Cairo', 'cc': 'EG', 'cc3': 'EGY', 'iac': '+20', 'timezone': 'UTC+02:00', 'currency': 'Egyptian pound'}
# {'country': 'El Salvador', 'capital': 'San Salvador', 'cc': 'SV', 'cc3': 'SLV', 'iac': '+503', 'timezone': 'UTC-06:00', 'currency': 'Salvadoran colón'}
# {'country': 'Equatorial Guinea', 'capital': 'Malabo', 'cc': 'GQ', 'cc3': 'GNQ', 'iac': '+240', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Eritrea', 'capital': 'Asmara', 'cc': 'ER', 'cc3': 'ERI', 'iac': '+291', 'timezone': 'UTC+03:00', 'currency': 'Eritrean nakfa'}
# {'country': 'Estonia', 'capital': 'Tallinn', 'cc': 'EE', 'cc3': 'EST', 'iac': '+372', 'timezone': 'UTC+03:00', 'currency': 'Euro'}
# {'country': 'Ethiopia', 'capital': 'Addis Ababa', 'cc': 'ET', 'cc3': 'ETH', 'iac': '+251', 'timezone': 'UTC+03:00', 'currency': 'Ethiopian birr'}
# {'country': 'Falkland Islands (Malvinas)', 'capital': 'Stanley', 'cc': 'FK', 'cc3': 'FLK', 'iac': '+500', 'timezone': 'UTC-04:00', 'currency': 'Falkland Islands pound'}
# {'country': 'Faroe Islands', 'capital': 'Tórshavn', 'cc': 'FO', 'cc3': 'FRO', 'iac': '+298', 'timezone': 'UTC', 'currency': 'Danish krone'}
# {'country': 'Fiji', 'capital': 'Suva', 'cc': 'FJ', 'cc3': 'FJI', 'iac': '+679', 'timezone': 'UTC+12:00', 'currency': 'Fijian dollar'}
# {'country': 'Finland', 'capital': 'Helsinki', 'cc': 'FI', 'cc3': 'FIN', 'iac': '+358', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'country': 'France', 'capital': 'Paris', 'cc': 'FR', 'cc3': 'FRA', 'iac': '+33', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'French Guiana', 'capital': 'Cayenne', 'cc': 'GF', 'cc3': 'GUF', 'iac': '+594', 'timezone': 'UTC-01:00', 'currency': 'Euro'}
# {'country': 'French Polynesia', 'capital': 'Papeete', 'cc': 'PF', 'cc3': 'PYF', 'iac': '+689', 'timezone': 'UTC-10:00', 'currency': 'CFP franc'}
# {'country': 'French Southern Territories', 'capital': 'Port-aux-Français', 'cc': 'TF', 'cc3': 'ATF', 'iac': '', 'timezone': 'UTC+05:00', 'currency': 'Euro'}
# {'country': 'Gabon', 'capital': 'Libreville', 'cc': 'GA', 'cc3': 'GAB', 'iac': '+241', 'timezone': 'UTC+01:00', 'currency': 'Central African CFA franc'}
# {'country': 'Gambia', 'capital': 'Banjul', 'cc': 'GM', 'cc3': 'GMB', 'iac': '+220', 'timezone': 'UTC', 'currency': 'Gambian dalasi'}
# {'country': 'Georgia', 'capital': 'Tbilisi', 'cc': 'GE', 'cc3': 'GEO', 'iac': '+995', 'timezone': 'UTC+04:00', 'currency': 'Georgian lari'}
# {'country': 'Germany', 'capital': 'Berlin', 'cc': 'DE', 'cc3': 'DEU', 'iac': '+49', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Ghana', 'capital': 'Accra', 'cc': 'GH', 'cc3': 'GHA', 'iac': '+233', 'timezone': 'UTC', 'currency': 'Ghanaian cedi'}
# {'country': 'Gibraltar', 'capital': 'Gibraltar', 'cc': 'GI', 'cc3': 'GIB', 'iac': '+350', 'timezone': 'UTC+01:00', 'currency': 'Gibraltar pound'}
# {'country': 'Greece', 'capital': 'Athens', 'cc': 'GR', 'cc3': 'GRC', 'iac': '+30', 'timezone': 'UTC+02:00', 'currency': 'Euro'}
# {'country': 'Greenland', 'capital': 'Nuuk', 'cc': 'GL', 'cc3': 'GRL', 'iac': '+299', 'timezone': 'UTC-03:00', 'currency': 'Danish krone'}
# {'country': 'Grenada', 'capital': "St. George's", 'cc': 'GD', 'cc3': 'GRD', 'iac': '+1 473', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Guadeloupe', 'capital': 'Basse-Terre', 'cc': 'GP', 'cc3': 'GLP', 'iac': '+590', 'timezone': 'UTC-04:00', 'currency': 'Euro'}
# {'country': 'Guam', 'capital': 'Hagåtña', 'cc': 'GU', 'cc3': 'GUM', 'iac': '+1 671', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'country': 'Guatemala', 'capital': 'Guatemala City', 'cc': 'GT', 'cc3': 'GTM', 'iac': '+502', 'timezone': 'UTC-06:00', 'currency': 'Guatemalan quetzal'}
# {'country': 'Guernsey', 'capital': 'St. Peter Port', 'cc': 'GG', 'cc3': 'GGY', 'iac': '+44 1481', 'timezone': 'UTC', 'currency': 'British pound'}
# {'country': 'Guinea', 'capital': 'Conakry', 'cc': 'GN', 'cc3': 'GIN', 'iac': '+224', 'timezone': 'UTC', 'currency': 'Guinean franc'}
# {'country': 'Guinea-Bissau', 'capital': 'Bissau', 'cc': 'GW', 'cc3': 'GNB', 'iac': '+245', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Guyana', 'capital': 'Georgetown', 'cc': 'GY', 'cc3': 'GUY', 'iac': '+592', 'timezone': 'UTC-03:00', 'currency': 'Guyanese dollar'}
# {'country': 'Haiti', 'capital': 'Port-au-Prince', 'cc': 'HT', 'cc3': 'HTI', 'iac': '+509', 'timezone': 'UTC-05:00', 'currency': 'Haitian gourde'}
# {'country': 'Heard Island and McDonald Islands', 'capital': '', 'cc': 'HM', 'cc3': 'HMD', 'iac': '', 'timezone': 'UTC+05', 'currency': ''}
# {'country': 'Honduras', 'capital': 'Tegucigalpa', 'cc': 'HN', 'cc3': 'HND', 'iac': '+504', 'timezone': 'UTC-06:00', 'currency': 'Honduran lempira'}
# {'country': 'Hong Kong', 'capital': '', 'cc': 'HK', 'cc3': 'HKG', 'iac': '+852', 'timezone': 'UTC+08:00', 'currency': 'Hong Kong dollar'}
# {'country': 'Hungary', 'capital': 'Budapest', 'cc': 'HU', 'cc3': 'HUN', 'iac': '+36', 'timezone': 'UTC+01:00', 'currency': 'Hungarian forint'}
# {'country': 'Iceland', 'capital': 'Reykjavík', 'cc': 'IS', 'cc3': 'ISL', 'iac': '+354', 'timezone': 'UTC', 'currency': 'Icelandic króna'}
# {'country': 'India', 'capital': 'New Delhi', 'cc': 'IN', 'cc3': 'IND', 'iac': '+91', 'timezone': 'UTC+05:30', 'currency': 'Indian rupee'}
# {'country': 'Indonesia', 'capital': 'Jakarta', 'cc': 'ID', 'cc3': 'IDN', 'iac': '+62', 'timezone': 'UTC+07:00 - UTC+09:00', 'currency': 'Indonesian rupiah'}
# {'country': 'Iran', 'capital': 'Tehran', 'cc': 'IR', 'cc3': 'IRN', 'iac': '+98', 'timezone': 'UTC+03:30', 'currency': 'Iranian rial'}
# {'country': 'Iraq', 'capital': 'Baghdad', 'cc': 'IQ', 'cc3': 'IRQ', 'iac': '+964', 'timezone': 'UTC+03:00', 'currency': 'Iraqi dinar'}
# {'country': 'Ireland', 'capital': 'Dublin', 'cc': 'IE', 'cc3': 'IRL', 'iac': '+353', 'timezone': 'UTC', 'currency': 'Euro'}
# {'country': 'Isle of Man', 'capital': 'Douglas', 'cc': 'IM', 'cc3': 'IMN', 'iac': '+44 1624', 'timezone': 'UTC', 'currency': 'British pound'}
# {'country': 'Israel', 'capital': 'Jerusalem', 'cc': 'IL', 'cc3': 'ISR', 'iac': '+972', 'timezone': 'UTC+02:00', 'currency': 'Israeli new shekel'}
# {'country': 'Italy', 'capital': 'Rome', 'cc': 'IT', 'cc3': 'ITA', 'iac': '+39', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Jamaica', 'capital': 'Kingston', 'cc': 'JM', 'cc3': 'JAM', 'iac': '+1 876', 'timezone': 'UTC-05:00', 'currency': 'Jamaican dollar'}
# {'country': 'Japan', 'capital': 'Tokyo', 'cc': 'JP', 'cc3': 'JPN', 'iac': '+81', 'timezone': 'UTC+09:00', 'currency': 'Japanese yen'}
# {'country': 'Jersey', 'capital': 'St. Helier', 'cc': 'JE', 'cc3': 'JEY', 'iac': '+44 1534', 'timezone': 'UTC', 'currency': 'British pound'}
# {'country': 'Jordan', 'capital': 'Amman', 'cc': 'JO', 'cc3': 'JOR', 'iac': '+962', 'timezone': 'UTC+02:00', 'currency': 'Jordanian dinar'}
# {'country': 'Kazakhstan', 'capital': 'Astana', 'cc': 'KZ', 'cc3': 'KAZ', 'iac': '+7 6xx/7xx', 'timezone': 'UTC+06:00', 'currency': 'Kazakhstani tenge'}
# {'country': 'Kenya', 'capital': 'Nairobi', 'cc': 'KE', 'cc3': 'KEN', 'iac': '+254', 'timezone': 'UTC+03:00', 'currency': 'Kenyan shilling'}
# {'country': 'Kiribati', 'capital': 'Tarawa', 'cc': 'KI', 'cc3': 'KIR', 'iac': '+686', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'country': 'Kuwait', 'capital': 'Kuwait City', 'cc': 'KW', 'cc3': 'KWT', 'iac': '+965', 'timezone': 'UTC+03:00', 'currency': 'Kuwaiti dinar'}
# {'country': 'Kyrgyzstan', 'capital': 'Bishkek', 'cc': 'KG', 'cc3': 'KGZ', 'iac': '+996', 'timezone': 'UTC+06:00', 'currency': 'Kyrgyzstani som'}
# {'country': 'Laos', 'capital': 'Vientiane', 'cc': 'LA', 'cc3': 'LAO', 'iac': '+856', 'timezone': 'UTC+07:00', 'currency': 'Lao kip'}
# {'country': 'Latvia', 'capital': 'Riga', 'cc': 'LV', 'cc3': 'LVA', 'iac': '+371', 'timezone': 'UTC+03:00', 'currency': 'Latvian lats'}
# {'country': 'Lebanon', 'capital': 'Beirut', 'cc': 'LB', 'cc3': 'LBN', 'iac': '+961', 'timezone': 'UTC+02:00', 'currency': 'Lebanese pound'}
# {'country': 'Lesotho', 'capital': 'Maseru', 'cc': 'LS', 'cc3': 'LSO', 'iac': '+266', 'timezone': 'UTC+02:00', 'currency': 'Lesotho loti'}
# {'country': 'Liberia', 'capital': 'Monrovia', 'cc': 'LR', 'cc3': 'LBR', 'iac': '+231', 'timezone': 'UTC', 'currency': 'Liberian dollar'}
# {'country': 'Libya', 'capital': 'Tripoli', 'cc': 'LY', 'cc3': 'LBY', 'iac': '+218', 'timezone': 'UTC+02:00', 'currency': 'Libyan dinar'}
# {'country': 'Liechtenstein', 'capital': 'Vaduz', 'cc': 'LI', 'cc3': 'LIE', 'iac': '+423', 'timezone': 'UTC+01:00', 'currency': 'Swiss franc'}
# {'country': 'Lithuania', 'capital': 'Vilnius', 'cc': 'LT', 'cc3': 'LTU', 'iac': '+370', 'timezone': 'UTC+02:00', 'currency': 'Lithuanian litas'}
# {'country': 'Luxembourg', 'capital': 'Luxembourg', 'cc': 'LU', 'cc3': 'LUX', 'iac': '+352', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Macau', 'capital': '', 'cc': 'MO', 'cc3': 'MAC', 'iac': '+853', 'timezone': 'UTC+08:00', 'currency': 'Macanese pataca'}
# {'country': 'Macedonia', 'capital': 'Skopje', 'cc': 'MK', 'cc3': 'MKD', 'iac': '+389', 'timezone': 'UTC+01:00', 'currency': 'Macedonian denar'}
# {'country': 'Madagascar', 'capital': 'Antananarivo', 'cc': 'MG', 'cc3': 'MDG', 'iac': '+261', 'timezone': 'UTC+03:00', 'currency': 'Malagasy ariary'}
# {'country': 'Malawi', 'capital': 'Lilongwe', 'cc': 'MW', 'cc3': 'MWI', 'iac': '+265', 'timezone': 'UTC+02:00', 'currency': 'Malawian kwacha'}
# {'country': 'Malaysia', 'capital': 'Kuala Lumpur', 'cc': 'MY', 'cc3': 'MYS', 'iac': '+60', 'timezone': 'UTC+08:00', 'currency': 'Malaysian ringgit'}
# {'country': 'Maldives', 'capital': 'Malé', 'cc': 'MV', 'cc3': 'MDV', 'iac': '+960', 'timezone': 'UTC+05:00', 'currency': 'Maldivian rufiyaa'}
# {'country': 'Mali', 'capital': 'Bamako', 'cc': 'ML', 'cc3': 'MLI', 'iac': '+223', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Malta', 'capital': 'Valletta', 'cc': 'MT', 'cc3': 'MLT', 'iac': '+356', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Marshall Islands', 'capital': 'Majuro', 'cc': 'MH', 'cc3': 'MHL', 'iac': '+692', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'country': 'Martinique', 'capital': 'Fort-de-France', 'cc': 'MQ', 'cc3': 'MTQ', 'iac': '+596', 'timezone': 'UTC-04:00', 'currency': 'Euro'}
# {'country': 'Mauritania', 'capital': 'Nouakchott', 'cc': 'MR', 'cc3': 'MRT', 'iac': '+222', 'timezone': 'UTC', 'currency': 'Mauritanian ouguiya'}
# {'country': 'Mauritius', 'capital': 'Port Louis', 'cc': 'MU', 'cc3': 'MUS', 'iac': '+230', 'timezone': 'UTC+04:00', 'currency': 'Mauritian rupee'}
# {'country': 'Mayotte', 'capital': 'Mamoudzou', 'cc': 'YT', 'cc3': 'MYT', 'iac': '+262 269/639', 'timezone': 'UTC+03:00', 'currency': 'Euro'}
# {'country': 'Mexico', 'capital': 'Mexico City', 'cc': 'MX', 'cc3': 'MEX', 'iac': '+52', 'timezone': 'UTC-08:00 - UTC-06:00', 'currency': 'Mexican peso'}
# {'country': 'Micronesia', 'capital': 'Palikir', 'cc': 'FM', 'cc3': 'FSM', 'iac': '+691', 'timezone': 'UTC+10:00', 'currency': 'Micronesian dollar'}
# {'country': 'Moldova', 'capital': 'Chisinau', 'cc': 'MD', 'cc3': 'MDA', 'iac': '+373', 'timezone': 'UTC+03:00', 'currency': 'Moldovan leu'}
# {'country': 'Monaco', 'capital': 'Monaco', 'cc': 'MC', 'cc3': 'MCO', 'iac': '+377', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Mongolia', 'capital': 'Ulaanbaatar', 'cc': 'MN', 'cc3': 'MNG', 'iac': '+976', 'timezone': 'UTC+08:00', 'currency': 'Mongolian tögrög'}
# {'country': 'Montenegro', 'capital': 'Podgorica', 'cc': 'ME', 'cc3': 'MNE', 'iac': '+382', 'timezone': 'UTC+01', 'currency': 'Euro'}
# {'country': 'Montserrat', 'capital': 'Plymouth', 'cc': 'MS', 'cc3': 'MSR', 'iac': '+1 664', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Morocco', 'capital': 'Rabat', 'cc': 'MA', 'cc3': 'MAR', 'iac': '+212', 'timezone': 'UTC', 'currency': 'Moroccan dirham'}
# {'country': 'Mozambique', 'capital': 'Maputo', 'cc': 'MZ', 'cc3': 'MOZ', 'iac': '+258', 'timezone': 'UTC+02:00', 'currency': 'Mozambican metical'}
# {'country': 'Myanmar (Burma)', 'capital': 'Naypyidaw', 'cc': 'MM', 'cc3': 'MMR', 'iac': '+95', 'timezone': 'UTC+06:30', 'currency': 'Myanma kyat'}
# {'country': 'Namibia', 'capital': 'Windhoek', 'cc': 'NA', 'cc3': 'NAM', 'iac': '+264', 'timezone': 'UTC+02:00', 'currency': 'Namibian dollar'}
# {'country': 'Nauru', 'capital': 'Yaren', 'cc': 'NR', 'cc3': 'NRU', 'iac': '+674', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'country': 'Nepal', 'capital': 'Kathmandu', 'cc': 'NP', 'cc3': 'NPL', 'iac': '+977', 'timezone': 'UTC+05:30', 'currency': 'Nepalese rupee'}
# {'country': 'Netherlands', 'capital': 'Amsterdam', 'cc': 'NL', 'cc3': 'NLD', 'iac': '+31', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'New Caledonia', 'capital': 'Nouméa', 'cc': 'NC', 'cc3': 'NCL', 'iac': '+687', 'timezone': 'UTC+11:00', 'currency': 'CFP franc'}
# {'country': 'New Zealand', 'capital': 'Wellington', 'cc': 'NZ', 'cc3': 'NZL', 'iac': '+64', 'timezone': 'UTC+12:00', 'currency': 'New Zealand dollar'}
# {'country': 'Nicaragua', 'capital': 'Managua', 'cc': 'NI', 'cc3': 'NIC', 'iac': '+505', 'timezone': 'UTC-06:00', 'currency': 'Nicaraguan córdoba'}
# {'country': 'Niger', 'capital': 'Niamey', 'cc': 'NE', 'cc3': 'NER', 'iac': '+227', 'timezone': 'UTC+01:00', 'currency': 'West African CFA franc'}
# {'country': 'Nigeria', 'capital': 'Abuja', 'cc': 'NG', 'cc3': 'NGA', 'iac': '+234', 'timezone': 'UTC+01:00', 'currency': 'Nigerian naira'}
# {'country': 'Niue', 'capital': 'Alofi', 'cc': 'NU', 'cc3': 'NIU', 'iac': '+683', 'timezone': 'UTC-11:00', 'currency': 'New Zealand dollar'}
# {'country': 'Norfolk Island', 'capital': 'Kingston', 'cc': 'NF', 'cc3': 'NFK', 'iac': '+672 3', 'timezone': 'UTC+11:30', 'currency': 'Australian dollar'}
# {'country': 'North Korea', 'capital': 'Pyongyang', 'cc': 'KP', 'cc3': 'PRK', 'iac': '+850', 'timezone': 'UTC+09:00', 'currency': 'North Korean won'}
# {'country': 'Northern Mariana Islands', 'capital': 'Saipan', 'cc': 'MP', 'cc3': 'MNP', 'iac': '+1 670', 'timezone': 'UTC+10:00', 'currency': 'United States dollar'}
# {'country': 'Norway', 'capital': 'Oslo', 'cc': 'NO', 'cc3': 'NOR', 'iac': '+47', 'timezone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'country': 'Oman', 'capital': 'Muscat', 'cc': 'OM', 'cc3': 'OMN', 'iac': '+968', 'timezone': 'UTC+04:00', 'currency': 'Omani rial'}
# {'country': 'Pakistan', 'capital': 'Islamabad', 'cc': 'PK', 'cc3': 'PAK', 'iac': '+92', 'timezone': 'UTC+05:00', 'currency': 'Pakistani rupee'}
# {'country': 'Palau', 'capital': 'Ngerulmud', 'cc': 'PW', 'cc3': 'PLW', 'iac': '+680', 'timezone': 'UTC+09:00', 'currency': 'Palauan dollar'}
# {'country': 'Panama', 'capital': 'Panama City', 'cc': 'PA', 'cc3': 'PAN', 'iac': '+507', 'timezone': 'UTC-05:00', 'currency': 'Panamanian balboa'}
# {'country': 'Papua New Guinea', 'capital': 'Port Moresby', 'cc': 'PG', 'cc3': 'PNG', 'iac': '+675', 'timezone': 'UTC+10:00', 'currency': 'Papua New Guinean kina'}
# {'country': 'Paraguay', 'capital': 'Asunción', 'cc': 'PY', 'cc3': 'PRY', 'iac': '+595', 'timezone': 'UTC-04:00', 'currency': 'Paraguayan guaraní'}
# {'country': 'Peru', 'capital': 'Lima', 'cc': 'PE', 'cc3': 'PER', 'iac': '+51', 'timezone': 'UTC-05:00', 'currency': 'Peruvian nuevo sol'}
# {'country': 'Philippines', 'capital': 'Manila', 'cc': 'PH', 'cc3': 'PHL', 'iac': '+63', 'timezone': 'UTC+08:00', 'currency': 'Philippine peso'}
# {'country': 'Pitcairn', 'capital': 'Adamstown', 'cc': 'PN', 'cc3': 'PCN', 'iac': '+872', 'timezone': 'UTC-08', 'currency': 'New Zealand dollar'}
# {'country': 'Poland', 'capital': 'Warsaw', 'cc': 'PL', 'cc3': 'POL', 'iac': '+48', 'timezone': 'UTC+01:00', 'currency': 'Polish złoty'}
# {'country': 'Portugal', 'capital': 'Lisbon', 'cc': 'PT', 'cc3': 'PRT', 'iac': '+351', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Puerto Rico', 'capital': 'San Juan', 'cc': 'PR', 'cc3': 'PRI', 'iac': '+1 787/939', 'timezone': 'UTC-04:00', 'currency': 'United States dollar'}
# {'country': 'Qatar', 'capital': 'Doha', 'cc': 'QA', 'cc3': 'QAT', 'iac': '+974', 'timezone': 'UTC+03:00', 'currency': 'Qatari riyal'}
# {'country': 'Reunion', 'capital': '', 'cc': 'RE', 'cc3': 'REU', 'iac': '+262', 'timezone': 'UTC+04:00', 'currency': 'Euro'}
# {'country': 'Romania', 'capital': 'Bucharest', 'cc': 'RO', 'cc3': 'ROU', 'iac': '+40', 'timezone': 'UTC+02:00', 'currency': 'Romanian leu'}
# {'country': 'Russia', 'capital': 'Moscow', 'cc': 'RU', 'cc3': 'RUS', 'iac': '+7', 'timezone': 'UTC+03:00', 'currency': 'Russian ruble'}
# {'country': 'Rwanda', 'capital': 'Kigali', 'cc': 'RW', 'cc3': 'RWA', 'iac': '+250', 'timezone': 'UTC+02:00', 'currency': 'Rwandan franc'}
# {'country': 'Saint Barthelemy', 'capital': 'Gustavia', 'cc': 'BL', 'cc3': 'BLM', 'iac': '+590', 'timezone': 'UTC-04', 'currency': 'Euro'}
# {'country': 'Saint Helena', 'capital': 'Jamestown', 'cc': 'SH', 'cc3': 'SHN', 'iac': '+290', 'timezone': 'UTC', 'currency': 'Saint Helena pound'}
# {'country': 'Saint Kitts and Nevis', 'capital': 'Basseterre', 'cc': 'KN', 'cc3': 'KNA', 'iac': '+1 869', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Saint Lucia', 'capital': 'Castries', 'cc': 'LC', 'cc3': 'LCA', 'iac': '+1 758', 'timezone': 'UTC-04:00', 'currency': 'East Caribbean dollar'}
# {'country': 'Saint Martin', 'capital': 'Marigot', 'cc': 'MF', 'cc3': 'MAF', 'iac': '+590', 'timezone': 'UTC-04', 'currency': 'Euro'}
# {'country': 'Saint Pierre and Miquelon', 'capital': 'St. Pierre', 'cc': 'PM', 'cc3': 'SPM', 'iac': '+508', 'timezone': 'UTC-03', 'currency': 'Euro'}
# {'country': 'Saint Vincent and the Grenadines', 'capital': 'Kingstown', 'cc': 'VC', 'cc3': 'VCT', 'iac': '+1 784', 'timezone': 'UTC-04', 'currency': 'East Caribbean dollar'}
# {'country': 'Samoa', 'capital': 'Apia', 'cc': 'WS', 'cc3': 'WSM', 'iac': '+685', 'timezone': 'UTC-11:00', 'currency': 'Samoan tala'}
# {'country': 'San Marino', 'capital': 'San Marino', 'cc': 'SM', 'cc3': 'SMR', 'iac': '+378', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Sao Tome and Príncipe', 'capital': 'São Tomé', 'cc': 'ST', 'cc3': 'STP', 'iac': '+239', 'timezone': 'UTC', 'currency': 'São Tomé and Príncipe dobra'}
# {'country': 'Saudi Arabia', 'capital': 'Riyadh', 'cc': 'SA', 'cc3': 'SAU', 'iac': '+966', 'timezone': 'UTC+03:00', 'currency': 'Saudi riyal'}
# {'country': 'Senegal', 'capital': 'Dakar', 'cc': 'SN', 'cc3': 'SEN', 'iac': '+221', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Serbia', 'capital': 'Belgrade', 'cc': 'RS', 'cc3': 'SRB', 'iac': '+381', 'timezone': 'UTC+01:00', 'currency': 'Serbian dinar'}
# {'country': 'Seychelles', 'capital': 'Victoria', 'cc': 'SC', 'cc3': 'SYC', 'iac': '+248', 'timezone': 'UTC+04:00', 'currency': 'Seychellois rupee'}
# {'country': 'Sierra Leone', 'capital': 'Freetown', 'cc': 'SL', 'cc3': 'SLE', 'iac': '+232', 'timezone': 'UTC', 'currency': 'Sierra Leonean leone'}
# {'country': 'Singapore', 'capital': 'Singapore', 'cc': 'SG', 'cc3': 'SGP', 'iac': '+65', 'timezone': 'UTC+08:00', 'currency': 'Brunei dollar'}
# {'country': 'Sint Maarten', 'capital': 'Philipsburg', 'cc': 'SX', 'cc3': 'SXM', 'iac': '+599 5', 'timezone': 'UTC-04:00', 'currency': 'Netherlands Antillean guilder'}
# {'country': 'Slovakia', 'capital': 'Bratislava', 'cc': 'SK', 'cc3': 'SVK', 'iac': '+421', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Slovenia', 'capital': 'Ljubljana', 'cc': 'SI', 'cc3': 'SVN', 'iac': '+386', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Solomon Islands', 'capital': 'Honiara', 'cc': 'SB', 'cc3': 'SLB', 'iac': '+677', 'timezone': 'UTC+11:00', 'currency': 'Solomon Islands dollar'}
# {'country': 'Somalia', 'capital': 'Mogadishu', 'cc': 'SO', 'cc3': 'SOM', 'iac': '+252', 'timezone': 'UTC+03:00', 'currency': 'Somali shilling'}
# {'country': 'South Africa', 'capital': 'Pretoria', 'cc': 'ZA', 'cc3': 'ZAF', 'iac': '+27', 'timezone': 'UTC+02:00', 'currency': 'South African rand'}
# {'country': 'South Georgia and the South Sandwich Islands', 'capital': 'Grytviken', 'cc': 'GS', 'cc3': 'SGS', 'iac': '', 'timezone': 'UTC-02', 'currency': 'British pound'}
# {'country': 'South Korea', 'capital': 'Seoul', 'cc': 'KR', 'cc3': 'KOR', 'iac': '+82', 'timezone': 'UTC+09:00', 'currency': 'South Korean won'}
# {'country': 'Spain', 'capital': 'Madrid', 'cc': 'ES', 'cc3': 'ESP', 'iac': '+34', 'timezone': 'UTC+01:00', 'currency': 'Euro'}
# {'country': 'Sri Lanka', 'capital': 'Sri Jayawardenapura Kotte', 'cc': 'LK', 'cc3': 'LKA', 'iac': '+94', 'timezone': 'UTC+05:30', 'currency': 'Sri Lankan rupee'}
# {'country': 'Sudan', 'capital': 'Khartoum', 'cc': 'SD', 'cc3': 'SDN', 'iac': '+249', 'timezone': 'UTC+02:00', 'currency': 'Sudanese pound'}
# {'country': 'Suriname', 'capital': 'Paramaribo', 'cc': 'SR', 'cc3': 'SUR', 'iac': '+597', 'timezone': 'UTC-03:30', 'currency': 'Surinamese dollar'}
# {'country': 'Svalbard and Jan Mayen', 'capital': '', 'cc': 'SJ', 'cc3': 'SJM', 'iac': '+47', 'timezone': 'UTC+01:00', 'currency': 'Norwegian krone'}
# {'country': 'Swaziland', 'capital': 'Mbabane', 'cc': 'SZ', 'cc3': 'SWZ', 'iac': '+268', 'timezone': 'UTC+02:00', 'currency': 'Swazi lilangeni'}
# {'country': 'Sweden', 'capital': 'Stockholm', 'cc': 'SE', 'cc3': 'SWE', 'iac': '+46', 'timezone': 'UTC+01:00', 'currency': 'Swedish krona'}
# {'country': 'Switzerland', 'capital': 'Bern', 'cc': 'CH', 'cc3': 'CHE', 'iac': '+41', 'timezone': 'UTC+01:00', 'currency': 'Swiss franc'}
# {'country': 'Syrian Arab Republic', 'capital': 'Damascus', 'cc': 'SY', 'cc3': 'SYR', 'iac': '+963', 'timezone': 'UTC+02:00', 'currency': 'Syrian pound'}
# {'country': 'Taiwan', 'capital': 'Taipei', 'cc': 'TW', 'cc3': 'TWN', 'iac': '+886', 'timezone': 'UTC+08:00', 'currency': 'New Taiwan dollar'}
# {'country': 'Tajikistan', 'capital': 'Dushanbe', 'cc': 'TJ', 'cc3': 'TJK', 'iac': '+992', 'timezone': 'UTC+06:00', 'currency': 'Tajikistani somoni'}
# {'country': 'Tanzania', 'capital': 'Dodoma', 'cc': 'TZ', 'cc3': 'TZA', 'iac': '+255', 'timezone': 'UTC+03:00', 'currency': 'Tanzanian shilling'}
# {'country': 'Thailand', 'capital': 'Bangkok', 'cc': 'TH', 'cc3': 'THA', 'iac': '+66', 'timezone': 'UTC+07:00', 'currency': 'Thai baht'}
# {'country': 'Togo', 'capital': 'Lomé', 'cc': 'TG', 'cc3': 'TGO', 'iac': '+228', 'timezone': 'UTC', 'currency': 'West African CFA franc'}
# {'country': 'Tokelau', 'capital': 'Rotates annually', 'cc': 'TK', 'cc3': 'TKL', 'iac': '+690', 'timezone': 'UTC-10', 'currency': 'New Zealand dollar'}
# {'country': 'Tonga', 'capital': 'Nuku', 'cc': 'TO', 'cc3': 'TON', 'iac': '+676', 'timezone': 'UTC+13:00', 'currency': 'Tongan paʻanga'}
# {'country': 'Trinidad and Tobago', 'capital': 'Port of Spain', 'cc': 'TT', 'cc3': 'TTO', 'iac': '+1 868', 'timezone': 'UTC-04:00', 'currency': 'Trinidad and Tobago dollar'}
# {'country': 'Tunisia', 'capital': 'Tunis', 'cc': 'TN', 'cc3': 'TUN', 'iac': '+216', 'timezone': 'UTC+01:00', 'currency': 'Tunisian dinar'}
# {'country': 'Turkey', 'capital': 'Ankara', 'cc': 'TR', 'cc3': 'TUR', 'iac': '+90', 'timezone': 'UTC+02:00', 'currency': 'Turkish lira'}
# {'country': 'Turkmenistan', 'capital': 'Ashgabat', 'cc': 'TM', 'cc3': 'TKM', 'iac': '+993', 'timezone': 'UTC+05:00', 'currency': 'Turkmenistani manat'}
# {'country': 'Turks and Caicos Islands', 'capital': 'Cockburn Town', 'cc': 'TC', 'cc3': 'TCA', 'iac': '+1 649', 'timezone': 'UTC-05:00', 'currency': 'United States dollar'}
# {'country': 'Tuvalu', 'capital': 'Funafuti', 'cc': 'TV', 'cc3': 'TUV', 'iac': '+688', 'timezone': 'UTC+12:00', 'currency': 'Australian dollar'}
# {'country': 'Uganda', 'capital': 'Kampala', 'cc': 'UG', 'cc3': 'UGA', 'iac': '+256', 'timezone': 'UTC+03:00', 'currency': 'Ugandan shilling'}
# {'country': 'Ukraine', 'capital': 'Kyiv', 'cc': 'UA', 'cc3': 'UKR', 'iac': '+380', 'timezone': 'UTC+03:00', 'currency': 'Ukrainian hryvnia'}
# {'country': 'United Arab Emirates', 'capital': 'Abu Dhabi', 'cc': 'AE', 'cc3': 'ARE', 'iac': '+971', 'timezone': 'UTC+04:00', 'currency': 'United Arab Emirates dirham'}
# {'country': 'United Kingdom', 'capital': 'London', 'cc': 'GB', 'cc3': 'GBR', 'iac': '+44', 'timezone': 'UTC', 'currency': 'British pound'}
# {'country': 'United States', 'capital': 'Washington D.C.', 'cc': 'US', 'cc3': 'USA', 'iac': '+1', 'timezone': 'UTC-11:00 - UTC-05:00', 'currency': 'United States dollar'}
# {'country': 'United States Minor Outlying Islands', 'capital': '', 'cc': 'UM', 'cc3': 'UMI', 'iac': '+1', 'timezone': '', 'currency': 'United States dollar'}
# {'country': 'Uruguay', 'capital': 'Montevideo', 'cc': 'UY', 'cc3': 'URY', 'iac': '+598', 'timezone': 'UTC-03:00', 'currency': 'Uruguayan peso'}
# {'country': 'Uzbekistan', 'capital': 'Tashkent', 'cc': 'UZ', 'cc3': 'UZB', 'iac': '+998', 'timezone': 'UTC+06:00', 'currency': 'Uzbekistani som'}
# {'country': 'Vanuatu', 'capital': 'Port Vila', 'cc': 'VU', 'cc3': 'VUT', 'iac': '+678', 'timezone': 'UTC+11:00', 'currency': 'Vanuatu vatu'}
# {'country': 'Vatican City', 'capital': 'Vatican City', 'cc': 'VA', 'cc3': 'VAT', 'iac': '+39 06 698', 'timezone': 'UTC+01', 'currency': 'Euro'}
# {'country': 'Venezuela', 'capital': 'Caracas', 'cc': 'VE', 'cc3': 'VEN', 'iac': '+58', 'timezone': 'UTC-04:00', 'currency': 'Venezuelan bolívar'}
# {'country': 'Vietnam', 'capital': 'Hanoi', 'cc': 'VN', 'cc3': 'VNM', 'iac': '+84', 'timezone': 'UTC+07:00', 'currency': 'Vietnamese đồng'}
# {'country': 'Virgin Islands', 'capital': 'Road Town', 'cc': 'VG', 'cc3': 'VGB', 'iac': '+1 284', 'timezone': 'UTC-04', 'currency': 'British Virgin Islands dollar'}
# {'country': 'Virgin Islands of the United States', 'capital': 'Charlotte Amalie', 'cc': 'VI', 'cc3': 'VIR', 'iac': '+1 340', 'timezone': 'UTC-04', 'currency': 'United States dollar'}
# {'country': 'Wallis and Futuna', 'capital': 'Mata-Utu', 'cc': 'WF', 'cc3': 'WLF', 'iac': '+681', 'timezone': 'UTC+12:00', 'currency': 'CFP franc'}
# {'country': 'Western Sahara', 'capital': 'Laâyoune (El Aaiún)', 'cc': 'EH', 'cc3': 'ESH', 'iac': '+212 5288/5289', 'timezone': 'UTC+01', 'currency': 'Moroccan dirham'}
# {'country': 'Yemen', 'capital': 'Sanaá', 'cc': 'YE', 'cc3': 'YEM', 'iac': '+967', 'timezone': 'UTC+03:00', 'currency': 'Yemeni rial'}
# {'country': 'Zambia', 'capital': 'Lusaka', 'cc': 'ZM', 'cc3': 'ZMB', 'iac': '+260', 'timezone': 'UTC+02:00', 'currency': 'Zambian kwacha'}
# {'country': 'Zimbabwe', 'capital': ' Harare', 'cc': 'ZW', 'cc3': 'ZWE', 'iac': '+263', 'timezone': 'UTC+02:00', 'currency': 'Zimbabwean dollar'}
