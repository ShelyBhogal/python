# %% [markdown]
# # Returning values in a loop
#
# **Using the program where the user guesses a number between 1 and 1000 (see While Loops notebook), how do you ensure that the user inputs a valid integer guess, like a string or no value?**
#
# **Define a function to loop around until the user input is valid, then return the integer value once successful.**

# %%
import random


# Function to prompt user to input integer
def get_integer(prompt):
    while True:
        temp = input(prompt)
        if temp.isnumeric():
            return int(temp)
        else:
            print("Input a number, not text")
            


# Constant for maximum guessing value
MAX = 1000

answer = random.randint(1, MAX)
#print(answer)

# Initialize to any non-zero number
guess = 0

print("Think of a number between 1 and {}".format(MAX))

while guess != answer:
    # Call function for user input
    guess = get_integer(": ")
    
    if guess == 0:
        break
        
    if guess == answer:
        print("GOT IT!")
    else:
        if guess < answer:
            print("Guess higher")
        else:
            print("Guess lower")
# Out:
# Think of a number between 1 and 1000
# : 500
# Guess higher
# : 600
# Guess higher
# : seven
# Input a number, not text
# : 700
# Guess higher
# : eighty
# Input a number, not text
# : 800
# Guess lower
# : 750
# Guess lower
# : 720
# Guess higher
# : 730
# Guess higher
# : 740
# Guess lower
# : 735
# Guess lower
# : 734
# Guess lower
# : 733
# Guess lower
# : 732
# Guess lower
# : 721
# Guess higher
# : 731
# GOT IT!

# %%
# Let's check!!

print(answer)
# Out:
# 731

# %% [markdown]
# **The `else` block is not actually necessary in the `get_integer` function, but it does make code more readable:**
#
#     def get_integer(prompt):
#         while True:
#             temp = input(prompt)
#             if temp.isnumeric():
#                 return int(temp)
#
#             print("Input a number, not text")
#
#
# **Ideally, you would turn the function into a module, which can be imported in any notebook. Until then, you can copy-and-paste the function definition to the notebook as needed.**
#
# **Rather than turning the `get_integer` function into a module, what about the entire guessing game as a function that can be called...**
#
# **Use the program that forces the computer to do the guessing. Note that entire `while` loop is contained in function, with `input()` function removed, since calling the function will act as computer making guess.**

# %% [markdown]
# **ORIGINAL PROGRAM USING WHILE LOOP**
#
#     low = 1
#     high = 1000
#
#     print("Think of a number between {} and {}".format(low, high))
#     input("Press ENTER to start ")
#
#     # Store no of guesses
#     guesses = 1
#
#     while True:`
#         print("\tGuessing between {} and {}...".format(low, high))
#         guess = low + (high - low) // 2
#         hi_lo = input("My guess is {}. Should it be higher or lower? Insert 'h' or 'l', or 'c' if correct: ".format(guess)).casefold()
#
#         if hi_lo == 'h':
#             # Low value becomes 1 greater than guess
#             low = guess + 1
#         elif hi_lo == 'l':
#             # High value becomes 1 less than guess
#             high = guess - 1
#         elif hi_lo == 'c':
#             print("CORRECT! Got it in {} guesses".format(guesses))
#             break
#         else:
#             print("Please enter 'h', 'l' or 'c'")
#
#         guesses += 1
#
# **Now contain this code as a function that you call with the answer (that you choose), and the range for guessing, i.e. between 1 and 1000. The computer will loop through its guesses until it gets the right answer and return the total number of guesses it took to guess correctly (should be 10 max).**

# %%
low = 1
high = 1000

def guess_binary(answer, low, high):
    guesses = 1
    
    while True:
        guess = low + (high - low) // 2
        
        if guess < answer:
            low = guess + 1
        elif guess > answer:
            high = guess - 1
        elif guess == answer:
            return guesses
        
        guesses += 1

# %%
guess_binary(692, low, high)
# Out:
# 9

# %%
guess_binary(41, low, high)
# Out:
# 10

# %%
for number in range(low, high + 1):
    number_of_guesses = guess_binary(number, low, high)
    print("No {} guessed in {} attempts".format(number, number_of_guesses))
# Out:
# No 1 guessed in 9 attempts
# No 2 guessed in 10 attempts
# No 3 guessed in 8 attempts
# No 4 guessed in 10 attempts
# No 5 guessed in 9 attempts
# No 6 guessed in 10 attempts
# No 7 guessed in 7 attempts
# No 8 guessed in 10 attempts
# No 9 guessed in 9 attempts
# No 10 guessed in 10 attempts
# No 11 guessed in 8 attempts
# No 12 guessed in 10 attempts
# No 13 guessed in 9 attempts
# No 14 guessed in 10 attempts
# No 15 guessed in 6 attempts
# No 16 guessed in 10 attempts
# No 17 guessed in 9 attempts
# No 18 guessed in 10 attempts
# No 19 guessed in 8 attempts
# No 20 guessed in 10 attempts
# No 21 guessed in 9 attempts
# No 22 guessed in 10 attempts
# No 23 guessed in 7 attempts
# No 24 guessed in 10 attempts
# No 25 guessed in 9 attempts
# No 26 guessed in 10 attempts
# No 27 guessed in 8 attempts
# No 28 guessed in 10 attempts
# No 29 guessed in 9 attempts
# No 30 guessed in 10 attempts
# No 31 guessed in 5 attempts
# No 32 guessed in 9 attempts
# No 33 guessed in 10 attempts
# No 34 guessed in 8 attempts
# No 35 guessed in 10 attempts
# No 36 guessed in 9 attempts
# No 37 guessed in 10 attempts
# No 38 guessed in 7 attempts
# No 39 guessed in 10 attempts
# No 40 guessed in 9 attempts
# No 41 guessed in 10 attempts
# No 42 guessed in 8 attempts
# No 43 guessed in 10 attempts
# No 44 guessed in 9 attempts
# No 45 guessed in 10 attempts
# No 46 guessed in 6 attempts
# No 47 guessed in 10 attempts
# No 48 guessed in 9 attempts
# No 49 guessed in 10 attempts
# No 50 guessed in 8 attempts
# No 51 guessed in 10 attempts
# No 52 guessed in 9 attempts
# No 53 guessed in 10 attempts
# No 54 guessed in 7 attempts
# No 55 guessed in 10 attempts
# No 56 guessed in 9 attempts
# No 57 guessed in 10 attempts
# No 58 guessed in 8 attempts
# No 59 guessed in 10 attempts
# No 60 guessed in 9 attempts
# No 61 guessed in 10 attempts
# No 62 guessed in 4 attempts
# No 63 guessed in 9 attempts
# No 64 guessed in 10 attempts
# No 65 guessed in 8 attempts
# No 66 guessed in 10 attempts
# No 67 guessed in 9 attempts
# No 68 guessed in 10 attempts
# No 69 guessed in 7 attempts
# No 70 guessed in 10 attempts
# No 71 guessed in 9 attempts
# No 72 guessed in 10 attempts
# No 73 guessed in 8 attempts
# No 74 guessed in 10 attempts
# No 75 guessed in 9 attempts
# No 76 guessed in 10 attempts
# No 77 guessed in 6 attempts
# No 78 guessed in 10 attempts
# No 79 guessed in 9 attempts
# No 80 guessed in 10 attempts
# No 81 guessed in 8 attempts
# No 82 guessed in 10 attempts
# No 83 guessed in 9 attempts
# No 84 guessed in 10 attempts
# No 85 guessed in 7 attempts
# No 86 guessed in 10 attempts
# No 87 guessed in 9 attempts
# No 88 guessed in 10 attempts
# No 89 guessed in 8 attempts
# No 90 guessed in 10 attempts
# No 91 guessed in 9 attempts
# No 92 guessed in 10 attempts
# No 93 guessed in 5 attempts
# No 94 guessed in 10 attempts
# No 95 guessed in 9 attempts
# No 96 guessed in 10 attempts
# No 97 guessed in 8 attempts
# No 98 guessed in 10 attempts
# No 99 guessed in 9 attempts
# No 100 guessed in 10 attempts
# No 101 guessed in 7 attempts
# No 102 guessed in 10 attempts
# No 103 guessed in 9 attempts
# No 104 guessed in 10 attempts
# No 105 guessed in 8 attempts
# No 106 guessed in 10 attempts
# No 107 guessed in 9 attempts
# No 108 guessed in 10 attempts
# No 109 guessed in 6 attempts
# No 110 guessed in 10 attempts
# No 111 guessed in 9 attempts
# No 112 guessed in 10 attempts
# No 113 guessed in 8 attempts
# No 114 guessed in 10 attempts
# No 115 guessed in 9 attempts
# No 116 guessed in 10 attempts
# No 117 guessed in 7 attempts
# No 118 guessed in 10 attempts
# No 119 guessed in 9 attempts
# No 120 guessed in 10 attempts
# No 121 guessed in 8 attempts
# No 122 guessed in 10 attempts
# No 123 guessed in 9 attempts
# No 124 guessed in 10 attempts
# No 125 guessed in 3 attempts
# No 126 guessed in 9 attempts
# No 127 guessed in 10 attempts
# No 128 guessed in 8 attempts
# No 129 guessed in 10 attempts
# No 130 guessed in 9 attempts
# No 131 guessed in 10 attempts
# No 132 guessed in 7 attempts
# No 133 guessed in 10 attempts
# No 134 guessed in 9 attempts
# No 135 guessed in 10 attempts
# No 136 guessed in 8 attempts
# No 137 guessed in 10 attempts
# No 138 guessed in 9 attempts
# No 139 guessed in 10 attempts
# No 140 guessed in 6 attempts
# No 141 guessed in 10 attempts
# No 142 guessed in 9 attempts
# No 143 guessed in 10 attempts
# No 144 guessed in 8 attempts
# No 145 guessed in 10 attempts
# No 146 guessed in 9 attempts
# No 147 guessed in 10 attempts
# No 148 guessed in 7 attempts
# No 149 guessed in 10 attempts
# No 150 guessed in 9 attempts
# No 151 guessed in 10 attempts
# No 152 guessed in 8 attempts
# No 153 guessed in 10 attempts
# No 154 guessed in 9 attempts
# No 155 guessed in 10 attempts
# No 156 guessed in 5 attempts
# No 157 guessed in 9 attempts
# No 158 guessed in 10 attempts
# No 159 guessed in 8 attempts
# No 160 guessed in 10 attempts
# No 161 guessed in 9 attempts
# No 162 guessed in 10 attempts
# No 163 guessed in 7 attempts
# No 164 guessed in 10 attempts
# No 165 guessed in 9 attempts
# No 166 guessed in 10 attempts
# No 167 guessed in 8 attempts
# No 168 guessed in 10 attempts
# No 169 guessed in 9 attempts
# No 170 guessed in 10 attempts
# No 171 guessed in 6 attempts
# No 172 guessed in 10 attempts
# No 173 guessed in 9 attempts
# No 174 guessed in 10 attempts
# No 175 guessed in 8 attempts
# No 176 guessed in 10 attempts
# No 177 guessed in 9 attempts
# No 178 guessed in 10 attempts
# No 179 guessed in 7 attempts
# No 180 guessed in 10 attempts
# No 181 guessed in 9 attempts
# No 182 guessed in 10 attempts
# No 183 guessed in 8 attempts
# No 184 guessed in 10 attempts
# No 185 guessed in 9 attempts
# No 186 guessed in 10 attempts
# No 187 guessed in 4 attempts
# No 188 guessed in 9 attempts
# No 189 guessed in 10 attempts
# No 190 guessed in 8 attempts
# No 191 guessed in 10 attempts
# No 192 guessed in 9 attempts
# No 193 guessed in 10 attempts
# No 194 guessed in 7 attempts
# No 195 guessed in 10 attempts
# No 196 guessed in 9 attempts
# No 197 guessed in 10 attempts
# No 198 guessed in 8 attempts
# No 199 guessed in 10 attempts
# No 200 guessed in 9 attempts
# No 201 guessed in 10 attempts
# No 202 guessed in 6 attempts
# No 203 guessed in 10 attempts
# No 204 guessed in 9 attempts
# No 205 guessed in 10 attempts
# No 206 guessed in 8 attempts
# No 207 guessed in 10 attempts
# No 208 guessed in 9 attempts
# No 209 guessed in 10 attempts
# No 210 guessed in 7 attempts
# No 211 guessed in 10 attempts
# No 212 guessed in 9 attempts
# No 213 guessed in 10 attempts
# No 214 guessed in 8 attempts
# No 215 guessed in 10 attempts
# No 216 guessed in 9 attempts
# No 217 guessed in 10 attempts
# No 218 guessed in 5 attempts
# No 219 guessed in 10 attempts
# No 220 guessed in 9 attempts
# No 221 guessed in 10 attempts
# No 222 guessed in 8 attempts
# No 223 guessed in 10 attempts
# No 224 guessed in 9 attempts
# No 225 guessed in 10 attempts
# No 226 guessed in 7 attempts
# No 227 guessed in 10 attempts
# No 228 guessed in 9 attempts
# No 229 guessed in 10 attempts
# No 230 guessed in 8 attempts
# No 231 guessed in 10 attempts
# No 232 guessed in 9 attempts
# No 233 guessed in 10 attempts
# No 234 guessed in 6 attempts
# No 235 guessed in 10 attempts
# No 236 guessed in 9 attempts
# No 237 guessed in 10 attempts
# No 238 guessed in 8 attempts
# No 239 guessed in 10 attempts
# No 240 guessed in 9 attempts
# No 241 guessed in 10 attempts
# No 242 guessed in 7 attempts
# No 243 guessed in 10 attempts
# No 244 guessed in 9 attempts
# No 245 guessed in 10 attempts
# No 246 guessed in 8 attempts
# No 247 guessed in 10 attempts
# No 248 guessed in 9 attempts
# No 249 guessed in 10 attempts
# No 250 guessed in 2 attempts
# No 251 guessed in 9 attempts
# No 252 guessed in 10 attempts
# No 253 guessed in 8 attempts
# No 254 guessed in 10 attempts
# No 255 guessed in 9 attempts
# No 256 guessed in 10 attempts
# No 257 guessed in 7 attempts
# No 258 guessed in 10 attempts
# No 259 guessed in 9 attempts
# No 260 guessed in 10 attempts
# No 261 guessed in 8 attempts
# No 262 guessed in 10 attempts
# No 263 guessed in 9 attempts
# No 264 guessed in 10 attempts
# No 265 guessed in 6 attempts
# No 266 guessed in 10 attempts
# No 267 guessed in 9 attempts
# No 268 guessed in 10 attempts
# No 269 guessed in 8 attempts
# No 270 guessed in 10 attempts
# No 271 guessed in 9 attempts
# No 272 guessed in 10 attempts
# No 273 guessed in 7 attempts
# No 274 guessed in 10 attempts
# No 275 guessed in 9 attempts
# No 276 guessed in 10 attempts
# No 277 guessed in 8 attempts
# No 278 guessed in 10 attempts
# No 279 guessed in 9 attempts
# No 280 guessed in 10 attempts
# No 281 guessed in 5 attempts
# No 282 guessed in 9 attempts
# No 283 guessed in 10 attempts
# No 284 guessed in 8 attempts
# No 285 guessed in 10 attempts
# No 286 guessed in 9 attempts
# No 287 guessed in 10 attempts
# No 288 guessed in 7 attempts
# No 289 guessed in 10 attempts
# No 290 guessed in 9 attempts
# No 291 guessed in 10 attempts
# No 292 guessed in 8 attempts
# No 293 guessed in 10 attempts
# No 294 guessed in 9 attempts
# No 295 guessed in 10 attempts
# No 296 guessed in 6 attempts
# No 297 guessed in 10 attempts
# No 298 guessed in 9 attempts
# No 299 guessed in 10 attempts
# No 300 guessed in 8 attempts
# No 301 guessed in 10 attempts
# No 302 guessed in 9 attempts
# No 303 guessed in 10 attempts
# No 304 guessed in 7 attempts
# No 305 guessed in 10 attempts
# No 306 guessed in 9 attempts
# No 307 guessed in 10 attempts
# No 308 guessed in 8 attempts
# No 309 guessed in 10 attempts
# No 310 guessed in 9 attempts
# No 311 guessed in 10 attempts
# No 312 guessed in 4 attempts
# No 313 guessed in 9 attempts
# No 314 guessed in 10 attempts
# No 315 guessed in 8 attempts
# No 316 guessed in 10 attempts
# No 317 guessed in 9 attempts
# No 318 guessed in 10 attempts
# No 319 guessed in 7 attempts
# No 320 guessed in 10 attempts
# No 321 guessed in 9 attempts
# No 322 guessed in 10 attempts
# No 323 guessed in 8 attempts
# No 324 guessed in 10 attempts
# No 325 guessed in 9 attempts
# No 326 guessed in 10 attempts
# No 327 guessed in 6 attempts
# No 328 guessed in 10 attempts
# No 329 guessed in 9 attempts
# No 330 guessed in 10 attempts
# No 331 guessed in 8 attempts
# No 332 guessed in 10 attempts
# No 333 guessed in 9 attempts
# No 334 guessed in 10 attempts
# No 335 guessed in 7 attempts
# No 336 guessed in 10 attempts
# No 337 guessed in 9 attempts
# No 338 guessed in 10 attempts
# No 339 guessed in 8 attempts
# No 340 guessed in 10 attempts
# No 341 guessed in 9 attempts
# No 342 guessed in 10 attempts
# No 343 guessed in 5 attempts
# No 344 guessed in 10 attempts
# No 345 guessed in 9 attempts
# No 346 guessed in 10 attempts
# No 347 guessed in 8 attempts
# No 348 guessed in 10 attempts
# No 349 guessed in 9 attempts
# No 350 guessed in 10 attempts
# No 351 guessed in 7 attempts
# No 352 guessed in 10 attempts
# No 353 guessed in 9 attempts
# No 354 guessed in 10 attempts
# No 355 guessed in 8 attempts
# No 356 guessed in 10 attempts
# No 357 guessed in 9 attempts
# No 358 guessed in 10 attempts
# No 359 guessed in 6 attempts
# No 360 guessed in 10 attempts
# No 361 guessed in 9 attempts
# No 362 guessed in 10 attempts
# No 363 guessed in 8 attempts
# No 364 guessed in 10 attempts
# No 365 guessed in 9 attempts
# No 366 guessed in 10 attempts
# No 367 guessed in 7 attempts
# No 368 guessed in 10 attempts
# No 369 guessed in 9 attempts
# No 370 guessed in 10 attempts
# No 371 guessed in 8 attempts
# No 372 guessed in 10 attempts
# No 373 guessed in 9 attempts
# No 374 guessed in 10 attempts
# No 375 guessed in 3 attempts
# No 376 guessed in 9 attempts
# No 377 guessed in 10 attempts
# No 378 guessed in 8 attempts
# No 379 guessed in 10 attempts
# No 380 guessed in 9 attempts
# No 381 guessed in 10 attempts
# No 382 guessed in 7 attempts
# No 383 guessed in 10 attempts
# No 384 guessed in 9 attempts
# No 385 guessed in 10 attempts
# No 386 guessed in 8 attempts
# No 387 guessed in 10 attempts
# No 388 guessed in 9 attempts
# No 389 guessed in 10 attempts
# No 390 guessed in 6 attempts
# No 391 guessed in 10 attempts
# No 392 guessed in 9 attempts
# No 393 guessed in 10 attempts
# No 394 guessed in 8 attempts
# No 395 guessed in 10 attempts
# No 396 guessed in 9 attempts
# No 397 guessed in 10 attempts
# No 398 guessed in 7 attempts
# No 399 guessed in 10 attempts
# No 400 guessed in 9 attempts
# No 401 guessed in 10 attempts
# No 402 guessed in 8 attempts
# No 403 guessed in 10 attempts
# No 404 guessed in 9 attempts
# No 405 guessed in 10 attempts
# No 406 guessed in 5 attempts
# No 407 guessed in 9 attempts
# No 408 guessed in 10 attempts
# No 409 guessed in 8 attempts
# No 410 guessed in 10 attempts
# No 411 guessed in 9 attempts
# No 412 guessed in 10 attempts
# No 413 guessed in 7 attempts
# No 414 guessed in 10 attempts
# No 415 guessed in 9 attempts
# No 416 guessed in 10 attempts
# No 417 guessed in 8 attempts
# No 418 guessed in 10 attempts
# No 419 guessed in 9 attempts
# No 420 guessed in 10 attempts
# No 421 guessed in 6 attempts
# No 422 guessed in 10 attempts
# No 423 guessed in 9 attempts
# No 424 guessed in 10 attempts
# No 425 guessed in 8 attempts
# No 426 guessed in 10 attempts
# No 427 guessed in 9 attempts
# No 428 guessed in 10 attempts
# No 429 guessed in 7 attempts
# No 430 guessed in 10 attempts
# No 431 guessed in 9 attempts
# No 432 guessed in 10 attempts
# No 433 guessed in 8 attempts
# No 434 guessed in 10 attempts
# No 435 guessed in 9 attempts
# No 436 guessed in 10 attempts
# No 437 guessed in 4 attempts
# No 438 guessed in 9 attempts
# No 439 guessed in 10 attempts
# No 440 guessed in 8 attempts
# No 441 guessed in 10 attempts
# No 442 guessed in 9 attempts
# No 443 guessed in 10 attempts
# No 444 guessed in 7 attempts
# No 445 guessed in 10 attempts
# No 446 guessed in 9 attempts
# No 447 guessed in 10 attempts
# No 448 guessed in 8 attempts
# No 449 guessed in 10 attempts
# No 450 guessed in 9 attempts
# No 451 guessed in 10 attempts
# No 452 guessed in 6 attempts
# No 453 guessed in 10 attempts
# No 454 guessed in 9 attempts
# No 455 guessed in 10 attempts
# No 456 guessed in 8 attempts
# No 457 guessed in 10 attempts
# No 458 guessed in 9 attempts
# No 459 guessed in 10 attempts
# No 460 guessed in 7 attempts
# No 461 guessed in 10 attempts
# No 462 guessed in 9 attempts
# No 463 guessed in 10 attempts
# No 464 guessed in 8 attempts
# No 465 guessed in 10 attempts
# No 466 guessed in 9 attempts
# No 467 guessed in 10 attempts
# No 468 guessed in 5 attempts
# No 469 guessed in 10 attempts
# No 470 guessed in 9 attempts
# No 471 guessed in 10 attempts
# No 472 guessed in 8 attempts
# No 473 guessed in 10 attempts
# No 474 guessed in 9 attempts
# No 475 guessed in 10 attempts
# No 476 guessed in 7 attempts
# No 477 guessed in 10 attempts
# No 478 guessed in 9 attempts
# No 479 guessed in 10 attempts
# No 480 guessed in 8 attempts
# No 481 guessed in 10 attempts
# No 482 guessed in 9 attempts
# No 483 guessed in 10 attempts
# No 484 guessed in 6 attempts
# No 485 guessed in 10 attempts
# No 486 guessed in 9 attempts
# No 487 guessed in 10 attempts
# No 488 guessed in 8 attempts
# No 489 guessed in 10 attempts
# No 490 guessed in 9 attempts
# No 491 guessed in 10 attempts
# No 492 guessed in 7 attempts
# No 493 guessed in 10 attempts
# No 494 guessed in 9 attempts
# No 495 guessed in 10 attempts
# No 496 guessed in 8 attempts
# No 497 guessed in 10 attempts
# No 498 guessed in 9 attempts
# No 499 guessed in 10 attempts
# No 500 guessed in 1 attempts
# No 501 guessed in 9 attempts
# No 502 guessed in 10 attempts
# No 503 guessed in 8 attempts
# No 504 guessed in 10 attempts
# No 505 guessed in 9 attempts
# No 506 guessed in 10 attempts
# No 507 guessed in 7 attempts
# No 508 guessed in 10 attempts
# No 509 guessed in 9 attempts
# No 510 guessed in 10 attempts
# No 511 guessed in 8 attempts
# No 512 guessed in 10 attempts
# No 513 guessed in 9 attempts
# No 514 guessed in 10 attempts
# No 515 guessed in 6 attempts
# No 516 guessed in 10 attempts
# No 517 guessed in 9 attempts
# No 518 guessed in 10 attempts
# No 519 guessed in 8 attempts
# No 520 guessed in 10 attempts
# No 521 guessed in 9 attempts
# No 522 guessed in 10 attempts
# No 523 guessed in 7 attempts
# No 524 guessed in 10 attempts
# No 525 guessed in 9 attempts
# No 526 guessed in 10 attempts
# No 527 guessed in 8 attempts
# No 528 guessed in 10 attempts
# No 529 guessed in 9 attempts
# No 530 guessed in 10 attempts
# No 531 guessed in 5 attempts
# No 532 guessed in 9 attempts
# No 533 guessed in 10 attempts
# No 534 guessed in 8 attempts
# No 535 guessed in 10 attempts
# No 536 guessed in 9 attempts
# No 537 guessed in 10 attempts
# No 538 guessed in 7 attempts
# No 539 guessed in 10 attempts
# No 540 guessed in 9 attempts
# No 541 guessed in 10 attempts
# No 542 guessed in 8 attempts
# No 543 guessed in 10 attempts
# No 544 guessed in 9 attempts
# No 545 guessed in 10 attempts
# No 546 guessed in 6 attempts
# No 547 guessed in 10 attempts
# No 548 guessed in 9 attempts
# No 549 guessed in 10 attempts
# No 550 guessed in 8 attempts
# No 551 guessed in 10 attempts
# No 552 guessed in 9 attempts
# No 553 guessed in 10 attempts
# No 554 guessed in 7 attempts
# No 555 guessed in 10 attempts
# No 556 guessed in 9 attempts
# No 557 guessed in 10 attempts
# No 558 guessed in 8 attempts
# No 559 guessed in 10 attempts
# No 560 guessed in 9 attempts
# No 561 guessed in 10 attempts
# No 562 guessed in 4 attempts
# No 563 guessed in 9 attempts
# No 564 guessed in 10 attempts
# No 565 guessed in 8 attempts
# No 566 guessed in 10 attempts
# No 567 guessed in 9 attempts
# No 568 guessed in 10 attempts
# No 569 guessed in 7 attempts
# No 570 guessed in 10 attempts
# No 571 guessed in 9 attempts
# No 572 guessed in 10 attempts
# No 573 guessed in 8 attempts
# No 574 guessed in 10 attempts
# No 575 guessed in 9 attempts
# No 576 guessed in 10 attempts
# No 577 guessed in 6 attempts
# No 578 guessed in 10 attempts
# No 579 guessed in 9 attempts
# No 580 guessed in 10 attempts
# No 581 guessed in 8 attempts
# No 582 guessed in 10 attempts
# No 583 guessed in 9 attempts
# No 584 guessed in 10 attempts
# No 585 guessed in 7 attempts
# No 586 guessed in 10 attempts
# No 587 guessed in 9 attempts
# No 588 guessed in 10 attempts
# No 589 guessed in 8 attempts
# No 590 guessed in 10 attempts
# No 591 guessed in 9 attempts
# No 592 guessed in 10 attempts
# No 593 guessed in 5 attempts
# No 594 guessed in 10 attempts
# No 595 guessed in 9 attempts
# No 596 guessed in 10 attempts
# No 597 guessed in 8 attempts
# No 598 guessed in 10 attempts
# No 599 guessed in 9 attempts
# No 600 guessed in 10 attempts
# No 601 guessed in 7 attempts
# No 602 guessed in 10 attempts
# No 603 guessed in 9 attempts
# No 604 guessed in 10 attempts
# No 605 guessed in 8 attempts
# No 606 guessed in 10 attempts
# No 607 guessed in 9 attempts
# No 608 guessed in 10 attempts
# No 609 guessed in 6 attempts
# No 610 guessed in 10 attempts
# No 611 guessed in 9 attempts
# No 612 guessed in 10 attempts
# No 613 guessed in 8 attempts
# No 614 guessed in 10 attempts
# No 615 guessed in 9 attempts
# No 616 guessed in 10 attempts
# No 617 guessed in 7 attempts
# No 618 guessed in 10 attempts
# No 619 guessed in 9 attempts
# No 620 guessed in 10 attempts
# No 621 guessed in 8 attempts
# No 622 guessed in 10 attempts
# No 623 guessed in 9 attempts
# No 624 guessed in 10 attempts
# No 625 guessed in 3 attempts
# No 626 guessed in 9 attempts
# No 627 guessed in 10 attempts
# No 628 guessed in 8 attempts
# No 629 guessed in 10 attempts
# No 630 guessed in 9 attempts
# No 631 guessed in 10 attempts
# No 632 guessed in 7 attempts
# No 633 guessed in 10 attempts
# No 634 guessed in 9 attempts
# No 635 guessed in 10 attempts
# No 636 guessed in 8 attempts
# No 637 guessed in 10 attempts
# No 638 guessed in 9 attempts
# No 639 guessed in 10 attempts
# No 640 guessed in 6 attempts
# No 641 guessed in 10 attempts
# No 642 guessed in 9 attempts
# No 643 guessed in 10 attempts
# No 644 guessed in 8 attempts
# No 645 guessed in 10 attempts
# No 646 guessed in 9 attempts
# No 647 guessed in 10 attempts
# No 648 guessed in 7 attempts
# No 649 guessed in 10 attempts
# No 650 guessed in 9 attempts
# No 651 guessed in 10 attempts
# No 652 guessed in 8 attempts
# No 653 guessed in 10 attempts
# No 654 guessed in 9 attempts
# No 655 guessed in 10 attempts
# No 656 guessed in 5 attempts
# No 657 guessed in 9 attempts
# No 658 guessed in 10 attempts
# No 659 guessed in 8 attempts
# No 660 guessed in 10 attempts
# No 661 guessed in 9 attempts
# No 662 guessed in 10 attempts
# No 663 guessed in 7 attempts
# No 664 guessed in 10 attempts
# No 665 guessed in 9 attempts
# No 666 guessed in 10 attempts
# No 667 guessed in 8 attempts
# No 668 guessed in 10 attempts
# No 669 guessed in 9 attempts
# No 670 guessed in 10 attempts
# No 671 guessed in 6 attempts
# No 672 guessed in 10 attempts
# No 673 guessed in 9 attempts
# No 674 guessed in 10 attempts
# No 675 guessed in 8 attempts
# No 676 guessed in 10 attempts
# No 677 guessed in 9 attempts
# No 678 guessed in 10 attempts
# No 679 guessed in 7 attempts
# No 680 guessed in 10 attempts
# No 681 guessed in 9 attempts
# No 682 guessed in 10 attempts
# No 683 guessed in 8 attempts
# No 684 guessed in 10 attempts
# No 685 guessed in 9 attempts
# No 686 guessed in 10 attempts
# No 687 guessed in 4 attempts
# No 688 guessed in 9 attempts
# No 689 guessed in 10 attempts
# No 690 guessed in 8 attempts
# No 691 guessed in 10 attempts
# No 692 guessed in 9 attempts
# No 693 guessed in 10 attempts
# No 694 guessed in 7 attempts
# No 695 guessed in 10 attempts
# No 696 guessed in 9 attempts
# No 697 guessed in 10 attempts
# No 698 guessed in 8 attempts
# No 699 guessed in 10 attempts
# No 700 guessed in 9 attempts
# No 701 guessed in 10 attempts
# No 702 guessed in 6 attempts
# No 703 guessed in 10 attempts
# No 704 guessed in 9 attempts
# No 705 guessed in 10 attempts
# No 706 guessed in 8 attempts
# No 707 guessed in 10 attempts
# No 708 guessed in 9 attempts
# No 709 guessed in 10 attempts
# No 710 guessed in 7 attempts
# No 711 guessed in 10 attempts
# No 712 guessed in 9 attempts
# No 713 guessed in 10 attempts
# No 714 guessed in 8 attempts
# No 715 guessed in 10 attempts
# No 716 guessed in 9 attempts
# No 717 guessed in 10 attempts
# No 718 guessed in 5 attempts
# No 719 guessed in 10 attempts
# No 720 guessed in 9 attempts
# No 721 guessed in 10 attempts
# No 722 guessed in 8 attempts
# No 723 guessed in 10 attempts
# No 724 guessed in 9 attempts
# No 725 guessed in 10 attempts
# No 726 guessed in 7 attempts
# No 727 guessed in 10 attempts
# No 728 guessed in 9 attempts
# No 729 guessed in 10 attempts
# No 730 guessed in 8 attempts
# No 731 guessed in 10 attempts
# No 732 guessed in 9 attempts
# No 733 guessed in 10 attempts
# No 734 guessed in 6 attempts
# No 735 guessed in 10 attempts
# No 736 guessed in 9 attempts
# No 737 guessed in 10 attempts
# No 738 guessed in 8 attempts
# No 739 guessed in 10 attempts
# No 740 guessed in 9 attempts
# No 741 guessed in 10 attempts
# No 742 guessed in 7 attempts
# No 743 guessed in 10 attempts
# No 744 guessed in 9 attempts
# No 745 guessed in 10 attempts
# No 746 guessed in 8 attempts
# No 747 guessed in 10 attempts
# No 748 guessed in 9 attempts
# No 749 guessed in 10 attempts
# No 750 guessed in 2 attempts
# No 751 guessed in 9 attempts
# No 752 guessed in 10 attempts
# No 753 guessed in 8 attempts
# No 754 guessed in 10 attempts
# No 755 guessed in 9 attempts
# No 756 guessed in 10 attempts
# No 757 guessed in 7 attempts
# No 758 guessed in 10 attempts
# No 759 guessed in 9 attempts
# No 760 guessed in 10 attempts
# No 761 guessed in 8 attempts
# No 762 guessed in 10 attempts
# No 763 guessed in 9 attempts
# No 764 guessed in 10 attempts
# No 765 guessed in 6 attempts
# No 766 guessed in 10 attempts
# No 767 guessed in 9 attempts
# No 768 guessed in 10 attempts
# No 769 guessed in 8 attempts
# No 770 guessed in 10 attempts
# No 771 guessed in 9 attempts
# No 772 guessed in 10 attempts
# No 773 guessed in 7 attempts
# No 774 guessed in 10 attempts
# No 775 guessed in 9 attempts
# No 776 guessed in 10 attempts
# No 777 guessed in 8 attempts
# No 778 guessed in 10 attempts
# No 779 guessed in 9 attempts
# No 780 guessed in 10 attempts
# No 781 guessed in 5 attempts
# No 782 guessed in 9 attempts
# No 783 guessed in 10 attempts
# No 784 guessed in 8 attempts
# No 785 guessed in 10 attempts
# No 786 guessed in 9 attempts
# No 787 guessed in 10 attempts
# No 788 guessed in 7 attempts
# No 789 guessed in 10 attempts
# No 790 guessed in 9 attempts
# No 791 guessed in 10 attempts
# No 792 guessed in 8 attempts
# No 793 guessed in 10 attempts
# No 794 guessed in 9 attempts
# No 795 guessed in 10 attempts
# No 796 guessed in 6 attempts
# No 797 guessed in 10 attempts
# No 798 guessed in 9 attempts
# No 799 guessed in 10 attempts
# No 800 guessed in 8 attempts
# No 801 guessed in 10 attempts
# No 802 guessed in 9 attempts
# No 803 guessed in 10 attempts
# No 804 guessed in 7 attempts
# No 805 guessed in 10 attempts
# No 806 guessed in 9 attempts
# No 807 guessed in 10 attempts
# No 808 guessed in 8 attempts
# No 809 guessed in 10 attempts
# No 810 guessed in 9 attempts
# No 811 guessed in 10 attempts
# No 812 guessed in 4 attempts
# No 813 guessed in 9 attempts
# No 814 guessed in 10 attempts
# No 815 guessed in 8 attempts
# No 816 guessed in 10 attempts
# No 817 guessed in 9 attempts
# No 818 guessed in 10 attempts
# No 819 guessed in 7 attempts
# No 820 guessed in 10 attempts
# No 821 guessed in 9 attempts
# No 822 guessed in 10 attempts
# No 823 guessed in 8 attempts
# No 824 guessed in 10 attempts
# No 825 guessed in 9 attempts
# No 826 guessed in 10 attempts
# No 827 guessed in 6 attempts
# No 828 guessed in 10 attempts
# No 829 guessed in 9 attempts
# No 830 guessed in 10 attempts
# No 831 guessed in 8 attempts
# No 832 guessed in 10 attempts
# No 833 guessed in 9 attempts
# No 834 guessed in 10 attempts
# No 835 guessed in 7 attempts
# No 836 guessed in 10 attempts
# No 837 guessed in 9 attempts
# No 838 guessed in 10 attempts
# No 839 guessed in 8 attempts
# No 840 guessed in 10 attempts
# No 841 guessed in 9 attempts
# No 842 guessed in 10 attempts
# No 843 guessed in 5 attempts
# No 844 guessed in 10 attempts
# No 845 guessed in 9 attempts
# No 846 guessed in 10 attempts
# No 847 guessed in 8 attempts
# No 848 guessed in 10 attempts
# No 849 guessed in 9 attempts
# No 850 guessed in 10 attempts
# No 851 guessed in 7 attempts
# No 852 guessed in 10 attempts
# No 853 guessed in 9 attempts
# No 854 guessed in 10 attempts
# No 855 guessed in 8 attempts
# No 856 guessed in 10 attempts
# No 857 guessed in 9 attempts
# No 858 guessed in 10 attempts
# No 859 guessed in 6 attempts
# No 860 guessed in 10 attempts
# No 861 guessed in 9 attempts
# No 862 guessed in 10 attempts
# No 863 guessed in 8 attempts
# No 864 guessed in 10 attempts
# No 865 guessed in 9 attempts
# No 866 guessed in 10 attempts
# No 867 guessed in 7 attempts
# No 868 guessed in 10 attempts
# No 869 guessed in 9 attempts
# No 870 guessed in 10 attempts
# No 871 guessed in 8 attempts
# No 872 guessed in 10 attempts
# No 873 guessed in 9 attempts
# No 874 guessed in 10 attempts
# No 875 guessed in 3 attempts
# No 876 guessed in 9 attempts
# No 877 guessed in 10 attempts
# No 878 guessed in 8 attempts
# No 879 guessed in 10 attempts
# No 880 guessed in 9 attempts
# No 881 guessed in 10 attempts
# No 882 guessed in 7 attempts
# No 883 guessed in 10 attempts
# No 884 guessed in 9 attempts
# No 885 guessed in 10 attempts
# No 886 guessed in 8 attempts
# No 887 guessed in 10 attempts
# No 888 guessed in 9 attempts
# No 889 guessed in 10 attempts
# No 890 guessed in 6 attempts
# No 891 guessed in 10 attempts
# No 892 guessed in 9 attempts
# No 893 guessed in 10 attempts
# No 894 guessed in 8 attempts
# No 895 guessed in 10 attempts
# No 896 guessed in 9 attempts
# No 897 guessed in 10 attempts
# No 898 guessed in 7 attempts
# No 899 guessed in 10 attempts
# No 900 guessed in 9 attempts
# No 901 guessed in 10 attempts
# No 902 guessed in 8 attempts
# No 903 guessed in 10 attempts
# No 904 guessed in 9 attempts
# No 905 guessed in 10 attempts
# No 906 guessed in 5 attempts
# No 907 guessed in 10 attempts
# No 908 guessed in 9 attempts
# No 909 guessed in 10 attempts
# No 910 guessed in 8 attempts
# No 911 guessed in 10 attempts
# No 912 guessed in 9 attempts
# No 913 guessed in 10 attempts
# No 914 guessed in 7 attempts
# No 915 guessed in 10 attempts
# No 916 guessed in 9 attempts
# No 917 guessed in 10 attempts
# No 918 guessed in 8 attempts
# No 919 guessed in 10 attempts
# No 920 guessed in 9 attempts
# No 921 guessed in 10 attempts
# No 922 guessed in 6 attempts
# No 923 guessed in 10 attempts
# No 924 guessed in 9 attempts
# No 925 guessed in 10 attempts
# No 926 guessed in 8 attempts
# No 927 guessed in 10 attempts
# No 928 guessed in 9 attempts
# No 929 guessed in 10 attempts
# No 930 guessed in 7 attempts
# No 931 guessed in 10 attempts
# No 932 guessed in 9 attempts
# No 933 guessed in 10 attempts
# No 934 guessed in 8 attempts
# No 935 guessed in 10 attempts
# No 936 guessed in 9 attempts
# No 937 guessed in 10 attempts
# No 938 guessed in 4 attempts
# No 939 guessed in 9 attempts
# No 940 guessed in 10 attempts
# No 941 guessed in 8 attempts
# No 942 guessed in 10 attempts
# No 943 guessed in 9 attempts
# No 944 guessed in 10 attempts
# No 945 guessed in 7 attempts
# No 946 guessed in 10 attempts
# No 947 guessed in 9 attempts
# No 948 guessed in 10 attempts
# No 949 guessed in 8 attempts
# No 950 guessed in 10 attempts
# No 951 guessed in 9 attempts
# No 952 guessed in 10 attempts
# No 953 guessed in 6 attempts
# No 954 guessed in 10 attempts
# No 955 guessed in 9 attempts
# No 956 guessed in 10 attempts
# No 957 guessed in 8 attempts
# No 958 guessed in 10 attempts
# No 959 guessed in 9 attempts
# No 960 guessed in 10 attempts
# No 961 guessed in 7 attempts
# No 962 guessed in 10 attempts
# No 963 guessed in 9 attempts
# No 964 guessed in 10 attempts
# No 965 guessed in 8 attempts
# No 966 guessed in 10 attempts
# No 967 guessed in 9 attempts
# No 968 guessed in 10 attempts
# No 969 guessed in 5 attempts
# No 970 guessed in 10 attempts
# No 971 guessed in 9 attempts
# No 972 guessed in 10 attempts
# No 973 guessed in 8 attempts
# No 974 guessed in 10 attempts
# No 975 guessed in 9 attempts
# No 976 guessed in 10 attempts
# No 977 guessed in 7 attempts
# No 978 guessed in 10 attempts
# No 979 guessed in 9 attempts
# No 980 guessed in 10 attempts
# No 981 guessed in 8 attempts
# No 982 guessed in 10 attempts
# No 983 guessed in 9 attempts
# No 984 guessed in 10 attempts
# No 985 guessed in 6 attempts
# No 986 guessed in 10 attempts
# No 987 guessed in 9 attempts
# No 988 guessed in 10 attempts
# No 989 guessed in 8 attempts
# No 990 guessed in 10 attempts
# No 991 guessed in 9 attempts
# No 992 guessed in 10 attempts
# No 993 guessed in 7 attempts
# No 994 guessed in 10 attempts
# No 995 guessed in 9 attempts
# No 996 guessed in 10 attempts
# No 997 guessed in 8 attempts
# No 998 guessed in 10 attempts
# No 999 guessed in 9 attempts
# No 1000 guessed in 10 attempts

# %% [markdown]
# **You can edit the loop to output the number of times the computer guesses correctly without being told it guessed correctly:**

# %%
correct_count = 0
max_guesses = 0

for number in range(low, high + 1):
    number_of_guesses = guess_binary(number, low, high)
    print("No {} guessed in {} attempts".format(number, number_of_guesses))
    
    if number_of_guesses > max_guesses:
        max_guesses, correct_count = number_of_guesses, 1
    elif number_of_guesses == max_guesses:
        correct_count += 1
        
        
print("Without having to whittle it down, I guessed correctly {} times".format(correct_count))
print("The maximum number of guesses was {}".format(max_guesses))
# Out:
# No 1 guessed in 9 attempts
# No 2 guessed in 10 attempts
# No 3 guessed in 8 attempts
# No 4 guessed in 10 attempts
# No 5 guessed in 9 attempts
# No 6 guessed in 10 attempts
# No 7 guessed in 7 attempts
# No 8 guessed in 10 attempts
# No 9 guessed in 9 attempts
# No 10 guessed in 10 attempts
# No 11 guessed in 8 attempts
# No 12 guessed in 10 attempts
# No 13 guessed in 9 attempts
# No 14 guessed in 10 attempts
# No 15 guessed in 6 attempts
# No 16 guessed in 10 attempts
# No 17 guessed in 9 attempts
# No 18 guessed in 10 attempts
# No 19 guessed in 8 attempts
# No 20 guessed in 10 attempts
# No 21 guessed in 9 attempts
# No 22 guessed in 10 attempts
# No 23 guessed in 7 attempts
# No 24 guessed in 10 attempts
# No 25 guessed in 9 attempts
# No 26 guessed in 10 attempts
# No 27 guessed in 8 attempts
# No 28 guessed in 10 attempts
# No 29 guessed in 9 attempts
# No 30 guessed in 10 attempts
# No 31 guessed in 5 attempts
# No 32 guessed in 9 attempts
# No 33 guessed in 10 attempts
# No 34 guessed in 8 attempts
# No 35 guessed in 10 attempts
# No 36 guessed in 9 attempts
# No 37 guessed in 10 attempts
# No 38 guessed in 7 attempts
# No 39 guessed in 10 attempts
# No 40 guessed in 9 attempts
# No 41 guessed in 10 attempts
# No 42 guessed in 8 attempts
# No 43 guessed in 10 attempts
# No 44 guessed in 9 attempts
# No 45 guessed in 10 attempts
# No 46 guessed in 6 attempts
# No 47 guessed in 10 attempts
# No 48 guessed in 9 attempts
# No 49 guessed in 10 attempts
# No 50 guessed in 8 attempts
# No 51 guessed in 10 attempts
# No 52 guessed in 9 attempts
# No 53 guessed in 10 attempts
# No 54 guessed in 7 attempts
# No 55 guessed in 10 attempts
# No 56 guessed in 9 attempts
# No 57 guessed in 10 attempts
# No 58 guessed in 8 attempts
# No 59 guessed in 10 attempts
# No 60 guessed in 9 attempts
# No 61 guessed in 10 attempts
# No 62 guessed in 4 attempts
# No 63 guessed in 9 attempts
# No 64 guessed in 10 attempts
# No 65 guessed in 8 attempts
# No 66 guessed in 10 attempts
# No 67 guessed in 9 attempts
# No 68 guessed in 10 attempts
# No 69 guessed in 7 attempts
# No 70 guessed in 10 attempts
# No 71 guessed in 9 attempts
# No 72 guessed in 10 attempts
# No 73 guessed in 8 attempts
# No 74 guessed in 10 attempts
# No 75 guessed in 9 attempts
# No 76 guessed in 10 attempts
# No 77 guessed in 6 attempts
# No 78 guessed in 10 attempts
# No 79 guessed in 9 attempts
# No 80 guessed in 10 attempts
# No 81 guessed in 8 attempts
# No 82 guessed in 10 attempts
# No 83 guessed in 9 attempts
# No 84 guessed in 10 attempts
# No 85 guessed in 7 attempts
# No 86 guessed in 10 attempts
# No 87 guessed in 9 attempts
# No 88 guessed in 10 attempts
# No 89 guessed in 8 attempts
# No 90 guessed in 10 attempts
# No 91 guessed in 9 attempts
# No 92 guessed in 10 attempts
# No 93 guessed in 5 attempts
# No 94 guessed in 10 attempts
# No 95 guessed in 9 attempts
# No 96 guessed in 10 attempts
# No 97 guessed in 8 attempts
# No 98 guessed in 10 attempts
# No 99 guessed in 9 attempts
# No 100 guessed in 10 attempts
# No 101 guessed in 7 attempts
# No 102 guessed in 10 attempts
# No 103 guessed in 9 attempts
# No 104 guessed in 10 attempts
# No 105 guessed in 8 attempts
# No 106 guessed in 10 attempts
# No 107 guessed in 9 attempts
# No 108 guessed in 10 attempts
# No 109 guessed in 6 attempts
# No 110 guessed in 10 attempts
# No 111 guessed in 9 attempts
# No 112 guessed in 10 attempts
# No 113 guessed in 8 attempts
# No 114 guessed in 10 attempts
# No 115 guessed in 9 attempts
# No 116 guessed in 10 attempts
# No 117 guessed in 7 attempts
# No 118 guessed in 10 attempts
# No 119 guessed in 9 attempts
# No 120 guessed in 10 attempts
# No 121 guessed in 8 attempts
# No 122 guessed in 10 attempts
# No 123 guessed in 9 attempts
# No 124 guessed in 10 attempts
# No 125 guessed in 3 attempts
# No 126 guessed in 9 attempts
# No 127 guessed in 10 attempts
# No 128 guessed in 8 attempts
# No 129 guessed in 10 attempts
# No 130 guessed in 9 attempts
# No 131 guessed in 10 attempts
# No 132 guessed in 7 attempts
# No 133 guessed in 10 attempts
# No 134 guessed in 9 attempts
# No 135 guessed in 10 attempts
# No 136 guessed in 8 attempts
# No 137 guessed in 10 attempts
# No 138 guessed in 9 attempts
# No 139 guessed in 10 attempts
# No 140 guessed in 6 attempts
# No 141 guessed in 10 attempts
# No 142 guessed in 9 attempts
# No 143 guessed in 10 attempts
# No 144 guessed in 8 attempts
# No 145 guessed in 10 attempts
# No 146 guessed in 9 attempts
# No 147 guessed in 10 attempts
# No 148 guessed in 7 attempts
# No 149 guessed in 10 attempts
# No 150 guessed in 9 attempts
# No 151 guessed in 10 attempts
# No 152 guessed in 8 attempts
# No 153 guessed in 10 attempts
# No 154 guessed in 9 attempts
# No 155 guessed in 10 attempts
# No 156 guessed in 5 attempts
# No 157 guessed in 9 attempts
# No 158 guessed in 10 attempts
# No 159 guessed in 8 attempts
# No 160 guessed in 10 attempts
# No 161 guessed in 9 attempts
# No 162 guessed in 10 attempts
# No 163 guessed in 7 attempts
# No 164 guessed in 10 attempts
# No 165 guessed in 9 attempts
# No 166 guessed in 10 attempts
# No 167 guessed in 8 attempts
# No 168 guessed in 10 attempts
# No 169 guessed in 9 attempts
# No 170 guessed in 10 attempts
# No 171 guessed in 6 attempts
# No 172 guessed in 10 attempts
# No 173 guessed in 9 attempts
# No 174 guessed in 10 attempts
# No 175 guessed in 8 attempts
# No 176 guessed in 10 attempts
# No 177 guessed in 9 attempts
# No 178 guessed in 10 attempts
# No 179 guessed in 7 attempts
# No 180 guessed in 10 attempts
# No 181 guessed in 9 attempts
# No 182 guessed in 10 attempts
# No 183 guessed in 8 attempts
# No 184 guessed in 10 attempts
# No 185 guessed in 9 attempts
# No 186 guessed in 10 attempts
# No 187 guessed in 4 attempts
# No 188 guessed in 9 attempts
# No 189 guessed in 10 attempts
# No 190 guessed in 8 attempts
# No 191 guessed in 10 attempts
# No 192 guessed in 9 attempts
# No 193 guessed in 10 attempts
# No 194 guessed in 7 attempts
# No 195 guessed in 10 attempts
# No 196 guessed in 9 attempts
# No 197 guessed in 10 attempts
# No 198 guessed in 8 attempts
# No 199 guessed in 10 attempts
# No 200 guessed in 9 attempts
# No 201 guessed in 10 attempts
# No 202 guessed in 6 attempts
# No 203 guessed in 10 attempts
# No 204 guessed in 9 attempts
# No 205 guessed in 10 attempts
# No 206 guessed in 8 attempts
# No 207 guessed in 10 attempts
# No 208 guessed in 9 attempts
# No 209 guessed in 10 attempts
# No 210 guessed in 7 attempts
# No 211 guessed in 10 attempts
# No 212 guessed in 9 attempts
# No 213 guessed in 10 attempts
# No 214 guessed in 8 attempts
# No 215 guessed in 10 attempts
# No 216 guessed in 9 attempts
# No 217 guessed in 10 attempts
# No 218 guessed in 5 attempts
# No 219 guessed in 10 attempts
# No 220 guessed in 9 attempts
# No 221 guessed in 10 attempts
# No 222 guessed in 8 attempts
# No 223 guessed in 10 attempts
# No 224 guessed in 9 attempts
# No 225 guessed in 10 attempts
# No 226 guessed in 7 attempts
# No 227 guessed in 10 attempts
# No 228 guessed in 9 attempts
# No 229 guessed in 10 attempts
# No 230 guessed in 8 attempts
# No 231 guessed in 10 attempts
# No 232 guessed in 9 attempts
# No 233 guessed in 10 attempts
# No 234 guessed in 6 attempts
# No 235 guessed in 10 attempts
# No 236 guessed in 9 attempts
# No 237 guessed in 10 attempts
# No 238 guessed in 8 attempts
# No 239 guessed in 10 attempts
# No 240 guessed in 9 attempts
# No 241 guessed in 10 attempts
# No 242 guessed in 7 attempts
# No 243 guessed in 10 attempts
# No 244 guessed in 9 attempts
# No 245 guessed in 10 attempts
# No 246 guessed in 8 attempts
# No 247 guessed in 10 attempts
# No 248 guessed in 9 attempts
# No 249 guessed in 10 attempts
# No 250 guessed in 2 attempts
# No 251 guessed in 9 attempts
# No 252 guessed in 10 attempts
# No 253 guessed in 8 attempts
# No 254 guessed in 10 attempts
# No 255 guessed in 9 attempts
# No 256 guessed in 10 attempts
# No 257 guessed in 7 attempts
# No 258 guessed in 10 attempts
# No 259 guessed in 9 attempts
# No 260 guessed in 10 attempts
# No 261 guessed in 8 attempts
# No 262 guessed in 10 attempts
# No 263 guessed in 9 attempts
# No 264 guessed in 10 attempts
# No 265 guessed in 6 attempts
# No 266 guessed in 10 attempts
# No 267 guessed in 9 attempts
# No 268 guessed in 10 attempts
# No 269 guessed in 8 attempts
# No 270 guessed in 10 attempts
# No 271 guessed in 9 attempts
# No 272 guessed in 10 attempts
# No 273 guessed in 7 attempts
# No 274 guessed in 10 attempts
# No 275 guessed in 9 attempts
# No 276 guessed in 10 attempts
# No 277 guessed in 8 attempts
# No 278 guessed in 10 attempts
# No 279 guessed in 9 attempts
# No 280 guessed in 10 attempts
# No 281 guessed in 5 attempts
# No 282 guessed in 9 attempts
# No 283 guessed in 10 attempts
# No 284 guessed in 8 attempts
# No 285 guessed in 10 attempts
# No 286 guessed in 9 attempts
# No 287 guessed in 10 attempts
# No 288 guessed in 7 attempts
# No 289 guessed in 10 attempts
# No 290 guessed in 9 attempts
# No 291 guessed in 10 attempts
# No 292 guessed in 8 attempts
# No 293 guessed in 10 attempts
# No 294 guessed in 9 attempts
# No 295 guessed in 10 attempts
# No 296 guessed in 6 attempts
# No 297 guessed in 10 attempts
# No 298 guessed in 9 attempts
# No 299 guessed in 10 attempts
# No 300 guessed in 8 attempts
# No 301 guessed in 10 attempts
# No 302 guessed in 9 attempts
# No 303 guessed in 10 attempts
# No 304 guessed in 7 attempts
# No 305 guessed in 10 attempts
# No 306 guessed in 9 attempts
# No 307 guessed in 10 attempts
# No 308 guessed in 8 attempts
# No 309 guessed in 10 attempts
# No 310 guessed in 9 attempts
# No 311 guessed in 10 attempts
# No 312 guessed in 4 attempts
# No 313 guessed in 9 attempts
# No 314 guessed in 10 attempts
# No 315 guessed in 8 attempts
# No 316 guessed in 10 attempts
# No 317 guessed in 9 attempts
# No 318 guessed in 10 attempts
# No 319 guessed in 7 attempts
# No 320 guessed in 10 attempts
# No 321 guessed in 9 attempts
# No 322 guessed in 10 attempts
# No 323 guessed in 8 attempts
# No 324 guessed in 10 attempts
# No 325 guessed in 9 attempts
# No 326 guessed in 10 attempts
# No 327 guessed in 6 attempts
# No 328 guessed in 10 attempts
# No 329 guessed in 9 attempts
# No 330 guessed in 10 attempts
# No 331 guessed in 8 attempts
# No 332 guessed in 10 attempts
# No 333 guessed in 9 attempts
# No 334 guessed in 10 attempts
# No 335 guessed in 7 attempts
# No 336 guessed in 10 attempts
# No 337 guessed in 9 attempts
# No 338 guessed in 10 attempts
# No 339 guessed in 8 attempts
# No 340 guessed in 10 attempts
# No 341 guessed in 9 attempts
# No 342 guessed in 10 attempts
# No 343 guessed in 5 attempts
# No 344 guessed in 10 attempts
# No 345 guessed in 9 attempts
# No 346 guessed in 10 attempts
# No 347 guessed in 8 attempts
# No 348 guessed in 10 attempts
# No 349 guessed in 9 attempts
# No 350 guessed in 10 attempts
# No 351 guessed in 7 attempts
# No 352 guessed in 10 attempts
# No 353 guessed in 9 attempts
# No 354 guessed in 10 attempts
# No 355 guessed in 8 attempts
# No 356 guessed in 10 attempts
# No 357 guessed in 9 attempts
# No 358 guessed in 10 attempts
# No 359 guessed in 6 attempts
# No 360 guessed in 10 attempts
# No 361 guessed in 9 attempts
# No 362 guessed in 10 attempts
# No 363 guessed in 8 attempts
# No 364 guessed in 10 attempts
# No 365 guessed in 9 attempts
# No 366 guessed in 10 attempts
# No 367 guessed in 7 attempts
# No 368 guessed in 10 attempts
# No 369 guessed in 9 attempts
# No 370 guessed in 10 attempts
# No 371 guessed in 8 attempts
# No 372 guessed in 10 attempts
# No 373 guessed in 9 attempts
# No 374 guessed in 10 attempts
# No 375 guessed in 3 attempts
# No 376 guessed in 9 attempts
# No 377 guessed in 10 attempts
# No 378 guessed in 8 attempts
# No 379 guessed in 10 attempts
# No 380 guessed in 9 attempts
# No 381 guessed in 10 attempts
# No 382 guessed in 7 attempts
# No 383 guessed in 10 attempts
# No 384 guessed in 9 attempts
# No 385 guessed in 10 attempts
# No 386 guessed in 8 attempts
# No 387 guessed in 10 attempts
# No 388 guessed in 9 attempts
# No 389 guessed in 10 attempts
# No 390 guessed in 6 attempts
# No 391 guessed in 10 attempts
# No 392 guessed in 9 attempts
# No 393 guessed in 10 attempts
# No 394 guessed in 8 attempts
# No 395 guessed in 10 attempts
# No 396 guessed in 9 attempts
# No 397 guessed in 10 attempts
# No 398 guessed in 7 attempts
# No 399 guessed in 10 attempts
# No 400 guessed in 9 attempts
# No 401 guessed in 10 attempts
# No 402 guessed in 8 attempts
# No 403 guessed in 10 attempts
# No 404 guessed in 9 attempts
# No 405 guessed in 10 attempts
# No 406 guessed in 5 attempts
# No 407 guessed in 9 attempts
# No 408 guessed in 10 attempts
# No 409 guessed in 8 attempts
# No 410 guessed in 10 attempts
# No 411 guessed in 9 attempts
# No 412 guessed in 10 attempts
# No 413 guessed in 7 attempts
# No 414 guessed in 10 attempts
# No 415 guessed in 9 attempts
# No 416 guessed in 10 attempts
# No 417 guessed in 8 attempts
# No 418 guessed in 10 attempts
# No 419 guessed in 9 attempts
# No 420 guessed in 10 attempts
# No 421 guessed in 6 attempts
# No 422 guessed in 10 attempts
# No 423 guessed in 9 attempts
# No 424 guessed in 10 attempts
# No 425 guessed in 8 attempts
# No 426 guessed in 10 attempts
# No 427 guessed in 9 attempts
# No 428 guessed in 10 attempts
# No 429 guessed in 7 attempts
# No 430 guessed in 10 attempts
# No 431 guessed in 9 attempts
# No 432 guessed in 10 attempts
# No 433 guessed in 8 attempts
# No 434 guessed in 10 attempts
# No 435 guessed in 9 attempts
# No 436 guessed in 10 attempts
# No 437 guessed in 4 attempts
# No 438 guessed in 9 attempts
# No 439 guessed in 10 attempts
# No 440 guessed in 8 attempts
# No 441 guessed in 10 attempts
# No 442 guessed in 9 attempts
# No 443 guessed in 10 attempts
# No 444 guessed in 7 attempts
# No 445 guessed in 10 attempts
# No 446 guessed in 9 attempts
# No 447 guessed in 10 attempts
# No 448 guessed in 8 attempts
# No 449 guessed in 10 attempts
# No 450 guessed in 9 attempts
# No 451 guessed in 10 attempts
# No 452 guessed in 6 attempts
# No 453 guessed in 10 attempts
# No 454 guessed in 9 attempts
# No 455 guessed in 10 attempts
# No 456 guessed in 8 attempts
# No 457 guessed in 10 attempts
# No 458 guessed in 9 attempts
# No 459 guessed in 10 attempts
# No 460 guessed in 7 attempts
# No 461 guessed in 10 attempts
# No 462 guessed in 9 attempts
# No 463 guessed in 10 attempts
# No 464 guessed in 8 attempts
# No 465 guessed in 10 attempts
# No 466 guessed in 9 attempts
# No 467 guessed in 10 attempts
# No 468 guessed in 5 attempts
# No 469 guessed in 10 attempts
# No 470 guessed in 9 attempts
# No 471 guessed in 10 attempts
# No 472 guessed in 8 attempts
# No 473 guessed in 10 attempts
# No 474 guessed in 9 attempts
# No 475 guessed in 10 attempts
# No 476 guessed in 7 attempts
# No 477 guessed in 10 attempts
# No 478 guessed in 9 attempts
# No 479 guessed in 10 attempts
# No 480 guessed in 8 attempts
# No 481 guessed in 10 attempts
# No 482 guessed in 9 attempts
# No 483 guessed in 10 attempts
# No 484 guessed in 6 attempts
# No 485 guessed in 10 attempts
# No 486 guessed in 9 attempts
# No 487 guessed in 10 attempts
# No 488 guessed in 8 attempts
# No 489 guessed in 10 attempts
# No 490 guessed in 9 attempts
# No 491 guessed in 10 attempts
# No 492 guessed in 7 attempts
# No 493 guessed in 10 attempts
# No 494 guessed in 9 attempts
# No 495 guessed in 10 attempts
# No 496 guessed in 8 attempts
# No 497 guessed in 10 attempts
# No 498 guessed in 9 attempts
# No 499 guessed in 10 attempts
# No 500 guessed in 1 attempts
# No 501 guessed in 9 attempts
# No 502 guessed in 10 attempts
# No 503 guessed in 8 attempts
# No 504 guessed in 10 attempts
# No 505 guessed in 9 attempts
# No 506 guessed in 10 attempts
# No 507 guessed in 7 attempts
# No 508 guessed in 10 attempts
# No 509 guessed in 9 attempts
# No 510 guessed in 10 attempts
# No 511 guessed in 8 attempts
# No 512 guessed in 10 attempts
# No 513 guessed in 9 attempts
# No 514 guessed in 10 attempts
# No 515 guessed in 6 attempts
# No 516 guessed in 10 attempts
# No 517 guessed in 9 attempts
# No 518 guessed in 10 attempts
# No 519 guessed in 8 attempts
# No 520 guessed in 10 attempts
# No 521 guessed in 9 attempts
# No 522 guessed in 10 attempts
# No 523 guessed in 7 attempts
# No 524 guessed in 10 attempts
# No 525 guessed in 9 attempts
# No 526 guessed in 10 attempts
# No 527 guessed in 8 attempts
# No 528 guessed in 10 attempts
# No 529 guessed in 9 attempts
# No 530 guessed in 10 attempts
# No 531 guessed in 5 attempts
# No 532 guessed in 9 attempts
# No 533 guessed in 10 attempts
# No 534 guessed in 8 attempts
# No 535 guessed in 10 attempts
# No 536 guessed in 9 attempts
# No 537 guessed in 10 attempts
# No 538 guessed in 7 attempts
# No 539 guessed in 10 attempts
# No 540 guessed in 9 attempts
# No 541 guessed in 10 attempts
# No 542 guessed in 8 attempts
# No 543 guessed in 10 attempts
# No 544 guessed in 9 attempts
# No 545 guessed in 10 attempts
# No 546 guessed in 6 attempts
# No 547 guessed in 10 attempts
# No 548 guessed in 9 attempts
# No 549 guessed in 10 attempts
# No 550 guessed in 8 attempts
# No 551 guessed in 10 attempts
# No 552 guessed in 9 attempts
# No 553 guessed in 10 attempts
# No 554 guessed in 7 attempts
# No 555 guessed in 10 attempts
# No 556 guessed in 9 attempts
# No 557 guessed in 10 attempts
# No 558 guessed in 8 attempts
# No 559 guessed in 10 attempts
# No 560 guessed in 9 attempts
# No 561 guessed in 10 attempts
# No 562 guessed in 4 attempts
# No 563 guessed in 9 attempts
# No 564 guessed in 10 attempts
# No 565 guessed in 8 attempts
# No 566 guessed in 10 attempts
# No 567 guessed in 9 attempts
# No 568 guessed in 10 attempts
# No 569 guessed in 7 attempts
# No 570 guessed in 10 attempts
# No 571 guessed in 9 attempts
# No 572 guessed in 10 attempts
# No 573 guessed in 8 attempts
# No 574 guessed in 10 attempts
# No 575 guessed in 9 attempts
# No 576 guessed in 10 attempts
# No 577 guessed in 6 attempts
# No 578 guessed in 10 attempts
# No 579 guessed in 9 attempts
# No 580 guessed in 10 attempts
# No 581 guessed in 8 attempts
# No 582 guessed in 10 attempts
# No 583 guessed in 9 attempts
# No 584 guessed in 10 attempts
# No 585 guessed in 7 attempts
# No 586 guessed in 10 attempts
# No 587 guessed in 9 attempts
# No 588 guessed in 10 attempts
# No 589 guessed in 8 attempts
# No 590 guessed in 10 attempts
# No 591 guessed in 9 attempts
# No 592 guessed in 10 attempts
# No 593 guessed in 5 attempts
# No 594 guessed in 10 attempts
# No 595 guessed in 9 attempts
# No 596 guessed in 10 attempts
# No 597 guessed in 8 attempts
# No 598 guessed in 10 attempts
# No 599 guessed in 9 attempts
# No 600 guessed in 10 attempts
# No 601 guessed in 7 attempts
# No 602 guessed in 10 attempts
# No 603 guessed in 9 attempts
# No 604 guessed in 10 attempts
# No 605 guessed in 8 attempts
# No 606 guessed in 10 attempts
# No 607 guessed in 9 attempts
# No 608 guessed in 10 attempts
# No 609 guessed in 6 attempts
# No 610 guessed in 10 attempts
# No 611 guessed in 9 attempts
# No 612 guessed in 10 attempts
# No 613 guessed in 8 attempts
# No 614 guessed in 10 attempts
# No 615 guessed in 9 attempts
# No 616 guessed in 10 attempts
# No 617 guessed in 7 attempts
# No 618 guessed in 10 attempts
# No 619 guessed in 9 attempts
# No 620 guessed in 10 attempts
# No 621 guessed in 8 attempts
# No 622 guessed in 10 attempts
# No 623 guessed in 9 attempts
# No 624 guessed in 10 attempts
# No 625 guessed in 3 attempts
# No 626 guessed in 9 attempts
# No 627 guessed in 10 attempts
# No 628 guessed in 8 attempts
# No 629 guessed in 10 attempts
# No 630 guessed in 9 attempts
# No 631 guessed in 10 attempts
# No 632 guessed in 7 attempts
# No 633 guessed in 10 attempts
# No 634 guessed in 9 attempts
# No 635 guessed in 10 attempts
# No 636 guessed in 8 attempts
# No 637 guessed in 10 attempts
# No 638 guessed in 9 attempts
# No 639 guessed in 10 attempts
# No 640 guessed in 6 attempts
# No 641 guessed in 10 attempts
# No 642 guessed in 9 attempts
# No 643 guessed in 10 attempts
# No 644 guessed in 8 attempts
# No 645 guessed in 10 attempts
# No 646 guessed in 9 attempts
# No 647 guessed in 10 attempts
# No 648 guessed in 7 attempts
# No 649 guessed in 10 attempts
# No 650 guessed in 9 attempts
# No 651 guessed in 10 attempts
# No 652 guessed in 8 attempts
# No 653 guessed in 10 attempts
# No 654 guessed in 9 attempts
# No 655 guessed in 10 attempts
# No 656 guessed in 5 attempts
# No 657 guessed in 9 attempts
# No 658 guessed in 10 attempts
# No 659 guessed in 8 attempts
# No 660 guessed in 10 attempts
# No 661 guessed in 9 attempts
# No 662 guessed in 10 attempts
# No 663 guessed in 7 attempts
# No 664 guessed in 10 attempts
# No 665 guessed in 9 attempts
# No 666 guessed in 10 attempts
# No 667 guessed in 8 attempts
# No 668 guessed in 10 attempts
# No 669 guessed in 9 attempts
# No 670 guessed in 10 attempts
# No 671 guessed in 6 attempts
# No 672 guessed in 10 attempts
# No 673 guessed in 9 attempts
# No 674 guessed in 10 attempts
# No 675 guessed in 8 attempts
# No 676 guessed in 10 attempts
# No 677 guessed in 9 attempts
# No 678 guessed in 10 attempts
# No 679 guessed in 7 attempts
# No 680 guessed in 10 attempts
# No 681 guessed in 9 attempts
# No 682 guessed in 10 attempts
# No 683 guessed in 8 attempts
# No 684 guessed in 10 attempts
# No 685 guessed in 9 attempts
# No 686 guessed in 10 attempts
# No 687 guessed in 4 attempts
# No 688 guessed in 9 attempts
# No 689 guessed in 10 attempts
# No 690 guessed in 8 attempts
# No 691 guessed in 10 attempts
# No 692 guessed in 9 attempts
# No 693 guessed in 10 attempts
# No 694 guessed in 7 attempts
# No 695 guessed in 10 attempts
# No 696 guessed in 9 attempts
# No 697 guessed in 10 attempts
# No 698 guessed in 8 attempts
# No 699 guessed in 10 attempts
# No 700 guessed in 9 attempts
# No 701 guessed in 10 attempts
# No 702 guessed in 6 attempts
# No 703 guessed in 10 attempts
# No 704 guessed in 9 attempts
# No 705 guessed in 10 attempts
# No 706 guessed in 8 attempts
# No 707 guessed in 10 attempts
# No 708 guessed in 9 attempts
# No 709 guessed in 10 attempts
# No 710 guessed in 7 attempts
# No 711 guessed in 10 attempts
# No 712 guessed in 9 attempts
# No 713 guessed in 10 attempts
# No 714 guessed in 8 attempts
# No 715 guessed in 10 attempts
# No 716 guessed in 9 attempts
# No 717 guessed in 10 attempts
# No 718 guessed in 5 attempts
# No 719 guessed in 10 attempts
# No 720 guessed in 9 attempts
# No 721 guessed in 10 attempts
# No 722 guessed in 8 attempts
# No 723 guessed in 10 attempts
# No 724 guessed in 9 attempts
# No 725 guessed in 10 attempts
# No 726 guessed in 7 attempts
# No 727 guessed in 10 attempts
# No 728 guessed in 9 attempts
# No 729 guessed in 10 attempts
# No 730 guessed in 8 attempts
# No 731 guessed in 10 attempts
# No 732 guessed in 9 attempts
# No 733 guessed in 10 attempts
# No 734 guessed in 6 attempts
# No 735 guessed in 10 attempts
# No 736 guessed in 9 attempts
# No 737 guessed in 10 attempts
# No 738 guessed in 8 attempts
# No 739 guessed in 10 attempts
# No 740 guessed in 9 attempts
# No 741 guessed in 10 attempts
# No 742 guessed in 7 attempts
# No 743 guessed in 10 attempts
# No 744 guessed in 9 attempts
# No 745 guessed in 10 attempts
# No 746 guessed in 8 attempts
# No 747 guessed in 10 attempts
# No 748 guessed in 9 attempts
# No 749 guessed in 10 attempts
# No 750 guessed in 2 attempts
# No 751 guessed in 9 attempts
# No 752 guessed in 10 attempts
# No 753 guessed in 8 attempts
# No 754 guessed in 10 attempts
# No 755 guessed in 9 attempts
# No 756 guessed in 10 attempts
# No 757 guessed in 7 attempts
# No 758 guessed in 10 attempts
# No 759 guessed in 9 attempts
# No 760 guessed in 10 attempts
# No 761 guessed in 8 attempts
# No 762 guessed in 10 attempts
# No 763 guessed in 9 attempts
# No 764 guessed in 10 attempts
# No 765 guessed in 6 attempts
# No 766 guessed in 10 attempts
# No 767 guessed in 9 attempts
# No 768 guessed in 10 attempts
# No 769 guessed in 8 attempts
# No 770 guessed in 10 attempts
# No 771 guessed in 9 attempts
# No 772 guessed in 10 attempts
# No 773 guessed in 7 attempts
# No 774 guessed in 10 attempts
# No 775 guessed in 9 attempts
# No 776 guessed in 10 attempts
# No 777 guessed in 8 attempts
# No 778 guessed in 10 attempts
# No 779 guessed in 9 attempts
# No 780 guessed in 10 attempts
# No 781 guessed in 5 attempts
# No 782 guessed in 9 attempts
# No 783 guessed in 10 attempts
# No 784 guessed in 8 attempts
# No 785 guessed in 10 attempts
# No 786 guessed in 9 attempts
# No 787 guessed in 10 attempts
# No 788 guessed in 7 attempts
# No 789 guessed in 10 attempts
# No 790 guessed in 9 attempts
# No 791 guessed in 10 attempts
# No 792 guessed in 8 attempts
# No 793 guessed in 10 attempts
# No 794 guessed in 9 attempts
# No 795 guessed in 10 attempts
# No 796 guessed in 6 attempts
# No 797 guessed in 10 attempts
# No 798 guessed in 9 attempts
# No 799 guessed in 10 attempts
# No 800 guessed in 8 attempts
# No 801 guessed in 10 attempts
# No 802 guessed in 9 attempts
# No 803 guessed in 10 attempts
# No 804 guessed in 7 attempts
# No 805 guessed in 10 attempts
# No 806 guessed in 9 attempts
# No 807 guessed in 10 attempts
# No 808 guessed in 8 attempts
# No 809 guessed in 10 attempts
# No 810 guessed in 9 attempts
# No 811 guessed in 10 attempts
# No 812 guessed in 4 attempts
# No 813 guessed in 9 attempts
# No 814 guessed in 10 attempts
# No 815 guessed in 8 attempts
# No 816 guessed in 10 attempts
# No 817 guessed in 9 attempts
# No 818 guessed in 10 attempts
# No 819 guessed in 7 attempts
# No 820 guessed in 10 attempts
# No 821 guessed in 9 attempts
# No 822 guessed in 10 attempts
# No 823 guessed in 8 attempts
# No 824 guessed in 10 attempts
# No 825 guessed in 9 attempts
# No 826 guessed in 10 attempts
# No 827 guessed in 6 attempts
# No 828 guessed in 10 attempts
# No 829 guessed in 9 attempts
# No 830 guessed in 10 attempts
# No 831 guessed in 8 attempts
# No 832 guessed in 10 attempts
# No 833 guessed in 9 attempts
# No 834 guessed in 10 attempts
# No 835 guessed in 7 attempts
# No 836 guessed in 10 attempts
# No 837 guessed in 9 attempts
# No 838 guessed in 10 attempts
# No 839 guessed in 8 attempts
# No 840 guessed in 10 attempts
# No 841 guessed in 9 attempts
# No 842 guessed in 10 attempts
# No 843 guessed in 5 attempts
# No 844 guessed in 10 attempts
# No 845 guessed in 9 attempts
# No 846 guessed in 10 attempts
# No 847 guessed in 8 attempts
# No 848 guessed in 10 attempts
# No 849 guessed in 9 attempts
# No 850 guessed in 10 attempts
# No 851 guessed in 7 attempts
# No 852 guessed in 10 attempts
# No 853 guessed in 9 attempts
# No 854 guessed in 10 attempts
# No 855 guessed in 8 attempts
# No 856 guessed in 10 attempts
# No 857 guessed in 9 attempts
# No 858 guessed in 10 attempts
# No 859 guessed in 6 attempts
# No 860 guessed in 10 attempts
# No 861 guessed in 9 attempts
# No 862 guessed in 10 attempts
# No 863 guessed in 8 attempts
# No 864 guessed in 10 attempts
# No 865 guessed in 9 attempts
# No 866 guessed in 10 attempts
# No 867 guessed in 7 attempts
# No 868 guessed in 10 attempts
# No 869 guessed in 9 attempts
# No 870 guessed in 10 attempts
# No 871 guessed in 8 attempts
# No 872 guessed in 10 attempts
# No 873 guessed in 9 attempts
# No 874 guessed in 10 attempts
# No 875 guessed in 3 attempts
# No 876 guessed in 9 attempts
# No 877 guessed in 10 attempts
# No 878 guessed in 8 attempts
# No 879 guessed in 10 attempts
# No 880 guessed in 9 attempts
# No 881 guessed in 10 attempts
# No 882 guessed in 7 attempts
# No 883 guessed in 10 attempts
# No 884 guessed in 9 attempts
# No 885 guessed in 10 attempts
# No 886 guessed in 8 attempts
# No 887 guessed in 10 attempts
# No 888 guessed in 9 attempts
# No 889 guessed in 10 attempts
# No 890 guessed in 6 attempts
# No 891 guessed in 10 attempts
# No 892 guessed in 9 attempts
# No 893 guessed in 10 attempts
# No 894 guessed in 8 attempts
# No 895 guessed in 10 attempts
# No 896 guessed in 9 attempts
# No 897 guessed in 10 attempts
# No 898 guessed in 7 attempts
# No 899 guessed in 10 attempts
# No 900 guessed in 9 attempts
# No 901 guessed in 10 attempts
# No 902 guessed in 8 attempts
# No 903 guessed in 10 attempts
# No 904 guessed in 9 attempts
# No 905 guessed in 10 attempts
# No 906 guessed in 5 attempts
# No 907 guessed in 10 attempts
# No 908 guessed in 9 attempts
# No 909 guessed in 10 attempts
# No 910 guessed in 8 attempts
# No 911 guessed in 10 attempts
# No 912 guessed in 9 attempts
# No 913 guessed in 10 attempts
# No 914 guessed in 7 attempts
# No 915 guessed in 10 attempts
# No 916 guessed in 9 attempts
# No 917 guessed in 10 attempts
# No 918 guessed in 8 attempts
# No 919 guessed in 10 attempts
# No 920 guessed in 9 attempts
# No 921 guessed in 10 attempts
# No 922 guessed in 6 attempts
# No 923 guessed in 10 attempts
# No 924 guessed in 9 attempts
# No 925 guessed in 10 attempts
# No 926 guessed in 8 attempts
# No 927 guessed in 10 attempts
# No 928 guessed in 9 attempts
# No 929 guessed in 10 attempts
# No 930 guessed in 7 attempts
# No 931 guessed in 10 attempts
# No 932 guessed in 9 attempts
# No 933 guessed in 10 attempts
# No 934 guessed in 8 attempts
# No 935 guessed in 10 attempts
# No 936 guessed in 9 attempts
# No 937 guessed in 10 attempts
# No 938 guessed in 4 attempts
# No 939 guessed in 9 attempts
# No 940 guessed in 10 attempts
# No 941 guessed in 8 attempts
# No 942 guessed in 10 attempts
# No 943 guessed in 9 attempts
# No 944 guessed in 10 attempts
# No 945 guessed in 7 attempts
# No 946 guessed in 10 attempts
# No 947 guessed in 9 attempts
# No 948 guessed in 10 attempts
# No 949 guessed in 8 attempts
# No 950 guessed in 10 attempts
# No 951 guessed in 9 attempts
# No 952 guessed in 10 attempts
# No 953 guessed in 6 attempts
# No 954 guessed in 10 attempts
# No 955 guessed in 9 attempts
# No 956 guessed in 10 attempts
# No 957 guessed in 8 attempts
# No 958 guessed in 10 attempts
# No 959 guessed in 9 attempts
# No 960 guessed in 10 attempts
# No 961 guessed in 7 attempts
# No 962 guessed in 10 attempts
# No 963 guessed in 9 attempts
# No 964 guessed in 10 attempts
# No 965 guessed in 8 attempts
# No 966 guessed in 10 attempts
# No 967 guessed in 9 attempts
# No 968 guessed in 10 attempts
# No 969 guessed in 5 attempts
# No 970 guessed in 10 attempts
# No 971 guessed in 9 attempts
# No 972 guessed in 10 attempts
# No 973 guessed in 8 attempts
# No 974 guessed in 10 attempts
# No 975 guessed in 9 attempts
# No 976 guessed in 10 attempts
# No 977 guessed in 7 attempts
# No 978 guessed in 10 attempts
# No 979 guessed in 9 attempts
# No 980 guessed in 10 attempts
# No 981 guessed in 8 attempts
# No 982 guessed in 10 attempts
# No 983 guessed in 9 attempts
# No 984 guessed in 10 attempts
# No 985 guessed in 6 attempts
# No 986 guessed in 10 attempts
# No 987 guessed in 9 attempts
# No 988 guessed in 10 attempts
# No 989 guessed in 8 attempts
# No 990 guessed in 10 attempts
# No 991 guessed in 9 attempts
# No 992 guessed in 10 attempts
# No 993 guessed in 7 attempts
# No 994 guessed in 10 attempts
# No 995 guessed in 9 attempts
# No 996 guessed in 10 attempts
# No 997 guessed in 8 attempts
# No 998 guessed in 10 attempts
# No 999 guessed in 9 attempts
# No 1000 guessed in 10 attempts
# Without having to whittle it down, I guessed correctly 489 times
# The maximum number of guesses was 10
